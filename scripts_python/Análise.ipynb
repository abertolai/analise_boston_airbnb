# %% [markdown]
# # Análise Airbnb Boston

# %% [markdown]
# <p> Um investidor pessoal contratou seus serviços. Ele está planejando comprar 10 casas de férias para investimento. Com base no desempenho das casas que você analisou, esse é um bom investimento? </p>
# <p> Qual o melhor tipo de casa para investir?</p>
# <p> O que acontece se o aluguel cair em média 20% </p>

# %% [markdown]
# ## Análise inicial

# %% [markdown]
# ### Dataset listings

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Configurar pandas para exibir todas as colunas
pd.set_option('display.max_columns', None)

# Configurar pandas para exibir todo o conteúdo das colunas
pd.reset_option('max_colwidth')

# %%
listings = pd.read_csv('../csvs_originais/listings.csv')
listings.head(3)
# Out:
#          id                            listing_url       scrape_id  \
# 0  12147973  https://www.airbnb.com/rooms/12147973  20160906204935
# 1   3075044   https://www.airbnb.com/rooms/3075044  20160906204935
# 2      6976      https://www.airbnb.com/rooms/6976  20160906204935
#
#   last_scraped                               name  \
# 0   2016-09-07         Sunny Bungalow in the City
# 1   2016-09-07  Charming room in pet friendly apt
# 2   2016-09-07   Mexican Folk Art Haven in Boston
#
#                                              summary  \
# 0  Cozy, sunny, family home.  Master bedroom high...
# 1  Charming and quiet room in a second floor 1910...
# 2  Come stay with a friendly, middle-aged guy in ...
#
#                                                space  \
# 0  The house has an open and cozy feel at the sam...
# 1  Small but cozy and quite room with a full size...
# 2  Come stay with a friendly, middle-aged guy in ...
#
#                                          description experiences_offered  \
# 0  Cozy, sunny, family home.  Master bedroom high...                none
# 1  Charming and quiet room in a second floor 1910...                none
# 2  Come stay with a friendly, middle-aged guy in ...                none
#
#                                neighborhood_overview  \
# 0  Roslindale is quiet, convenient and friendly. ...
# 1  The room is in Roslindale, a diverse and prima...
# 2  The LOCATION: Roslindale is a safe and diverse...
#
#                                                notes  \
# 0                                                NaN
# 1  If you don't have a US cell phone, you can tex...
# 2  I am in a scenic part of Boston with a couple ...
#
#                                              transit  \
# 0  The bus stop is 2 blocks away, and frequent. B...
# 1  Plenty of safe street parking. Bus stops a few...
# 2  PUBLIC TRANSPORTATION: From the house, quick p...
#
#                                               access  \
# 0  You will have access to 2 bedrooms, a living r...
# 1  Apt has one more bedroom (which I use) and lar...
# 2  I am living in the apartment during your stay,...
#
#                                          interaction  \
# 0                                                NaN
# 1  If I am at home, I am likely working in my hom...
# 2  ABOUT ME: I'm a laid-back, friendly, unmarried...
#
#                                          house_rules  \
# 0  Clean up and treat the home the way you'd like...
# 1  Pet friendly but please confirm with me if the...
# 2  I encourage you to use my kitchen, cooking and...
#
#                                        thumbnail_url  \
# 0  https://a2.muscache.com/im/pictures/c0842db1-e...
# 1  https://a1.muscache.com/im/pictures/39327812/d...
# 2  https://a2.muscache.com/im/pictures/6ae8335d-9...
#
#                                           medium_url  \
# 0  https://a2.muscache.com/im/pictures/c0842db1-e...
# 1  https://a1.muscache.com/im/pictures/39327812/d...
# 2  https://a2.muscache.com/im/pictures/6ae8335d-9...
#
#                                          picture_url  \
# 0  https://a2.muscache.com/im/pictures/c0842db1-e...
# 1  https://a1.muscache.com/im/pictures/39327812/d...
# 2  https://a2.muscache.com/im/pictures/6ae8335d-9...
#
#                                       xl_picture_url   host_id  \
# 0  https://a2.muscache.com/im/pictures/c0842db1-e...  31303940
# 1  https://a1.muscache.com/im/pictures/39327812/d...   2572247
# 2  https://a2.muscache.com/im/pictures/6ae8335d-9...     16701
#
#                                      host_url host_name  host_since  \
# 0  https://www.airbnb.com/users/show/31303940  Virginia  2015-04-15
# 1   https://www.airbnb.com/users/show/2572247    Andrea  2012-06-07
# 2     https://www.airbnb.com/users/show/16701      Phil  2009-05-11
#
#                           host_location  \
# 0  Boston, Massachusetts, United States
# 1  Boston, Massachusetts, United States
# 2  Boston, Massachusetts, United States
#
#                                           host_about  host_response_time  \
# 0  We are country and city connecting in our deck...                 NaN
# 1  I live in Boston and I like to travel and have...      within an hour
# 2  I am a middle-aged, single male with a wide ra...  within a few hours
#
#   host_response_rate host_acceptance_rate host_is_superhost  \
# 0                NaN                  NaN                 f
# 1               100%                 100%                 f
# 2               100%                  88%                 t
#
#                                   host_thumbnail_url  \
# 0  https://a2.muscache.com/im/pictures/5936fef0-b...
# 1  https://a2.muscache.com/im/users/2572247/profi...
# 2  https://a2.muscache.com/im/users/16701/profile...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a2.muscache.com/im/pictures/5936fef0-b...         Roslindale
# 1  https://a2.muscache.com/im/users/2572247/profi...         Roslindale
# 2  https://a2.muscache.com/im/users/16701/profile...         Roslindale
#
#    host_listings_count  host_total_listings_count  \
# 0                    1                          1
# 1                    1                          1
# 2                    1                          1
#
#                                   host_verifications host_has_profile_pic  \
# 0          ['email', 'phone', 'facebook', 'reviews']                    t
# 1  ['email', 'phone', 'facebook', 'linkedin', 'am...                    t
# 2             ['email', 'phone', 'reviews', 'jumio']                    t
#
#   host_identity_verified                                             street  \
# 0                      f      Birch Street, Boston, MA 02131, United States
# 1                      t  Pinehurst Street, Boston, MA 02131, United States
# 2                      t        Ardale St., Boston, MA 02131, United States
#
#   neighbourhood neighbourhood_cleansed  neighbourhood_group_cleansed    city  \
# 0    Roslindale             Roslindale                           NaN  Boston
# 1    Roslindale             Roslindale                           NaN  Boston
# 2    Roslindale             Roslindale                           NaN  Boston
#
#   state zipcode  market smart_location country_code        country   latitude  \
# 0    MA   02131  Boston     Boston, MA           US  United States  42.282619
# 1    MA   02131  Boston     Boston, MA           US  United States  42.286241
# 2    MA   02131  Boston     Boston, MA           US  United States  42.292438
#
#    longitude is_location_exact property_type        room_type  accommodates  \
# 0 -71.133068                 t         House  Entire home/apt             4
# 1 -71.134374                 t     Apartment     Private room             2
# 2 -71.135765                 t     Apartment     Private room             2
#
#    bathrooms  bedrooms  beds  bed_type  \
# 0        1.5       2.0   3.0  Real Bed
# 1        1.0       1.0   1.0  Real Bed
# 2        1.0       1.0   1.0  Real Bed
#
#                                            amenities  square_feet    price  \
# 0  {TV,"Wireless Internet",Kitchen,"Free Parking ...          NaN  $250.00
# 1  {TV,Internet,"Wireless Internet","Air Conditio...          NaN   $65.00
# 2  {TV,"Cable TV","Wireless Internet","Air Condit...          NaN   $65.00
#
#   weekly_price monthly_price security_deposit cleaning_fee  guests_included  \
# 0          NaN           NaN              NaN       $35.00                1
# 1      $400.00           NaN           $95.00       $10.00                0
# 2      $395.00     $1,350.00              NaN          NaN                1
#
#   extra_people  minimum_nights  maximum_nights calendar_updated  \
# 0        $0.00               2            1125      2 weeks ago
# 1        $0.00               2              15       a week ago
# 2       $20.00               3              45       5 days ago
#
#    has_availability  availability_30  availability_60  availability_90  \
# 0               NaN                0                0                0
# 1               NaN               26               54               84
# 2               NaN               19               46               61
#
#    availability_365 calendar_last_scraped  number_of_reviews first_review  \
# 0                 0            2016-09-06                  0          NaN
# 1               359            2016-09-06                 36   2014-06-01
# 2               319            2016-09-06                 41   2009-07-19
#
#   last_review  review_scores_rating  review_scores_accuracy  \
# 0         NaN                   NaN                     NaN
# 1  2016-08-13                  94.0                    10.0
# 2  2016-08-05                  98.0                    10.0
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                        NaN                    NaN
# 1                        9.0                   10.0
# 2                        9.0                   10.0
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                          NaN                     NaN                  NaN
# 1                         10.0                     9.0                  9.0
# 2                         10.0                     9.0                 10.0
#
#   requires_license  license  jurisdiction_names instant_bookable  \
# 0                f      NaN                 NaN                f
# 1                f      NaN                 NaN                t
# 2                f      NaN                 NaN                f
#
#   cancellation_policy require_guest_profile_picture  \
# 0            moderate                             f
# 1            moderate                             f
# 2            moderate                             t
#
#   require_guest_phone_verification  calculated_host_listings_count  \
# 0                                f                               1
# 1                                f                               1
# 2                                f                               1
#
#    reviews_per_month
# 0                NaN
# 1               1.30
# 2               0.47

# %%
colunas_para_remover = ['scrape_id','last_scraped','thumbnail_url','medium_url','picture_url','xl_picture_url','host_thumbnail_url','host_picture_url','country_code','country','calendar_last_scraped']

listings = listings.drop(columns=colunas_para_remover)

# %%
listings.describe()
# Out:
#                  id       host_id  host_listings_count  \
# count  3.585000e+03  3.585000e+03          3585.000000
# mean   8.440875e+06  2.492311e+07            58.902371
# std    4.500787e+06  2.292781e+07           171.119663
# min    3.353000e+03  4.240000e+03             0.000000
# 25%    4.679319e+06  6.103425e+06             1.000000
# 50%    8.577620e+06  1.928100e+07             2.000000
# 75%    1.278953e+07  3.622147e+07             7.000000
# max    1.493346e+07  9.385411e+07           749.000000
#
#        host_total_listings_count  neighbourhood_group_cleansed     latitude  \
# count                3585.000000                           0.0  3585.000000
# mean                   58.902371                           NaN    42.340032
# std                   171.119663                           NaN     0.024403
# min                     0.000000                           NaN    42.235942
# 25%                     1.000000                           NaN    42.329995
# 50%                     2.000000                           NaN    42.345201
# 75%                     7.000000                           NaN    42.354685
# max                   749.000000                           NaN    42.389982
#
#          longitude  accommodates    bathrooms     bedrooms         beds  \
# count  3585.000000   3585.000000  3571.000000  3575.000000  3576.000000
# mean    -71.084818      3.041283     1.221647     1.255944     1.609060
# std       0.031565      1.778929     0.501487     0.753060     1.011745
# min     -71.171789      1.000000     0.000000     0.000000     0.000000
# 25%     -71.105083      2.000000     1.000000     1.000000     1.000000
# 50%     -71.078429      2.000000     1.000000     1.000000     1.000000
# 75%     -71.062155      4.000000     1.000000     2.000000     2.000000
# max     -71.000100     16.000000     6.000000     5.000000    16.000000
#
#        square_feet  guests_included  minimum_nights  maximum_nights  \
# count    56.000000      3585.000000     3585.000000    3.585000e+03
# mean    858.464286         1.429847        3.171269    2.872584e+04
# std     608.874310         1.056787        8.874133    1.670136e+06
# min       0.000000         0.000000        1.000000    1.000000e+00
# 25%     415.000000         1.000000        1.000000    3.650000e+02
# 50%     825.000000         1.000000        2.000000    1.125000e+03
# 75%    1200.000000         1.000000        3.000000    1.125000e+03
# max    2400.000000        14.000000      300.000000    1.000000e+08
#
#        has_availability  availability_30  availability_60  availability_90  \
# count               0.0       3585.00000      3585.000000      3585.000000
# mean                NaN          8.64993        21.833194        38.558159
# std                 NaN         10.43533        21.860966        33.158272
# min                 NaN          0.00000         0.000000         0.000000
# 25%                 NaN          0.00000         0.000000         0.000000
# 50%                 NaN          4.00000        16.000000        37.000000
# 75%                 NaN         15.00000        40.000000        68.000000
# max                 NaN         30.00000        60.000000        90.000000
#
#        availability_365  number_of_reviews  review_scores_rating  \
# count       3585.000000        3585.000000           2772.000000
# mean         179.346444          19.044630             91.916667
# std          142.136180          35.571658              9.531686
# min            0.000000           0.000000             20.000000
# 25%           19.000000           1.000000             89.000000
# 50%          179.000000           5.000000             94.000000
# 75%          325.000000          21.000000             98.250000
# max          365.000000         404.000000            100.000000
#
#        review_scores_accuracy  review_scores_cleanliness  \
# count             2762.000000                2767.000000
# mean                 9.431571                   9.258041
# std                  0.931863                   1.168977
# min                  2.000000                   2.000000
# 25%                  9.000000                   9.000000
# 50%                 10.000000                  10.000000
# 75%                 10.000000                  10.000000
# max                 10.000000                  10.000000
#
#        review_scores_checkin  review_scores_communication  \
# count            2765.000000                  2767.000000
# mean                9.646293                     9.646549
# std                 0.762753                     0.735507
# min                 2.000000                     4.000000
# 25%                 9.000000                     9.000000
# 50%                10.000000                    10.000000
# 75%                10.000000                    10.000000
# max                10.000000                    10.000000
#
#        review_scores_location  review_scores_value  license  \
# count             2763.000000          2764.000000      0.0
# mean                 9.414043             9.168234      NaN
# std                  0.903436             1.011116      NaN
# min                  2.000000             2.000000      NaN
# 25%                  9.000000             9.000000      NaN
# 50%                 10.000000             9.000000      NaN
# 75%                 10.000000            10.000000      NaN
# max                 10.000000            10.000000      NaN
#
#        jurisdiction_names  calculated_host_listings_count  reviews_per_month
# count                 0.0                     3585.000000        2829.000000
# mean                  NaN                       12.733891           1.970908
# std                   NaN                       29.415076           2.120561
# min                   NaN                        1.000000           0.010000
# 25%                   NaN                        1.000000           0.480000
# 50%                   NaN                        2.000000           1.170000
# 75%                   NaN                        6.000000           2.720000
# max                   NaN                      136.000000          19.150000

# %%
listings.shape
# Out:
# (3585, 84)

# %% [markdown]
# <i>Validando se algumas tabelas que não foram removidas de fato não possuem valores que são interessantes para a análise </i>

# %%
# jurisdiction_names, license, neighbourhood_group_cleansed

listings['jurisdiction_names'].isnull().sum()
# Out:
# 3585

# %%
listings['license'].isnull().sum()
# Out:
# 3585

# %%
listings['neighbourhood_group_cleansed'].isnull().sum()
# Out:
# 3585

# %%
listings['square_feet'].isnull().sum()
#considerando do total de 3585 registros, 3529 possuem valores nulos no campo square_feet,
#essa coluna não é confiável para uma análise significativa, por isso, irei removê-la também do meu dataframe
# Out:
# 3529

# %%
listings['has_availability'].isnull().sum()
# Out:
# 3585

# %%
colunas_para_remover = ['jurisdiction_names','license','neighbourhood_group_cleansed', 'square_feet','has_availability']

listings = listings.drop(columns=colunas_para_remover)

# %%
listings.head()
# Out:
#          id                            listing_url  \
# 0  12147973  https://www.airbnb.com/rooms/12147973
# 1   3075044   https://www.airbnb.com/rooms/3075044
# 2      6976      https://www.airbnb.com/rooms/6976
# 3   1436513   https://www.airbnb.com/rooms/1436513
# 4   7651065   https://www.airbnb.com/rooms/7651065
#
#                                             name  \
# 0                     Sunny Bungalow in the City
# 1              Charming room in pet friendly apt
# 2               Mexican Folk Art Haven in Boston
# 3  Spacious Sunny Bedroom Suite in Historic Home
# 4                            Come Home to Boston
#
#                                              summary  \
# 0  Cozy, sunny, family home.  Master bedroom high...
# 1  Charming and quiet room in a second floor 1910...
# 2  Come stay with a friendly, middle-aged guy in ...
# 3  Come experience the comforts of home away from...
# 4  My comfy, clean and relaxing home is one block...
#
#                                                space  \
# 0  The house has an open and cozy feel at the sam...
# 1  Small but cozy and quite room with a full size...
# 2  Come stay with a friendly, middle-aged guy in ...
# 3  Most places you find in Boston are small howev...
# 4  Clean, attractive, private room, one block fro...
#
#                                          description experiences_offered  \
# 0  Cozy, sunny, family home.  Master bedroom high...                none
# 1  Charming and quiet room in a second floor 1910...                none
# 2  Come stay with a friendly, middle-aged guy in ...                none
# 3  Come experience the comforts of home away from...                none
# 4  My comfy, clean and relaxing home is one block...                none
#
#                                neighborhood_overview  \
# 0  Roslindale is quiet, convenient and friendly. ...
# 1  The room is in Roslindale, a diverse and prima...
# 2  The LOCATION: Roslindale is a safe and diverse...
# 3  Roslindale is a lovely little neighborhood loc...
# 4  I love the proximity to downtown, the neighbor...
#
#                                                notes  \
# 0                                                NaN
# 1  If you don't have a US cell phone, you can tex...
# 2  I am in a scenic part of Boston with a couple ...
# 3  Please be mindful of the property as it is old...
# 4  I have one roommate who lives on the lower lev...
#
#                                              transit  \
# 0  The bus stop is 2 blocks away, and frequent. B...
# 1  Plenty of safe street parking. Bus stops a few...
# 2  PUBLIC TRANSPORTATION: From the house, quick p...
# 3  There are buses that stop right in front of th...
# 4  From Logan Airport  and South Station you have...
#
#                                               access  \
# 0  You will have access to 2 bedrooms, a living r...
# 1  Apt has one more bedroom (which I use) and lar...
# 2  I am living in the apartment during your stay,...
# 3  The basement has a washer dryer and gym area. ...
# 4  You will have access to the front and side por...
#
#                                          interaction  \
# 0                                                NaN
# 1  If I am at home, I am likely working in my hom...
# 2  ABOUT ME: I'm a laid-back, friendly, unmarried...
# 3  We do live in the house therefore might be som...
# 4  I love my city and really enjoy sharing it wit...
#
#                                          house_rules   host_id  \
# 0  Clean up and treat the home the way you'd like...  31303940
# 1  Pet friendly but please confirm with me if the...   2572247
# 2  I encourage you to use my kitchen, cooking and...     16701
# 3  - The bathroom and house are shared so please ...   6031442
# 4  Please no smoking in the house, porch or on th...  15396970
#
#                                      host_url host_name  host_since  \
# 0  https://www.airbnb.com/users/show/31303940  Virginia  2015-04-15
# 1   https://www.airbnb.com/users/show/2572247    Andrea  2012-06-07
# 2     https://www.airbnb.com/users/show/16701      Phil  2009-05-11
# 3   https://www.airbnb.com/users/show/6031442    Meghna  2013-04-21
# 4  https://www.airbnb.com/users/show/15396970     Linda  2014-05-11
#
#                           host_location  \
# 0  Boston, Massachusetts, United States
# 1  Boston, Massachusetts, United States
# 2  Boston, Massachusetts, United States
# 3  Boston, Massachusetts, United States
# 4  Boston, Massachusetts, United States
#
#                                           host_about  host_response_time  \
# 0  We are country and city connecting in our deck...                 NaN
# 1  I live in Boston and I like to travel and have...      within an hour
# 2  I am a middle-aged, single male with a wide ra...  within a few hours
# 3  My husband and I live on the property.  He’s a...  within a few hours
# 4  I work full time for a public school district....      within an hour
#
#   host_response_rate host_acceptance_rate host_is_superhost  \
# 0                NaN                  NaN                 f
# 1               100%                 100%                 f
# 2               100%                  88%                 t
# 3               100%                  50%                 f
# 4               100%                 100%                 t
#
#   host_neighbourhood  host_listings_count  host_total_listings_count  \
# 0         Roslindale                    1                          1
# 1         Roslindale                    1                          1
# 2         Roslindale                    1                          1
# 3                NaN                    1                          1
# 4         Roslindale                    1                          1
#
#                                   host_verifications host_has_profile_pic  \
# 0          ['email', 'phone', 'facebook', 'reviews']                    t
# 1  ['email', 'phone', 'facebook', 'linkedin', 'am...                    t
# 2             ['email', 'phone', 'reviews', 'jumio']                    t
# 3                      ['email', 'phone', 'reviews']                    t
# 4               ['email', 'phone', 'reviews', 'kba']                    t
#
#   host_identity_verified                                             street  \
# 0                      f      Birch Street, Boston, MA 02131, United States
# 1                      t  Pinehurst Street, Boston, MA 02131, United States
# 2                      t        Ardale St., Boston, MA 02131, United States
# 3                      f                          Boston, MA, United States
# 4                      t    Durnell Avenue, Boston, MA 02131, United States
#
#   neighbourhood neighbourhood_cleansed    city state zipcode  market  \
# 0    Roslindale             Roslindale  Boston    MA   02131  Boston
# 1    Roslindale             Roslindale  Boston    MA   02131  Boston
# 2    Roslindale             Roslindale  Boston    MA   02131  Boston
# 3           NaN             Roslindale  Boston    MA     NaN  Boston
# 4    Roslindale             Roslindale  Boston    MA   02131  Boston
#
#   smart_location   latitude  longitude is_location_exact property_type  \
# 0     Boston, MA  42.282619 -71.133068                 t         House
# 1     Boston, MA  42.286241 -71.134374                 t     Apartment
# 2     Boston, MA  42.292438 -71.135765                 t     Apartment
# 3     Boston, MA  42.281106 -71.121021                 f         House
# 4     Boston, MA  42.284512 -71.136258                 t         House
#
#          room_type  accommodates  bathrooms  bedrooms  beds  bed_type  \
# 0  Entire home/apt             4        1.5       2.0   3.0  Real Bed
# 1     Private room             2        1.0       1.0   1.0  Real Bed
# 2     Private room             2        1.0       1.0   1.0  Real Bed
# 3     Private room             4        1.0       1.0   2.0  Real Bed
# 4     Private room             2        1.5       1.0   2.0  Real Bed
#
#                                            amenities    price weekly_price  \
# 0  {TV,"Wireless Internet",Kitchen,"Free Parking ...  $250.00          NaN
# 1  {TV,Internet,"Wireless Internet","Air Conditio...   $65.00      $400.00
# 2  {TV,"Cable TV","Wireless Internet","Air Condit...   $65.00      $395.00
# 3  {TV,Internet,"Wireless Internet","Air Conditio...   $75.00          NaN
# 4  {Internet,"Wireless Internet","Air Conditionin...   $79.00          NaN
#
#   monthly_price security_deposit cleaning_fee  guests_included extra_people  \
# 0           NaN              NaN       $35.00                1        $0.00
# 1           NaN           $95.00       $10.00                0        $0.00
# 2     $1,350.00              NaN          NaN                1       $20.00
# 3           NaN          $100.00       $50.00                2       $25.00
# 4           NaN              NaN       $15.00                1        $0.00
#
#    minimum_nights  maximum_nights calendar_updated  availability_30  \
# 0               2            1125      2 weeks ago                0
# 1               2              15       a week ago               26
# 2               3              45       5 days ago               19
# 3               1            1125       a week ago                6
# 4               2              31      2 weeks ago               13
#
#    availability_60  availability_90  availability_365  number_of_reviews  \
# 0                0                0                 0                  0
# 1               54               84               359                 36
# 2               46               61               319                 41
# 3               16               26                98                  1
# 4               34               59               334                 29
#
#   first_review last_review  review_scores_rating  review_scores_accuracy  \
# 0          NaN         NaN                   NaN                     NaN
# 1   2014-06-01  2016-08-13                  94.0                    10.0
# 2   2009-07-19  2016-08-05                  98.0                    10.0
# 3   2016-08-28  2016-08-28                 100.0                    10.0
# 4   2015-08-18  2016-09-01                  99.0                    10.0
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                        NaN                    NaN
# 1                        9.0                   10.0
# 2                        9.0                   10.0
# 3                       10.0                   10.0
# 4                       10.0                   10.0
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                          NaN                     NaN                  NaN
# 1                         10.0                     9.0                  9.0
# 2                         10.0                     9.0                 10.0
# 3                         10.0                    10.0                 10.0
# 4                         10.0                     9.0                 10.0
#
#   requires_license instant_bookable cancellation_policy  \
# 0                f                f            moderate
# 1                f                t            moderate
# 2                f                f            moderate
# 3                f                f            moderate
# 4                f                f            flexible
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                f
# 1                             f                                f
# 2                             t                                f
# 3                             f                                f
# 4                             f                                f
#
#    calculated_host_listings_count  reviews_per_month
# 0                               1                NaN
# 1                               1               1.30
# 2                               1               0.47
# 3                               1               1.00
# 4                               1               2.25

# %%
#contando a quantidade de valores none para a coluna experiences_offered
(listings['experiences_offered'] == 'none').sum()
# Out:
# 3585

# %%
(listings['requires_license'] == 'f').sum()
# Out:
# 3585

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3585 entries, 0 to 3584
# Data columns (total 79 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                3585 non-null   int64
#  1   listing_url                       3585 non-null   object
#  2   name                              3585 non-null   object
#  3   summary                           3442 non-null   object
#  4   space                             2528 non-null   object
#  5   description                       3585 non-null   object
#  6   experiences_offered               3585 non-null   object
#  7   neighborhood_overview             2170 non-null   object
#  8   notes                             1610 non-null   object
#  9   transit                           2295 non-null   object
#  10  access                            2096 non-null   object
#  11  interaction                       2031 non-null   object
#  12  house_rules                       2393 non-null   object
#  13  host_id                           3585 non-null   int64
#  14  host_url                          3585 non-null   object
#  15  host_name                         3585 non-null   object
#  16  host_since                        3585 non-null   object
#  17  host_location                     3574 non-null   object
#  18  host_about                        2276 non-null   object
#  19  host_response_time                3114 non-null   object
#  20  host_response_rate                3114 non-null   object
#  21  host_acceptance_rate              3114 non-null   object
#  22  host_is_superhost                 3585 non-null   object
#  23  host_neighbourhood                3246 non-null   object
#  24  host_listings_count               3585 non-null   int64
#  25  host_total_listings_count         3585 non-null   int64
#  26  host_verifications                3585 non-null   object
#  27  host_has_profile_pic              3585 non-null   object
#  28  host_identity_verified            3585 non-null   object
#  29  street                            3585 non-null   object
#  30  neighbourhood                     3042 non-null   object
#  31  neighbourhood_cleansed            3585 non-null   object
#  32  city                              3583 non-null   object
#  33  state                             3585 non-null   object
#  34  zipcode                           3547 non-null   object
#  35  market                            3571 non-null   object
#  36  smart_location                    3585 non-null   object
#  37  latitude                          3585 non-null   float64
#  38  longitude                         3585 non-null   float64
#  39  is_location_exact                 3585 non-null   object
#  40  property_type                     3582 non-null   object
#  41  room_type                         3585 non-null   object
#  42  accommodates                      3585 non-null   int64
#  43  bathrooms                         3571 non-null   float64
#  44  bedrooms                          3575 non-null   float64
#  45  beds                              3576 non-null   float64
#  46  bed_type                          3585 non-null   object
#  47  amenities                         3585 non-null   object
#  48  price                             3585 non-null   object
#  49  weekly_price                      892 non-null    object
#  50  monthly_price                     888 non-null    object
#  51  security_deposit                  1342 non-null   object
#  52  cleaning_fee                      2478 non-null   object
#  53  guests_included                   3585 non-null   int64
#  54  extra_people                      3585 non-null   object
#  55  minimum_nights                    3585 non-null   int64
#  56  maximum_nights                    3585 non-null   int64
#  57  calendar_updated                  3585 non-null   object
#  58  availability_30                   3585 non-null   int64
#  59  availability_60                   3585 non-null   int64
#  60  availability_90                   3585 non-null   int64
#  61  availability_365                  3585 non-null   int64
#  62  number_of_reviews                 3585 non-null   int64
#  63  first_review                      2829 non-null   object
#  64  last_review                       2829 non-null   object
#  65  review_scores_rating              2772 non-null   float64
#  66  review_scores_accuracy            2762 non-null   float64
#  67  review_scores_cleanliness         2767 non-null   float64
#  68  review_scores_checkin             2765 non-null   float64
#  69  review_scores_communication       2767 non-null   float64
#  70  review_scores_location            2763 non-null   float64
#  71  review_scores_value               2764 non-null   float64
#  72  requires_license                  3585 non-null   object
#  73  instant_bookable                  3585 non-null   object
#  74  cancellation_policy               3585 non-null   object
#  75  require_guest_profile_picture     3585 non-null   object
#  76  require_guest_phone_verification  3585 non-null   object
#  77  calculated_host_listings_count    3585 non-null   int64
#  78  reviews_per_month                 2829 non-null   float64
# dtypes: float64(13), int64(14), object(52)
# memory usage: 2.2+ MB

# %% [markdown]
# Removendo mais alguns campos que não são necessários para nossa análise

# %%
listings = listings.drop(columns=['experiences_offered', 'market', 'smart_location', 'calendar_updated', 'requires_license','host_location', 'host_about', 'host_neighbourhood', 'host_total_listings_count','calculated_host_listings_count'])

# %%
listings.head(2)
# Out:
#          id                            listing_url  \
# 0  12147973  https://www.airbnb.com/rooms/12147973
# 1   3075044   https://www.airbnb.com/rooms/3075044
#
#                                 name  \
# 0         Sunny Bungalow in the City
# 1  Charming room in pet friendly apt
#
#                                              summary  \
# 0  Cozy, sunny, family home.  Master bedroom high...
# 1  Charming and quiet room in a second floor 1910...
#
#                                                space  \
# 0  The house has an open and cozy feel at the sam...
# 1  Small but cozy and quite room with a full size...
#
#                                          description  \
# 0  Cozy, sunny, family home.  Master bedroom high...
# 1  Charming and quiet room in a second floor 1910...
#
#                                neighborhood_overview  \
# 0  Roslindale is quiet, convenient and friendly. ...
# 1  The room is in Roslindale, a diverse and prima...
#
#                                                notes  \
# 0                                                NaN
# 1  If you don't have a US cell phone, you can tex...
#
#                                              transit  \
# 0  The bus stop is 2 blocks away, and frequent. B...
# 1  Plenty of safe street parking. Bus stops a few...
#
#                                               access  \
# 0  You will have access to 2 bedrooms, a living r...
# 1  Apt has one more bedroom (which I use) and lar...
#
#                                          interaction  \
# 0                                                NaN
# 1  If I am at home, I am likely working in my hom...
#
#                                          house_rules   host_id  \
# 0  Clean up and treat the home the way you'd like...  31303940
# 1  Pet friendly but please confirm with me if the...   2572247
#
#                                      host_url host_name  host_since  \
# 0  https://www.airbnb.com/users/show/31303940  Virginia  2015-04-15
# 1   https://www.airbnb.com/users/show/2572247    Andrea  2012-06-07
#
#   host_response_time host_response_rate host_acceptance_rate  \
# 0                NaN                NaN                  NaN
# 1     within an hour               100%                 100%
#
#   host_is_superhost  host_listings_count  \
# 0                 f                    1
# 1                 f                    1
#
#                                   host_verifications host_has_profile_pic  \
# 0          ['email', 'phone', 'facebook', 'reviews']                    t
# 1  ['email', 'phone', 'facebook', 'linkedin', 'am...                    t
#
#   host_identity_verified                                             street  \
# 0                      f      Birch Street, Boston, MA 02131, United States
# 1                      t  Pinehurst Street, Boston, MA 02131, United States
#
#   neighbourhood neighbourhood_cleansed    city state zipcode   latitude  \
# 0    Roslindale             Roslindale  Boston    MA   02131  42.282619
# 1    Roslindale             Roslindale  Boston    MA   02131  42.286241
#
#    longitude is_location_exact property_type        room_type  accommodates  \
# 0 -71.133068                 t         House  Entire home/apt             4
# 1 -71.134374                 t     Apartment     Private room             2
#
#    bathrooms  bedrooms  beds  bed_type  \
# 0        1.5       2.0   3.0  Real Bed
# 1        1.0       1.0   1.0  Real Bed
#
#                                            amenities    price weekly_price  \
# 0  {TV,"Wireless Internet",Kitchen,"Free Parking ...  $250.00          NaN
# 1  {TV,Internet,"Wireless Internet","Air Conditio...   $65.00      $400.00
#
#   monthly_price security_deposit cleaning_fee  guests_included extra_people  \
# 0           NaN              NaN       $35.00                1        $0.00
# 1           NaN           $95.00       $10.00                0        $0.00
#
#    minimum_nights  maximum_nights  availability_30  availability_60  \
# 0               2            1125                0                0
# 1               2              15               26               54
#
#    availability_90  availability_365  number_of_reviews first_review  \
# 0                0                 0                  0          NaN
# 1               84               359                 36   2014-06-01
#
#   last_review  review_scores_rating  review_scores_accuracy  \
# 0         NaN                   NaN                     NaN
# 1  2016-08-13                  94.0                    10.0
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                        NaN                    NaN
# 1                        9.0                   10.0
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                          NaN                     NaN                  NaN
# 1                         10.0                     9.0                  9.0
#
#   instant_bookable cancellation_policy require_guest_profile_picture  \
# 0                f            moderate                             f
# 1                t            moderate                             f
#
#   require_guest_phone_verification  reviews_per_month
# 0                                f                NaN
# 1                                f                1.3

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3585 entries, 0 to 3584
# Data columns (total 69 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                3585 non-null   int64
#  1   listing_url                       3585 non-null   object
#  2   name                              3585 non-null   object
#  3   summary                           3442 non-null   object
#  4   space                             2528 non-null   object
#  5   description                       3585 non-null   object
#  6   neighborhood_overview             2170 non-null   object
#  7   notes                             1610 non-null   object
#  8   transit                           2295 non-null   object
#  9   access                            2096 non-null   object
#  10  interaction                       2031 non-null   object
#  11  house_rules                       2393 non-null   object
#  12  host_id                           3585 non-null   int64
#  13  host_url                          3585 non-null   object
#  14  host_name                         3585 non-null   object
#  15  host_since                        3585 non-null   object
#  16  host_response_time                3114 non-null   object
#  17  host_response_rate                3114 non-null   object
#  18  host_acceptance_rate              3114 non-null   object
#  19  host_is_superhost                 3585 non-null   object
#  20  host_listings_count               3585 non-null   int64
#  21  host_verifications                3585 non-null   object
#  22  host_has_profile_pic              3585 non-null   object
#  23  host_identity_verified            3585 non-null   object
#  24  street                            3585 non-null   object
#  25  neighbourhood                     3042 non-null   object
#  26  neighbourhood_cleansed            3585 non-null   object
#  27  city                              3583 non-null   object
#  28  state                             3585 non-null   object
#  29  zipcode                           3547 non-null   object
#  30  latitude                          3585 non-null   float64
#  31  longitude                         3585 non-null   float64
#  32  is_location_exact                 3585 non-null   object
#  33  property_type                     3582 non-null   object
#  34  room_type                         3585 non-null   object
#  35  accommodates                      3585 non-null   int64
#  36  bathrooms                         3571 non-null   float64
#  37  bedrooms                          3575 non-null   float64
#  38  beds                              3576 non-null   float64
#  39  bed_type                          3585 non-null   object
#  40  amenities                         3585 non-null   object
#  41  price                             3585 non-null   object
#  42  weekly_price                      892 non-null    object
#  43  monthly_price                     888 non-null    object
#  44  security_deposit                  1342 non-null   object
#  45  cleaning_fee                      2478 non-null   object
#  46  guests_included                   3585 non-null   int64
#  47  extra_people                      3585 non-null   object
#  48  minimum_nights                    3585 non-null   int64
#  49  maximum_nights                    3585 non-null   int64
#  50  availability_30                   3585 non-null   int64
#  51  availability_60                   3585 non-null   int64
#  52  availability_90                   3585 non-null   int64
#  53  availability_365                  3585 non-null   int64
#  54  number_of_reviews                 3585 non-null   int64
#  55  first_review                      2829 non-null   object
#  56  last_review                       2829 non-null   object
#  57  review_scores_rating              2772 non-null   float64
#  58  review_scores_accuracy            2762 non-null   float64
#  59  review_scores_cleanliness         2767 non-null   float64
#  60  review_scores_checkin             2765 non-null   float64
#  61  review_scores_communication       2767 non-null   float64
#  62  review_scores_location            2763 non-null   float64
#  63  review_scores_value               2764 non-null   float64
#  64  instant_bookable                  3585 non-null   object
#  65  cancellation_policy               3585 non-null   object
#  66  require_guest_profile_picture     3585 non-null   object
#  67  require_guest_phone_verification  3585 non-null   object
#  68  reviews_per_month                 2829 non-null   float64
# dtypes: float64(13), int64(12), object(44)
# memory usage: 1.9+ MB

# %% [markdown]
# Converter tipos de dados para o correto

# %%
#Convertendo as datas que estão como object para datetime
listings[['host_since', 'first_review', 'last_review']] = listings[['host_since','first_review','last_review']].apply(pd.to_datetime)

# %%
#Converter os valores monetários para float64 price, weekly_price, monthly_price, security_deposit, cleaning_fee, extra_people
listings[['price', 'weekly_price', 'monthly_price','security_deposit', 'cleaning_fee','extra_people']] = listings[['price','weekly_price','monthly_price','security_deposit','cleaning_fee','extra_people']].replace('[\$,]', '', regex=True).astype(float)

# %%
#Converter os valores t e f para boolean host_is_superhost, host_has_profile_pic, host_identity_verified, is_location_exact, instant_bookable, require_guest_profile_picture, require_guest_phone_verification
listings[['host_is_superhost','host_has_profile_pic','host_identity_verified','is_location_exact','instant_bookable','require_guest_profile_picture','require_guest_phone_verification']] = listings[['host_is_superhost','host_has_profile_pic','host_identity_verified','is_location_exact','instant_bookable','require_guest_profile_picture','require_guest_phone_verification']].replace({'t': True, 'f': False}).astype(bool)
# Out:
# /var/folders/_5/jv6f9k4n2xq59l09xtzj00fc0000gn/T/ipykernel_36706/562114937.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   listings[['host_is_superhost','host_has_profile_pic','host_identity_verified','is_location_exact','instant_bookable','require_guest_profile_picture','require_guest_phone_verification']] = listings[['host_is_superhost','host_has_profile_pic','host_identity_verified','is_location_exact','instant_bookable','require_guest_profile_picture','require_guest_phone_verification']].replace({'t': True, 'f': False}).astype(bool)

# %%
# Função para remover '%' e converter para float
def percent_to_float(value):
    if isinstance(value, str):  # Verifica se o valor é uma string
        return float(value.rstrip('%')) / 100.0
    return value  # Retorna o valor original se não for uma string

# Aplicar a função na coluna 'host_response_rate' e 'host_acceptance_rate'
listings[['host_response_rate', 'host_acceptance_rate']] = listings[['host_response_rate', 'host_acceptance_rate']].apply(lambda x: x.apply(percent_to_float))

# %%
listings[['host_response_rate', 'host_acceptance_rate']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3585 entries, 0 to 3584
# Data columns (total 2 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   host_response_rate    3114 non-null   float64
#  1   host_acceptance_rate  3114 non-null   float64
# dtypes: float64(2)
# memory usage: 56.1 KB

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3585 entries, 0 to 3584
# Data columns (total 69 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                3585 non-null   int64
#  1   listing_url                       3585 non-null   object
#  2   name                              3585 non-null   object
#  3   summary                           3442 non-null   object
#  4   space                             2528 non-null   object
#  5   description                       3585 non-null   object
#  6   neighborhood_overview             2170 non-null   object
#  7   notes                             1610 non-null   object
#  8   transit                           2295 non-null   object
#  9   access                            2096 non-null   object
#  10  interaction                       2031 non-null   object
#  11  house_rules                       2393 non-null   object
#  12  host_id                           3585 non-null   int64
#  13  host_url                          3585 non-null   object
#  14  host_name                         3585 non-null   object
#  15  host_since                        3585 non-null   datetime64[ns]
#  16  host_response_time                3114 non-null   object
#  17  host_response_rate                3114 non-null   float64
#  18  host_acceptance_rate              3114 non-null   float64
#  19  host_is_superhost                 3585 non-null   bool
#  20  host_listings_count               3585 non-null   int64
#  21  host_verifications                3585 non-null   object
#  22  host_has_profile_pic              3585 non-null   bool
#  23  host_identity_verified            3585 non-null   bool
#  24  street                            3585 non-null   object
#  25  neighbourhood                     3042 non-null   object
#  26  neighbourhood_cleansed            3585 non-null   object
#  27  city                              3583 non-null   object
#  28  state                             3585 non-null   object
#  29  zipcode                           3547 non-null   object
#  30  latitude                          3585 non-null   float64
#  31  longitude                         3585 non-null   float64
#  32  is_location_exact                 3585 non-null   bool
#  33  property_type                     3582 non-null   object
#  34  room_type                         3585 non-null   object
#  35  accommodates                      3585 non-null   int64
#  36  bathrooms                         3571 non-null   float64
#  37  bedrooms                          3575 non-null   float64
#  38  beds                              3576 non-null   float64
#  39  bed_type                          3585 non-null   object
#  40  amenities                         3585 non-null   object
#  41  price                             3585 non-null   float64
#  42  weekly_price                      892 non-null    float64
#  43  monthly_price                     888 non-null    float64
#  44  security_deposit                  1342 non-null   float64
#  45  cleaning_fee                      2478 non-null   float64
#  46  guests_included                   3585 non-null   int64
#  47  extra_people                      3585 non-null   float64
#  48  minimum_nights                    3585 non-null   int64
#  49  maximum_nights                    3585 non-null   int64
#  50  availability_30                   3585 non-null   int64
#  51  availability_60                   3585 non-null   int64
#  52  availability_90                   3585 non-null   int64
#  53  availability_365                  3585 non-null   int64
#  54  number_of_reviews                 3585 non-null   int64
#  55  first_review                      2829 non-null   datetime64[ns]
#  56  last_review                       2829 non-null   datetime64[ns]
#  57  review_scores_rating              2772 non-null   float64
#  58  review_scores_accuracy            2762 non-null   float64
#  59  review_scores_cleanliness         2767 non-null   float64
#  60  review_scores_checkin             2765 non-null   float64
#  61  review_scores_communication       2767 non-null   float64
#  62  review_scores_location            2763 non-null   float64
#  63  review_scores_value               2764 non-null   float64
#  64  instant_bookable                  3585 non-null   bool
#  65  cancellation_policy               3585 non-null   object
#  66  require_guest_profile_picture     3585 non-null   bool
#  67  require_guest_phone_verification  3585 non-null   bool
#  68  reviews_per_month                 2829 non-null   float64
# dtypes: bool(7), datetime64[ns](3), float64(21), int64(12), object(26)
# memory usage: 1.7+ MB

# %%
listings.head(2)
# Out:
#          id                            listing_url  \
# 0  12147973  https://www.airbnb.com/rooms/12147973
# 1   3075044   https://www.airbnb.com/rooms/3075044
#
#                                 name  \
# 0         Sunny Bungalow in the City
# 1  Charming room in pet friendly apt
#
#                                              summary  \
# 0  Cozy, sunny, family home.  Master bedroom high...
# 1  Charming and quiet room in a second floor 1910...
#
#                                                space  \
# 0  The house has an open and cozy feel at the sam...
# 1  Small but cozy and quite room with a full size...
#
#                                          description  \
# 0  Cozy, sunny, family home.  Master bedroom high...
# 1  Charming and quiet room in a second floor 1910...
#
#                                neighborhood_overview  \
# 0  Roslindale is quiet, convenient and friendly. ...
# 1  The room is in Roslindale, a diverse and prima...
#
#                                                notes  \
# 0                                                NaN
# 1  If you don't have a US cell phone, you can tex...
#
#                                              transit  \
# 0  The bus stop is 2 blocks away, and frequent. B...
# 1  Plenty of safe street parking. Bus stops a few...
#
#                                               access  \
# 0  You will have access to 2 bedrooms, a living r...
# 1  Apt has one more bedroom (which I use) and lar...
#
#                                          interaction  \
# 0                                                NaN
# 1  If I am at home, I am likely working in my hom...
#
#                                          house_rules   host_id  \
# 0  Clean up and treat the home the way you'd like...  31303940
# 1  Pet friendly but please confirm with me if the...   2572247
#
#                                      host_url host_name host_since  \
# 0  https://www.airbnb.com/users/show/31303940  Virginia 2015-04-15
# 1   https://www.airbnb.com/users/show/2572247    Andrea 2012-06-07
#
#   host_response_time  host_response_rate  host_acceptance_rate  \
# 0                NaN                 NaN                   NaN
# 1     within an hour                 1.0                   1.0
#
#    host_is_superhost  host_listings_count  \
# 0              False                    1
# 1              False                    1
#
#                                   host_verifications  host_has_profile_pic  \
# 0          ['email', 'phone', 'facebook', 'reviews']                  True
# 1  ['email', 'phone', 'facebook', 'linkedin', 'am...                  True
#
#    host_identity_verified                                             street  \
# 0                   False      Birch Street, Boston, MA 02131, United States
# 1                    True  Pinehurst Street, Boston, MA 02131, United States
#
#   neighbourhood neighbourhood_cleansed    city state zipcode   latitude  \
# 0    Roslindale             Roslindale  Boston    MA   02131  42.282619
# 1    Roslindale             Roslindale  Boston    MA   02131  42.286241
#
#    longitude  is_location_exact property_type        room_type  accommodates  \
# 0 -71.133068               True         House  Entire home/apt             4
# 1 -71.134374               True     Apartment     Private room             2
#
#    bathrooms  bedrooms  beds  bed_type  \
# 0        1.5       2.0   3.0  Real Bed
# 1        1.0       1.0   1.0  Real Bed
#
#                                            amenities  price  weekly_price  \
# 0  {TV,"Wireless Internet",Kitchen,"Free Parking ...  250.0           NaN
# 1  {TV,Internet,"Wireless Internet","Air Conditio...   65.0         400.0
#
#    monthly_price  security_deposit  cleaning_fee  guests_included  \
# 0            NaN               NaN          35.0                1
# 1            NaN              95.0          10.0                0
#
#    extra_people  minimum_nights  maximum_nights  availability_30  \
# 0           0.0               2            1125                0
# 1           0.0               2              15               26
#
#    availability_60  availability_90  availability_365  number_of_reviews  \
# 0                0                0                 0                  0
# 1               54               84               359                 36
#
#   first_review last_review  review_scores_rating  review_scores_accuracy  \
# 0          NaT         NaT                   NaN                     NaN
# 1   2014-06-01  2016-08-13                  94.0                    10.0
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                        NaN                    NaN
# 1                        9.0                   10.0
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                          NaN                     NaN                  NaN
# 1                         10.0                     9.0                  9.0
#
#    instant_bookable cancellation_policy  require_guest_profile_picture  \
# 0             False            moderate                          False
# 1              True            moderate                          False
#
#    require_guest_phone_verification  reviews_per_month
# 0                             False                NaN
# 1                             False                1.3

# %%
(listings['bathrooms'] % 1 != 0).sum()
# Out:
# 311

# %%
(listings['bedrooms'] % 1 != 0).sum()
# Out:
# 10

# %%
(listings['beds'] % 1 != 0).sum()
# Out:
# 9

# %% [markdown]
# Considerando que temos bathrooms, bedrooms e beds com valores quebrados e temos uma quantidade considerada de propriedades com essas informações, vou removê-los da minha análise, pois não faz sentido manter valor quebrado para nossa análise

# %%
listings = listings[(listings['bathrooms'] % 1 == 0) & (listings['bedrooms'] % 1 == 0) & (listings['beds'] % 1 == 0)]
listings[['bathrooms','bedrooms','beds']] = listings[['bathrooms','bedrooms','beds']].astype(int)

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3260 entries, 1 to 3584
# Data columns (total 69 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                3260 non-null   int64
#  1   listing_url                       3260 non-null   object
#  2   name                              3260 non-null   object
#  3   summary                           3149 non-null   object
#  4   space                             2292 non-null   object
#  5   description                       3260 non-null   object
#  6   neighborhood_overview             1985 non-null   object
#  7   notes                             1461 non-null   object
#  8   transit                           2099 non-null   object
#  9   access                            1902 non-null   object
#  10  interaction                       1850 non-null   object
#  11  house_rules                       2158 non-null   object
#  12  host_id                           3260 non-null   int64
#  13  host_url                          3260 non-null   object
#  14  host_name                         3260 non-null   object
#  15  host_since                        3260 non-null   datetime64[ns]
#  16  host_response_time                2831 non-null   object
#  17  host_response_rate                2831 non-null   float64
#  18  host_acceptance_rate              2831 non-null   float64
#  19  host_is_superhost                 3260 non-null   bool
#  20  host_listings_count               3260 non-null   int64
#  21  host_verifications                3260 non-null   object
#  22  host_has_profile_pic              3260 non-null   bool
#  23  host_identity_verified            3260 non-null   bool
#  24  street                            3260 non-null   object
#  25  neighbourhood                     2752 non-null   object
#  26  neighbourhood_cleansed            3260 non-null   object
#  27  city                              3258 non-null   object
#  28  state                             3260 non-null   object
#  29  zipcode                           3227 non-null   object
#  30  latitude                          3260 non-null   float64
#  31  longitude                         3260 non-null   float64
#  32  is_location_exact                 3260 non-null   bool
#  33  property_type                     3257 non-null   object
#  34  room_type                         3260 non-null   object
#  35  accommodates                      3260 non-null   int64
#  36  bathrooms                         3260 non-null   int64
#  37  bedrooms                          3260 non-null   int64
#  38  beds                              3260 non-null   int64
#  39  bed_type                          3260 non-null   object
#  40  amenities                         3260 non-null   object
#  41  price                             3260 non-null   float64
#  42  weekly_price                      799 non-null    float64
#  43  monthly_price                     801 non-null    float64
#  44  security_deposit                  1199 non-null   float64
#  45  cleaning_fee                      2250 non-null   float64
#  46  guests_included                   3260 non-null   int64
#  47  extra_people                      3260 non-null   float64
#  48  minimum_nights                    3260 non-null   int64
#  49  maximum_nights                    3260 non-null   int64
#  50  availability_30                   3260 non-null   int64
#  51  availability_60                   3260 non-null   int64
#  52  availability_90                   3260 non-null   int64
#  53  availability_365                  3260 non-null   int64
#  54  number_of_reviews                 3260 non-null   int64
#  55  first_review                      2555 non-null   datetime64[ns]
#  56  last_review                       2555 non-null   datetime64[ns]
#  57  review_scores_rating              2505 non-null   float64
#  58  review_scores_accuracy            2494 non-null   float64
#  59  review_scores_cleanliness         2499 non-null   float64
#  60  review_scores_checkin             2497 non-null   float64
#  61  review_scores_communication       2499 non-null   float64
#  62  review_scores_location            2495 non-null   float64
#  63  review_scores_value               2496 non-null   float64
#  64  instant_bookable                  3260 non-null   bool
#  65  cancellation_policy               3260 non-null   object
#  66  require_guest_profile_picture     3260 non-null   bool
#  67  require_guest_phone_verification  3260 non-null   bool
#  68  reviews_per_month                 2555 non-null   float64
# dtypes: bool(7), datetime64[ns](3), float64(18), int64(15), object(26)
# memory usage: 1.6+ MB

# %%
listings.shape
# Out:
# (3260, 69)

# %%
listings.head(2)
# Out:
#         id                           listing_url  \
# 1  3075044  https://www.airbnb.com/rooms/3075044
# 2     6976     https://www.airbnb.com/rooms/6976
#
#                                 name  \
# 1  Charming room in pet friendly apt
# 2   Mexican Folk Art Haven in Boston
#
#                                              summary  \
# 1  Charming and quiet room in a second floor 1910...
# 2  Come stay with a friendly, middle-aged guy in ...
#
#                                                space  \
# 1  Small but cozy and quite room with a full size...
# 2  Come stay with a friendly, middle-aged guy in ...
#
#                                          description  \
# 1  Charming and quiet room in a second floor 1910...
# 2  Come stay with a friendly, middle-aged guy in ...
#
#                                neighborhood_overview  \
# 1  The room is in Roslindale, a diverse and prima...
# 2  The LOCATION: Roslindale is a safe and diverse...
#
#                                                notes  \
# 1  If you don't have a US cell phone, you can tex...
# 2  I am in a scenic part of Boston with a couple ...
#
#                                              transit  \
# 1  Plenty of safe street parking. Bus stops a few...
# 2  PUBLIC TRANSPORTATION: From the house, quick p...
#
#                                               access  \
# 1  Apt has one more bedroom (which I use) and lar...
# 2  I am living in the apartment during your stay,...
#
#                                          interaction  \
# 1  If I am at home, I am likely working in my hom...
# 2  ABOUT ME: I'm a laid-back, friendly, unmarried...
#
#                                          house_rules  host_id  \
# 1  Pet friendly but please confirm with me if the...  2572247
# 2  I encourage you to use my kitchen, cooking and...    16701
#
#                                     host_url host_name host_since  \
# 1  https://www.airbnb.com/users/show/2572247    Andrea 2012-06-07
# 2    https://www.airbnb.com/users/show/16701      Phil 2009-05-11
#
#    host_response_time  host_response_rate  host_acceptance_rate  \
# 1      within an hour                 1.0                  1.00
# 2  within a few hours                 1.0                  0.88
#
#    host_is_superhost  host_listings_count  \
# 1              False                    1
# 2               True                    1
#
#                                   host_verifications  host_has_profile_pic  \
# 1  ['email', 'phone', 'facebook', 'linkedin', 'am...                  True
# 2             ['email', 'phone', 'reviews', 'jumio']                  True
#
#    host_identity_verified                                             street  \
# 1                    True  Pinehurst Street, Boston, MA 02131, United States
# 2                    True        Ardale St., Boston, MA 02131, United States
#
#   neighbourhood neighbourhood_cleansed    city state zipcode   latitude  \
# 1    Roslindale             Roslindale  Boston    MA   02131  42.286241
# 2    Roslindale             Roslindale  Boston    MA   02131  42.292438
#
#    longitude  is_location_exact property_type     room_type  accommodates  \
# 1 -71.134374               True     Apartment  Private room             2
# 2 -71.135765               True     Apartment  Private room             2
#
#    bathrooms  bedrooms  beds  bed_type  \
# 1          1         1     1  Real Bed
# 2          1         1     1  Real Bed
#
#                                            amenities  price  weekly_price  \
# 1  {TV,Internet,"Wireless Internet","Air Conditio...   65.0         400.0
# 2  {TV,"Cable TV","Wireless Internet","Air Condit...   65.0         395.0
#
#    monthly_price  security_deposit  cleaning_fee  guests_included  \
# 1            NaN              95.0          10.0                0
# 2         1350.0               NaN           NaN                1
#
#    extra_people  minimum_nights  maximum_nights  availability_30  \
# 1           0.0               2              15               26
# 2          20.0               3              45               19
#
#    availability_60  availability_90  availability_365  number_of_reviews  \
# 1               54               84               359                 36
# 2               46               61               319                 41
#
#   first_review last_review  review_scores_rating  review_scores_accuracy  \
# 1   2014-06-01  2016-08-13                  94.0                    10.0
# 2   2009-07-19  2016-08-05                  98.0                    10.0
#
#    review_scores_cleanliness  review_scores_checkin  \
# 1                        9.0                   10.0
# 2                        9.0                   10.0
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 1                         10.0                     9.0                  9.0
# 2                         10.0                     9.0                 10.0
#
#    instant_bookable cancellation_policy  require_guest_profile_picture  \
# 1              True            moderate                          False
# 2             False            moderate                           True
#
#    require_guest_phone_verification  reviews_per_month
# 1                             False               1.30
# 2                             False               0.47

# %% [markdown]
# Descobrindo quais os tipos de propriedades

# %%
listings['property_type'].unique()
# Out:
# array(['Apartment', 'House', 'Condominium', 'Bed & Breakfast',
#        'Townhouse', 'Entire Floor', 'Loft', 'Guesthouse', 'Boat', 'Dorm',
#        'Other', nan, 'Camper/RV', 'Villa'], dtype=object)

# %% [markdown]
# Excluir as propriedades que não é de nosso interesse para a análise

# %%
valores_para_deletar = ['Villa', 'Bed & Breakfast', 'Guesthouse', 'Boat', 'Dorm', 'Other', 'Camper/RV']
listings = listings.query('property_type not in @valores_para_deletar')

# %%
listings['property_type'].count()
# Out:
# 3187

# %%
listings['property_type'].unique()
# Out:
# array(['Apartment', 'House', 'Condominium', 'Townhouse', 'Entire Floor',
#        'Loft', nan], dtype=object)

# %%
listings[listings['property_type'].isnull()]
# Out:
#             id                            listing_url  \
# 1321   7731797   https://www.airbnb.com/rooms/7731797
# 2061  14122467  https://www.airbnb.com/rooms/14122467
# 3393     10758     https://www.airbnb.com/rooms/10758
#
#                                                    name  \
# 1321                 Classy Studio in Historic Back Bay
# 2061  Hotel room in Downtown Boston - amazing location!
# 3393                         Budget Single - share bath
#
#                                                 summary  \
# 1321  This polished studio in the heart of Boston’s ...
# 2061  This is a room in a 4-star hotel located in Do...
# 3393  Our least expensive room - this room has one s...
#
#                                                   space  \
# 1321  When you walk through the front door of this F...
# 2061                                                NaN
# 3393   THE FARRINGTON -The Boston Hotel Alternative ...
#
#                                             description  \
# 1321  This polished studio in the heart of Boston’s ...
# 2061  This is a room in a 4-star hotel located in Do...
# 3393  Our least expensive room - this room has one s...
#
#                                   neighborhood_overview  \
# 1321  Right downstairs you’ll find Newbury Street bu...
# 2061                                                NaN
# 3393  We are in the student section of Boston - draw...
#
#                                                   notes  \
# 1321  • Please be aware that this is a 4th floor wal...
# 2061                                                NaN
# 3393                                                NaN
#
#                                                 transit  \
# 1321  Parking can be difficult in this area. If you’...
# 2061                                                NaN
# 3393  Transportation is EXCELLENT !! We're right off...
#
#                                                  access  \
# 1321                                                NaN
# 2061                                                NaN
# 3393  The guest will have access to our building, co...
#
#                                             interaction  \
# 1321  Need more towels? A restaurant recommendation?...
# 2061                                                NaN
# 3393  We have someone here to assist you just a phon...
#
#                                             house_rules   host_id  \
# 1321  House Rules 1. Check-in is 4 pm local time. If...  12243051
# 2061  - Handicap Accessible - Additional information...  32088178
# 3393  Please note that we are a no smoking environme...     38440
#
#                                         host_url           host_name  \
# 1321  https://www.airbnb.com/users/show/12243051            Flatbook
# 2061  https://www.airbnb.com/users/show/32088178           Christine
# 3393     https://www.airbnb.com/users/show/38440  The Farrington Inn
#
#      host_since  host_response_time  host_response_rate  host_acceptance_rate  \
# 1321 2014-02-14  within a few hours                0.71                  0.98
# 2061 2015-04-27                 NaN                 NaN                   NaN
# 3393 2009-09-14        within a day                1.00                  0.42
#
#       host_is_superhost  host_listings_count  \
# 1321              False                  363
# 2061              False                    1
# 3393              False                    4
#
#                                      host_verifications  host_has_profile_pic  \
# 1321  ['email', 'phone', 'reviews', 'manual_offline'...                  True
# 2061             ['email', 'phone', 'reviews', 'jumio']                  True
# 3393                      ['email', 'phone', 'reviews']                  True
#
#       host_identity_verified  \
# 1321                    True
# 2061                    True
# 3393                   False
#
#                                                  street      neighbourhood  \
# 1321    Newbury Street, Boston, MA 02116, United States           Back Bay
# 2061  Devonshire Street, Boston, MA 02110, United St...  Downtown Crossing
# 3393    Farrington Ave, Boston, MA 02134, United States   Allston-Brighton
#
#      neighbourhood_cleansed    city state zipcode   latitude  longitude  \
# 1321               Back Bay  Boston    MA   02116  42.349350 -71.082488
# 2061               Downtown  Boston    MA   02110  42.355444 -71.057985
# 3393                Allston  Boston    MA   02134  42.353449 -71.131797
#
#       is_location_exact property_type        room_type  accommodates  \
# 1321               True           NaN  Entire home/apt             2
# 2061               True           NaN  Entire home/apt             2
# 3393               True           NaN     Private room             1
#
#       bathrooms  bedrooms  beds  bed_type  \
# 1321          1         0     1  Real Bed
# 2061          1         1     1  Real Bed
# 3393          1         1     1  Real Bed
#
#                                               amenities  price  weekly_price  \
# 1321  {TV,"Cable TV",Internet,"Wireless Internet","A...  199.0           NaN
# 2061  {TV,"Wireless Internet","Air Conditioning","Wh...  190.0           NaN
# 3393  {TV,"Cable TV",Internet,"Wireless Internet","A...  115.0           NaN
#
#       monthly_price  security_deposit  cleaning_fee  guests_included  \
# 1321            NaN             300.0          75.0                2
# 2061            NaN               NaN           NaN                1
# 3393            NaN               NaN           NaN                1
#
#       extra_people  minimum_nights  maximum_nights  availability_30  \
# 1321          10.0               3            1125               16
# 2061           0.0               2               3                0
# 3393           0.0               1              90                3
#
#       availability_60  availability_90  availability_365  number_of_reviews  \
# 1321               32               59               105                 26
# 2061                0                0                 0                  0
# 3393               13               43                43                  2
#
#      first_review last_review  review_scores_rating  review_scores_accuracy  \
# 1321   2015-09-13  2016-08-21                  85.0                     9.0
# 2061          NaT         NaT                   NaN                     NaN
# 3393   2014-10-22  2015-10-03                  60.0                     6.0
#
#       review_scores_cleanliness  review_scores_checkin  \
# 1321                        9.0                    9.0
# 2061                        NaN                    NaN
# 3393                        5.0                    8.0
#
#       review_scores_communication  review_scores_location  \
# 1321                          9.0                    10.0
# 2061                          NaN                     NaN
# 3393                          8.0                     8.0
#
#       review_scores_value  instant_bookable cancellation_policy  \
# 1321                  9.0              True              strict
# 2061                  NaN             False              strict
# 3393                  7.0             False            moderate
#
#       require_guest_profile_picture  require_guest_phone_verification  \
# 1321                          False                             False
# 2061                          False                             False
# 3393                          False                             False
#
#       reviews_per_month
# 1321               2.16
# 2061                NaN
# 3393               0.09

# %% [markdown]
# Analisando os valores de property_type null decidi deletá-los

# %%
listings = listings.dropna(subset=['property_type'])

# %%
listings.shape
# Out:
# (3187, 69)

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3187 entries, 1 to 3584
# Data columns (total 69 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                3187 non-null   int64
#  1   listing_url                       3187 non-null   object
#  2   name                              3187 non-null   object
#  3   summary                           3081 non-null   object
#  4   space                             2232 non-null   object
#  5   description                       3187 non-null   object
#  6   neighborhood_overview             1936 non-null   object
#  7   notes                             1425 non-null   object
#  8   transit                           2048 non-null   object
#  9   access                            1855 non-null   object
#  10  interaction                       1801 non-null   object
#  11  house_rules                       2108 non-null   object
#  12  host_id                           3187 non-null   int64
#  13  host_url                          3187 non-null   object
#  14  host_name                         3187 non-null   object
#  15  host_since                        3187 non-null   datetime64[ns]
#  16  host_response_time                2771 non-null   object
#  17  host_response_rate                2771 non-null   float64
#  18  host_acceptance_rate              2771 non-null   float64
#  19  host_is_superhost                 3187 non-null   bool
#  20  host_listings_count               3187 non-null   int64
#  21  host_verifications                3187 non-null   object
#  22  host_has_profile_pic              3187 non-null   bool
#  23  host_identity_verified            3187 non-null   bool
#  24  street                            3187 non-null   object
#  25  neighbourhood                     2687 non-null   object
#  26  neighbourhood_cleansed            3187 non-null   object
#  27  city                              3185 non-null   object
#  28  state                             3187 non-null   object
#  29  zipcode                           3156 non-null   object
#  30  latitude                          3187 non-null   float64
#  31  longitude                         3187 non-null   float64
#  32  is_location_exact                 3187 non-null   bool
#  33  property_type                     3187 non-null   object
#  34  room_type                         3187 non-null   object
#  35  accommodates                      3187 non-null   int64
#  36  bathrooms                         3187 non-null   int64
#  37  bedrooms                          3187 non-null   int64
#  38  beds                              3187 non-null   int64
#  39  bed_type                          3187 non-null   object
#  40  amenities                         3187 non-null   object
#  41  price                             3187 non-null   float64
#  42  weekly_price                      782 non-null    float64
#  43  monthly_price                     791 non-null    float64
#  44  security_deposit                  1182 non-null   float64
#  45  cleaning_fee                      2219 non-null   float64
#  46  guests_included                   3187 non-null   int64
#  47  extra_people                      3187 non-null   float64
#  48  minimum_nights                    3187 non-null   int64
#  49  maximum_nights                    3187 non-null   int64
#  50  availability_30                   3187 non-null   int64
#  51  availability_60                   3187 non-null   int64
#  52  availability_90                   3187 non-null   int64
#  53  availability_365                  3187 non-null   int64
#  54  number_of_reviews                 3187 non-null   int64
#  55  first_review                      2506 non-null   datetime64[ns]
#  56  last_review                       2506 non-null   datetime64[ns]
#  57  review_scores_rating              2457 non-null   float64
#  58  review_scores_accuracy            2447 non-null   float64
#  59  review_scores_cleanliness         2452 non-null   float64
#  60  review_scores_checkin             2450 non-null   float64
#  61  review_scores_communication       2452 non-null   float64
#  62  review_scores_location            2448 non-null   float64
#  63  review_scores_value               2449 non-null   float64
#  64  instant_bookable                  3187 non-null   bool
#  65  cancellation_policy               3187 non-null   object
#  66  require_guest_profile_picture     3187 non-null   bool
#  67  require_guest_phone_verification  3187 non-null   bool
#  68  reviews_per_month                 2506 non-null   float64
# dtypes: bool(7), datetime64[ns](3), float64(18), int64(15), object(26)
# memory usage: 1.6+ MB

# %%
listings.describe().round(2)
# Out:
#                 id      host_id                     host_since  \
# count      3187.00      3187.00                           3187
# mean    8584401.15  25271740.62  2014-04-16 06:05:04.989017856
# min        3353.00      4240.00            2008-11-11 00:00:00
# 25%     4977750.50   6608084.00            2013-05-27 00:00:00
# 50%     8761060.00  19806255.00            2014-08-14 00:00:00
# 75%    12819845.00  36607627.00            2015-06-26 12:00:00
# max    14933461.00  93854106.00            2016-09-06 00:00:00
# std     4418734.91  22819204.17                            NaN
#
#        host_response_rate  host_acceptance_rate  host_listings_count  \
# count             2771.00               2771.00              3187.00
# mean                 0.95                  0.84                61.61
# min                  0.00                  0.00                 0.00
# 25%                  0.97                  0.72                 1.00
# 50%                  1.00                  0.94                 2.00
# 75%                  1.00                  1.00                 7.00
# max                  1.00                  1.00               749.00
# std                  0.13                  0.21               175.66
#
#        latitude  longitude  accommodates  bathrooms  bedrooms     beds  \
# count   3187.00    3187.00       3187.00    3187.00   3187.00  3187.00
# mean      42.34     -71.08          2.99       1.16      1.22     1.57
# min       42.24     -71.17          1.00       0.00      0.00     0.00
# 25%       42.33     -71.10          2.00       1.00      1.00     1.00
# 50%       42.35     -71.08          2.00       1.00      1.00     1.00
# 75%       42.35     -71.06          4.00       1.00      1.00     2.00
# max       42.39     -71.00         16.00       5.00      5.00    16.00
# std        0.02       0.03          1.67       0.40      0.72     0.95
#
#          price  weekly_price  monthly_price  security_deposit  cleaning_fee  \
# count  3187.00        782.00         791.00           1182.00       2219.00
# mean    171.53        888.23        3595.08            318.10         67.82
# min      10.00         80.00         500.00             95.00          5.00
# 25%      89.00        475.00        1615.00            100.00         28.00
# 50%     150.00        745.00        2900.00            250.00         50.00
# 75%     216.00       1150.00        5000.00            400.00        100.00
# max    4000.00       5000.00       14000.00           4500.00        300.00
# std     145.66        597.52        2529.04            331.54         49.98
#
#        guests_included  extra_people  minimum_nights  maximum_nights  \
# count          3187.00       3187.00         3187.00         3187.00
# mean              1.42         10.72            3.05        32212.11
# min               0.00          0.00            1.00            1.00
# 25%               1.00          0.00            1.00          365.00
# 50%               1.00          0.00            2.00         1125.00
# 75%               2.00         20.00            3.00         1125.00
# max              14.00        200.00          200.00     99999999.00
# std               1.03         19.11            6.01      1771353.97
#
#        availability_30  availability_60  availability_90  availability_365  \
# count          3187.00          3187.00          3187.00           3187.00
# mean              8.50            21.48            38.08            175.34
# min               0.00             0.00             0.00              0.00
# 25%               0.00             0.00             0.00             17.00
# 50%               4.00            15.00            36.00            174.00
# 75%              15.00            40.00            68.00            322.00
# max              30.00            60.00            90.00            365.00
# std              10.39            21.81            33.12            141.54
#
#        number_of_reviews                   first_review  \
# count            3187.00                           2506
# mean               18.70  2015-07-13 02:15:02.154828288
# min                 0.00            2009-03-21 00:00:00
# 25%                 1.00            2015-02-23 00:00:00
# 50%                 5.00            2015-10-16 12:00:00
# 75%                20.00            2016-05-22 00:00:00
# max               404.00            2016-09-06 00:00:00
# std                35.09                            NaN
#
#                          last_review  review_scores_rating  \
# count                           2506               2457.00
# mean   2016-06-13 13:14:07.565841920                 91.91
# min              2010-10-16 00:00:00                 20.00
# 25%              2016-06-19 00:00:00                 89.00
# 50%              2016-08-14 00:00:00                 94.00
# 75%              2016-08-28 00:00:00                 98.00
# max              2016-09-06 00:00:00                100.00
# std                              NaN                  9.40
#
#        review_scores_accuracy  review_scores_cleanliness  \
# count                 2447.00                    2452.00
# mean                     9.44                       9.26
# min                      2.00                       2.00
# 25%                      9.00                       9.00
# 50%                     10.00                      10.00
# 75%                     10.00                      10.00
# max                     10.00                      10.00
# std                      0.92                       1.15
#
#        review_scores_checkin  review_scores_communication  \
# count                2450.00                      2452.00
# mean                    9.65                         9.65
# min                     2.00                         4.00
# 25%                     9.00                         9.00
# 50%                    10.00                        10.00
# 75%                    10.00                        10.00
# max                    10.00                        10.00
# std                     0.76                         0.74
#
#        review_scores_location  review_scores_value  reviews_per_month
# count                 2448.00              2449.00            2506.00
# mean                     9.44                 9.17               2.02
# min                      2.00                 2.00               0.01
# 25%                      9.00                 9.00               0.49
# 50%                     10.00                 9.00               1.25
# 75%                     10.00                10.00               2.81
# max                     10.00                10.00              19.15
# std                      0.89                 1.01               2.16

# %%
listings['room_type'].unique()
# Out:
# array(['Private room', 'Entire home/apt', 'Shared room'], dtype=object)

# %% [markdown]
# Vamos deletar os registros que são Private room e Shared room porque não nos interessa para a nossa análise, visto que o nosso foco é casa/apartamento inteiro

# %%
valores_para_deletar = ['Private room', 'Shared room']
listings = listings.query('room_type not in @valores_para_deletar')

# %%
listings.shape
# Out:
# (1957, 69)

# %%
listings.corr(numeric_only = True).round(4)
# Out:
#                                       id  host_id  host_response_rate  \
# id                                1.0000   0.5169             -0.0415
# host_id                           0.5169   1.0000              0.0391
# host_response_rate               -0.0415   0.0391              1.0000
# host_acceptance_rate              0.1203   0.1122              0.0018
# host_is_superhost                -0.1021  -0.0556              0.1203
# host_listings_count              -0.0206  -0.0814             -0.0659
# host_has_profile_pic             -0.0305  -0.0944             -0.0143
# host_identity_verified           -0.1185  -0.2946              0.0546
# latitude                          0.0668   0.0118              0.0348
# longitude                         0.0390  -0.0140              0.0662
# is_location_exact                -0.1983  -0.1557              0.0151
# accommodates                      0.0351  -0.0398              0.0171
# bathrooms                         0.0294  -0.0378             -0.0155
# bedrooms                         -0.0169  -0.0562             -0.0242
# beds                              0.0097  -0.0342              0.0201
# price                            -0.0201   0.0333              0.0203
# weekly_price                     -0.0164  -0.0190              0.0278
# monthly_price                     0.0895   0.0626              0.0339
# security_deposit                 -0.1350  -0.0658             -0.0624
# cleaning_fee                     -0.2160  -0.1943             -0.0053
# guests_included                  -0.0537  -0.0399              0.0821
# extra_people                     -0.0336  -0.0245              0.0792
# minimum_nights                   -0.0984  -0.0706             -0.0302
# maximum_nights                   -0.0272  -0.0207              0.0106
# availability_30                  -0.0360  -0.0330             -0.0473
# availability_60                  -0.0200  -0.0286             -0.0273
# availability_90                  -0.0352  -0.0335             -0.0004
# availability_365                 -0.2085  -0.1440              0.0731
# number_of_reviews                -0.4015  -0.2084              0.1251
# review_scores_rating              0.0445   0.0645              0.0356
# review_scores_accuracy            0.0559   0.0634              0.0302
# review_scores_cleanliness         0.0592   0.0530              0.0142
# review_scores_checkin             0.0320   0.0710              0.0780
# review_scores_communication       0.0437   0.0672              0.0754
# review_scores_location            0.0063   0.0376              0.0176
# review_scores_value               0.0862   0.0810              0.0185
# instant_bookable                  0.1513   0.0730             -0.0766
# require_guest_profile_picture    -0.1645  -0.1193              0.0424
# require_guest_phone_verification -0.3325  -0.2619             -0.0265
# reviews_per_month                 0.2489   0.1983              0.1364
#
#                                   host_acceptance_rate  host_is_superhost  \
# id                                              0.1203            -0.1021
# host_id                                         0.1122            -0.0556
# host_response_rate                              0.0018             0.1203
# host_acceptance_rate                            1.0000             0.1532
# host_is_superhost                               0.1532             1.0000
# host_listings_count                            -0.4720            -0.1411
# host_has_profile_pic                           -0.0449             0.0195
# host_identity_verified                         -0.1279             0.0730
# latitude                                       -0.0723            -0.0223
# longitude                                      -0.0347             0.0054
# is_location_exact                              -0.0567             0.0296
# accommodates                                   -0.0093             0.0734
# bathrooms                                      -0.1731             0.0066
# bedrooms                                       -0.0488             0.0618
# beds                                            0.0528             0.0613
# price                                          -0.0944             0.0407
# weekly_price                                   -0.0229             0.0245
# monthly_price                                  -0.4094            -0.0845
# security_deposit                               -0.0118             0.0330
# cleaning_fee                                   -0.1446            -0.0289
# guests_included                                 0.1471             0.1423
# extra_people                                    0.1044             0.1203
# minimum_nights                                 -0.0260            -0.0323
# maximum_nights                                  0.0200            -0.0074
# availability_30                                -0.4062            -0.1042
# availability_60                                -0.3659            -0.0919
# availability_90                                -0.3198            -0.0507
# availability_365                               -0.1279             0.0757
# number_of_reviews                               0.2223             0.2291
# review_scores_rating                            0.0560             0.1973
# review_scores_accuracy                          0.1120             0.1985
# review_scores_cleanliness                       0.0298             0.1882
# review_scores_checkin                           0.0950             0.1454
# review_scores_communication                     0.1326             0.1506
# review_scores_location                         -0.0346             0.0823
# review_scores_value                             0.1336             0.1934
# instant_bookable                                0.3423             0.0935
# require_guest_profile_picture                   0.0483             0.0605
# require_guest_phone_verification               -0.2278            -0.0250
# reviews_per_month                               0.3697             0.2099
#
#                                   host_listings_count  host_has_profile_pic  \
# id                                            -0.0206               -0.0305
# host_id                                       -0.0814               -0.0944
# host_response_rate                            -0.0659               -0.0143
# host_acceptance_rate                          -0.4720               -0.0449
# host_is_superhost                             -0.1411                0.0195
# host_listings_count                            1.0000                0.0267
# host_has_profile_pic                           0.0267                1.0000
# host_identity_verified                         0.2549                0.0822
# latitude                                       0.0850               -0.0039
# longitude                                     -0.0057               -0.0180
# is_location_exact                              0.1479               -0.0215
# accommodates                                   0.0701                0.0193
# bathrooms                                      0.2919                0.0084
# bedrooms                                       0.1085                0.0145
# beds                                          -0.0398                0.0064
# price                                          0.0849                0.0244
# weekly_price                                   0.2680               -0.0370
# monthly_price                                  0.6497               -0.0098
# security_deposit                               0.0248               -0.0288
# cleaning_fee                                   0.2649                0.0251
# guests_included                               -0.1909                0.0166
# extra_people                                  -0.2105               -0.0557
# minimum_nights                                 0.0966               -0.0043
# maximum_nights                                -0.0088                0.0014
# availability_30                                0.6093                0.0019
# availability_60                                0.5544                0.0015
# availability_90                                0.4971                0.0143
# availability_365                               0.0712                0.0294
# number_of_reviews                             -0.1841                0.0150
# review_scores_rating                          -0.1859               -0.0431
# review_scores_accuracy                        -0.2377               -0.0275
# review_scores_cleanliness                     -0.0726               -0.0398
# review_scores_checkin                         -0.2779               -0.0032
# review_scores_communication                   -0.2987               -0.0022
# review_scores_location                        -0.0685               -0.0212
# review_scores_value                           -0.2692               -0.0435
# instant_bookable                              -0.0504               -0.0223
# require_guest_profile_picture                 -0.0540               -0.0635
# require_guest_phone_verification               0.3184               -0.0141
# reviews_per_month                             -0.2515                0.0027
#
#                                   host_identity_verified  latitude  longitude  \
# id                                               -0.1185    0.0668     0.0390
# host_id                                          -0.2946    0.0118    -0.0140
# host_response_rate                                0.0546    0.0348     0.0662
# host_acceptance_rate                             -0.1279   -0.0723    -0.0347
# host_is_superhost                                 0.0730   -0.0223     0.0054
# host_listings_count                               0.2549    0.0850    -0.0057
# host_has_profile_pic                              0.0822   -0.0039    -0.0180
# host_identity_verified                            1.0000   -0.0068     0.0096
# latitude                                         -0.0068    1.0000     0.3962
# longitude                                         0.0096    0.3962     1.0000
# is_location_exact                                 0.0425    0.0177    -0.0307
# accommodates                                      0.0652   -0.1328    -0.0306
# bathrooms                                         0.0716    0.0221     0.0533
# bedrooms                                          0.0560   -0.1583    -0.0257
# beds                                              0.0260   -0.1419    -0.0483
# price                                            -0.0096    0.0817     0.0982
# weekly_price                                     -0.0802    0.0917     0.1429
# monthly_price                                     0.2186    0.1317     0.0396
# security_deposit                                  0.0181    0.0227    -0.0390
# cleaning_fee                                      0.1194    0.0584     0.0430
# guests_included                                   0.0371   -0.1264    -0.0325
# extra_people                                     -0.0117   -0.0456     0.0042
# minimum_nights                                    0.0178    0.0632     0.0124
# maximum_nights                                    0.0133    0.0240     0.0196
# availability_30                                   0.1624    0.0365    -0.0110
# availability_60                                   0.1685    0.0376     0.0095
# availability_90                                   0.1788    0.0341     0.0205
# availability_365                                  0.0882   -0.0048     0.0186
# number_of_reviews                                 0.0891    0.0218     0.0524
# review_scores_rating                              0.0346   -0.0022     0.0565
# review_scores_accuracy                            0.0373   -0.0443    -0.0065
# review_scores_cleanliness                         0.0365   -0.0141     0.0504
# review_scores_checkin                            -0.0110   -0.0421     0.0387
# review_scores_communication                      -0.0098   -0.0345     0.0352
# review_scores_location                           -0.0528    0.1809     0.0340
# review_scores_value                              -0.0195   -0.0128     0.0282
# instant_bookable                                  0.0545    0.0565    -0.0042
# require_guest_profile_picture                     0.0432   -0.0391    -0.0136
# require_guest_phone_verification                  0.1381    0.0158     0.0040
# reviews_per_month                                 0.0037    0.0717     0.1048
#
#                                   is_location_exact  accommodates  bathrooms  \
# id                                          -0.1983        0.0351     0.0294
# host_id                                     -0.1557       -0.0398    -0.0378
# host_response_rate                           0.0151        0.0171    -0.0155
# host_acceptance_rate                        -0.0567       -0.0093    -0.1731
# host_is_superhost                            0.0296        0.0734     0.0066
# host_listings_count                          0.1479        0.0701     0.2919
# host_has_profile_pic                        -0.0215        0.0193     0.0084
# host_identity_verified                       0.0425        0.0652     0.0716
# latitude                                     0.0177       -0.1328     0.0221
# longitude                                   -0.0307       -0.0306     0.0533
# is_location_exact                            1.0000       -0.0084     0.0680
# accommodates                                -0.0084        1.0000     0.4502
# bathrooms                                    0.0680        0.4502     1.0000
# bedrooms                                     0.0324        0.7477     0.5346
# beds                                         0.0104        0.7994     0.4139
# price                                        0.0122        0.2594     0.2973
# weekly_price                                 0.0699        0.4585     0.5141
# monthly_price                                0.1308        0.3479     0.5544
# security_deposit                             0.1391        0.0285     0.0804
# cleaning_fee                                 0.1700        0.1587     0.2529
# guests_included                             -0.0372        0.4382     0.0995
# extra_people                                -0.0657        0.1684    -0.0548
# minimum_nights                               0.0762       -0.0716     0.0347
# maximum_nights                               0.0081       -0.0224    -0.0105
# availability_30                              0.0470        0.1635     0.2195
# availability_60                              0.0388        0.1535     0.1914
# availability_90                              0.0295        0.1438     0.1619
# availability_365                            -0.0184        0.1068     0.0208
# number_of_reviews                            0.0527        0.0022    -0.0897
# review_scores_rating                        -0.0105       -0.0231     0.0128
# review_scores_accuracy                      -0.0229       -0.0147    -0.0327
# review_scores_cleanliness                    0.0018        0.0048     0.0358
# review_scores_checkin                       -0.0242       -0.0091    -0.0592
# review_scores_communication                 -0.0301       -0.0098    -0.0544
# review_scores_location                      -0.0194       -0.1688    -0.0409
# review_scores_value                         -0.0521       -0.0332    -0.0098
# instant_bookable                             0.0043        0.0927    -0.0090
# require_guest_profile_picture                0.0440       -0.0050    -0.0379
# require_guest_phone_verification             0.1052       -0.0045     0.0840
# reviews_per_month                           -0.1232        0.0812    -0.0765
#
#                                   bedrooms    beds   price  weekly_price  \
# id                                 -0.0169  0.0097 -0.0201       -0.0164
# host_id                            -0.0562 -0.0342  0.0333       -0.0190
# host_response_rate                 -0.0242  0.0201  0.0203        0.0278
# host_acceptance_rate               -0.0488  0.0528 -0.0944       -0.0229
# host_is_superhost                   0.0618  0.0613  0.0407        0.0245
# host_listings_count                 0.1085 -0.0398  0.0849        0.2680
# host_has_profile_pic                0.0145  0.0064  0.0244       -0.0370
# host_identity_verified              0.0560  0.0260 -0.0096       -0.0802
# latitude                           -0.1583 -0.1419  0.0817        0.0917
# longitude                          -0.0257 -0.0483  0.0982        0.1429
# is_location_exact                   0.0324  0.0104  0.0122        0.0699
# accommodates                        0.7477  0.7994  0.2594        0.4585
# bathrooms                           0.5346  0.4139  0.2973        0.5141
# bedrooms                            1.0000  0.6949  0.2899        0.4926
# beds                                0.6949  1.0000  0.2338        0.4512
# price                               0.2899  0.2338  1.0000        0.8723
# weekly_price                        0.4926  0.4512  0.8723        1.0000
# monthly_price                       0.3894  0.3038  0.7122        0.8516
# security_deposit                    0.0965  0.0779  0.1832        0.1598
# cleaning_fee                        0.1610  0.1702  0.2389        0.2943
# guests_included                     0.3591  0.4353  0.1215        0.1949
# extra_people                        0.1036  0.1839  0.0576        0.1024
# minimum_nights                     -0.0223 -0.0448  0.0572        0.1878
# maximum_nights                     -0.0091 -0.0174 -0.0139       -0.0280
# availability_30                     0.1417  0.0871  0.1662        0.4240
# availability_60                     0.1196  0.0755  0.1579        0.4087
# availability_90                     0.0945  0.0698  0.1436        0.3670
# availability_365                    0.0370  0.0623  0.0837        0.1492
# number_of_reviews                  -0.0354  0.0025 -0.0857       -0.0999
# review_scores_rating                0.0392  0.0047  0.0936        0.0820
# review_scores_accuracy              0.0158 -0.0009  0.0260        0.0769
# review_scores_cleanliness           0.0458  0.0165  0.0830        0.0318
# review_scores_checkin               0.0054  0.0086 -0.0083       -0.0063
# review_scores_communication         0.0081  0.0175  0.0036       -0.0087
# review_scores_location             -0.1673 -0.1364  0.0518       -0.0228
# review_scores_value                 0.0133 -0.0101 -0.0017       -0.0327
# instant_bookable                    0.0725  0.0949 -0.0251       -0.0112
# require_guest_profile_picture      -0.0018 -0.0120 -0.0073       -0.0119
# require_guest_phone_verification    0.0564  0.0412  0.1292        0.1587
# reviews_per_month                  -0.0165  0.0617 -0.1484       -0.1087
#
#                                   monthly_price  security_deposit  \
# id                                       0.0895           -0.1350
# host_id                                  0.0626           -0.0658
# host_response_rate                       0.0339           -0.0624
# host_acceptance_rate                    -0.4094           -0.0118
# host_is_superhost                       -0.0845            0.0330
# host_listings_count                      0.6497            0.0248
# host_has_profile_pic                    -0.0098           -0.0288
# host_identity_verified                   0.2186            0.0181
# latitude                                 0.1317            0.0227
# longitude                                0.0396           -0.0390
# is_location_exact                        0.1308            0.1391
# accommodates                             0.3479            0.0285
# bathrooms                                0.5544            0.0804
# bedrooms                                 0.3894            0.0965
# beds                                     0.3038            0.0779
# price                                    0.7122            0.1832
# weekly_price                             0.8516            0.1598
# monthly_price                            1.0000            0.0289
# security_deposit                         0.0289            1.0000
# cleaning_fee                             0.2468            0.4405
# guests_included                         -0.0595           -0.0155
# extra_people                            -0.1154           -0.0146
# minimum_nights                           0.0557            0.2248
# maximum_nights                          -0.0362           -0.0690
# availability_30                          0.6000            0.0351
# availability_60                          0.5924            0.0382
# availability_90                          0.5469            0.0226
# availability_365                         0.0516            0.0222
# number_of_reviews                       -0.2180           -0.1125
# review_scores_rating                    -0.1251            0.0572
# review_scores_accuracy                  -0.1205            0.0395
# review_scores_cleanliness               -0.0055            0.0209
# review_scores_checkin                   -0.1605            0.0096
# review_scores_communication             -0.2740            0.0037
# review_scores_location                  -0.0339            0.0163
# review_scores_value                     -0.2134            0.0017
# instant_bookable                        -0.0961           -0.0502
# require_guest_profile_picture           -0.0763           -0.0215
# require_guest_phone_verification         0.3865           -0.0136
# reviews_per_month                       -0.2200           -0.2073
#
#                                   cleaning_fee  guests_included  extra_people  \
# id                                     -0.2160          -0.0537       -0.0336
# host_id                                -0.1943          -0.0399       -0.0245
# host_response_rate                     -0.0053           0.0821        0.0792
# host_acceptance_rate                   -0.1446           0.1471        0.1044
# host_is_superhost                      -0.0289           0.1423        0.1203
# host_listings_count                     0.2649          -0.1909       -0.2105
# host_has_profile_pic                    0.0251           0.0166       -0.0557
# host_identity_verified                  0.1194           0.0371       -0.0117
# latitude                                0.0584          -0.1264       -0.0456
# longitude                               0.0430          -0.0325        0.0042
# is_location_exact                       0.1700          -0.0372       -0.0657
# accommodates                            0.1587           0.4382        0.1684
# bathrooms                               0.2529           0.0995       -0.0548
# bedrooms                                0.1610           0.3591        0.1036
# beds                                    0.1702           0.4353        0.1839
# price                                   0.2389           0.1215        0.0576
# weekly_price                            0.2943           0.1949        0.1024
# monthly_price                           0.2468          -0.0595       -0.1154
# security_deposit                        0.4405          -0.0155       -0.0146
# cleaning_fee                            1.0000           0.0162       -0.0560
# guests_included                         0.0162           1.0000        0.4932
# extra_people                           -0.0560           0.4932        1.0000
# minimum_nights                          0.2251          -0.0560       -0.0440
# maximum_nights                         -0.0203          -0.0116       -0.0119
# availability_30                         0.2496          -0.0243       -0.0306
# availability_60                         0.2773          -0.0013       -0.0068
# availability_90                         0.3049           0.0311        0.0129
# availability_365                        0.3247           0.1089        0.0572
# number_of_reviews                      -0.1506           0.0890        0.0942
# review_scores_rating                   -0.0333           0.0391        0.0391
# review_scores_accuracy                 -0.0726           0.0746        0.0673
# review_scores_cleanliness               0.0574           0.0077        0.0438
# review_scores_checkin                  -0.1265           0.0322        0.0461
# review_scores_communication            -0.1637           0.0993        0.1003
# review_scores_location                  0.0032          -0.0560       -0.0404
# review_scores_value                    -0.1051           0.0178        0.0200
# instant_bookable                       -0.0504           0.0776        0.0066
# require_guest_profile_picture          -0.0572           0.0727        0.1179
# require_guest_phone_verification        0.2033          -0.0473       -0.0428
# reviews_per_month                      -0.2745           0.0945        0.0814
#
#                                   minimum_nights  maximum_nights  \
# id                                       -0.0984         -0.0272
# host_id                                  -0.0706         -0.0207
# host_response_rate                       -0.0302          0.0106
# host_acceptance_rate                     -0.0260          0.0200
# host_is_superhost                        -0.0323         -0.0074
# host_listings_count                       0.0966         -0.0088
# host_has_profile_pic                     -0.0043          0.0014
# host_identity_verified                    0.0178          0.0133
# latitude                                  0.0632          0.0240
# longitude                                 0.0124          0.0196
# is_location_exact                         0.0762          0.0081
# accommodates                             -0.0716         -0.0224
# bathrooms                                 0.0347         -0.0105
# bedrooms                                 -0.0223         -0.0091
# beds                                     -0.0448         -0.0174
# price                                     0.0572         -0.0139
# weekly_price                              0.1878         -0.0280
# monthly_price                             0.0557         -0.0362
# security_deposit                          0.2248         -0.0690
# cleaning_fee                              0.2251         -0.0203
# guests_included                          -0.0560         -0.0116
# extra_people                             -0.0440         -0.0119
# minimum_nights                            1.0000         -0.0080
# maximum_nights                           -0.0080          1.0000
# availability_30                           0.1195         -0.0129
# availability_60                           0.1118         -0.0125
# availability_90                           0.1034         -0.0027
# availability_365                          0.0717          0.0223
# number_of_reviews                        -0.0909          0.1053
# review_scores_rating                     -0.0185         -0.0007
# review_scores_accuracy                   -0.0427         -0.0130
# review_scores_cleanliness                -0.0035         -0.0096
# review_scores_checkin                    -0.0853          0.0122
# review_scores_communication              -0.0375          0.0123
# review_scores_location                    0.0403          0.0143
# review_scores_value                      -0.0197         -0.0043
# instant_bookable                         -0.0629          0.0533
# require_guest_profile_picture            -0.0126         -0.0028
# require_guest_phone_verification          0.0783         -0.0066
# reviews_per_month                        -0.1906          0.0578
#
#                                   availability_30  availability_60  \
# id                                        -0.0360          -0.0200
# host_id                                   -0.0330          -0.0286
# host_response_rate                        -0.0473          -0.0273
# host_acceptance_rate                      -0.4062          -0.3659
# host_is_superhost                         -0.1042          -0.0919
# host_listings_count                        0.6093           0.5544
# host_has_profile_pic                       0.0019           0.0015
# host_identity_verified                     0.1624           0.1685
# latitude                                   0.0365           0.0376
# longitude                                 -0.0110           0.0095
# is_location_exact                          0.0470           0.0388
# accommodates                               0.1635           0.1535
# bathrooms                                  0.2195           0.1914
# bedrooms                                   0.1417           0.1196
# beds                                       0.0871           0.0755
# price                                      0.1662           0.1579
# weekly_price                               0.4240           0.4087
# monthly_price                              0.6000           0.5924
# security_deposit                           0.0351           0.0382
# cleaning_fee                               0.2496           0.2773
# guests_included                           -0.0243          -0.0013
# extra_people                              -0.0306          -0.0068
# minimum_nights                             0.1195           0.1118
# maximum_nights                            -0.0129          -0.0125
# availability_30                            1.0000           0.9518
# availability_60                            0.9518           1.0000
# availability_90                            0.8844           0.9658
# availability_365                           0.4122           0.4975
# number_of_reviews                         -0.1231          -0.0993
# review_scores_rating                      -0.1774          -0.1731
# review_scores_accuracy                    -0.2126          -0.2087
# review_scores_cleanliness                 -0.0687          -0.0554
# review_scores_checkin                     -0.2092          -0.1973
# review_scores_communication               -0.2091          -0.2097
# review_scores_location                    -0.1059          -0.0969
# review_scores_value                       -0.2652          -0.2609
# instant_bookable                          -0.1213          -0.1161
# require_guest_profile_picture             -0.0010           0.0002
# require_guest_phone_verification           0.3013           0.2759
# reviews_per_month                         -0.1822          -0.1357
#
#                                   availability_90  availability_365  \
# id                                        -0.0352           -0.2085
# host_id                                   -0.0335           -0.1440
# host_response_rate                        -0.0004            0.0731
# host_acceptance_rate                      -0.3198           -0.1279
# host_is_superhost                         -0.0507            0.0757
# host_listings_count                        0.4971            0.0712
# host_has_profile_pic                       0.0143            0.0294
# host_identity_verified                     0.1788            0.0882
# latitude                                   0.0341           -0.0048
# longitude                                  0.0205            0.0186
# is_location_exact                          0.0295           -0.0184
# accommodates                               0.1438            0.1068
# bathrooms                                  0.1619            0.0208
# bedrooms                                   0.0945            0.0370
# beds                                       0.0698            0.0623
# price                                      0.1436            0.0837
# weekly_price                               0.3670            0.1492
# monthly_price                              0.5469            0.0516
# security_deposit                           0.0226            0.0222
# cleaning_fee                               0.3049            0.3247
# guests_included                            0.0311            0.1089
# extra_people                               0.0129            0.0572
# minimum_nights                             0.1034            0.0717
# maximum_nights                            -0.0027            0.0223
# availability_30                            0.8844            0.4122
# availability_60                            0.9658            0.4975
# availability_90                            1.0000            0.5890
# availability_365                           0.5890            1.0000
# number_of_reviews                         -0.0310            0.1849
# review_scores_rating                      -0.1631           -0.0796
# review_scores_accuracy                    -0.1940           -0.0980
# review_scores_cleanliness                 -0.0323           -0.0205
# review_scores_checkin                     -0.1757           -0.0715
# review_scores_communication               -0.1959           -0.1126
# review_scores_location                    -0.0956           -0.0108
# review_scores_value                       -0.2490           -0.1204
# instant_bookable                          -0.0930           -0.0355
# require_guest_profile_picture              0.0085            0.0391
# require_guest_phone_verification           0.2495            0.1333
# reviews_per_month                         -0.0496            0.0695
#
#                                   number_of_reviews  review_scores_rating  \
# id                                          -0.4015                0.0445
# host_id                                     -0.2084                0.0645
# host_response_rate                           0.1251                0.0356
# host_acceptance_rate                         0.2223                0.0560
# host_is_superhost                            0.2291                0.1973
# host_listings_count                         -0.1841               -0.1859
# host_has_profile_pic                         0.0150               -0.0431
# host_identity_verified                       0.0891                0.0346
# latitude                                     0.0218               -0.0022
# longitude                                    0.0524                0.0565
# is_location_exact                            0.0527               -0.0105
# accommodates                                 0.0022               -0.0231
# bathrooms                                   -0.0897                0.0128
# bedrooms                                    -0.0354                0.0392
# beds                                         0.0025                0.0047
# price                                       -0.0857                0.0936
# weekly_price                                -0.0999                0.0820
# monthly_price                               -0.2180               -0.1251
# security_deposit                            -0.1125                0.0572
# cleaning_fee                                -0.1506               -0.0333
# guests_included                              0.0890                0.0391
# extra_people                                 0.0942                0.0391
# minimum_nights                              -0.0909               -0.0185
# maximum_nights                               0.1053               -0.0007
# availability_30                             -0.1231               -0.1774
# availability_60                             -0.0993               -0.1731
# availability_90                             -0.0310               -0.1631
# availability_365                             0.1849               -0.0796
# number_of_reviews                            1.0000               -0.0301
# review_scores_rating                        -0.0301                1.0000
# review_scores_accuracy                      -0.0037                0.6775
# review_scores_cleanliness                   -0.0454                0.6918
# review_scores_checkin                        0.0508                0.5859
# review_scores_communication                  0.0590                0.5973
# review_scores_location                      -0.0076                0.3607
# review_scores_value                         -0.0082                0.7535
# instant_bookable                             0.2032               -0.0147
# require_guest_profile_picture                0.2013                0.0289
# require_guest_phone_verification             0.0064               -0.0760
# reviews_per_month                            0.5243                0.0439
#
#                                   review_scores_accuracy  \
# id                                                0.0559
# host_id                                           0.0634
# host_response_rate                                0.0302
# host_acceptance_rate                              0.1120
# host_is_superhost                                 0.1985
# host_listings_count                              -0.2377
# host_has_profile_pic                             -0.0275
# host_identity_verified                            0.0373
# latitude                                         -0.0443
# longitude                                        -0.0065
# is_location_exact                                -0.0229
# accommodates                                     -0.0147
# bathrooms                                        -0.0327
# bedrooms                                          0.0158
# beds                                             -0.0009
# price                                             0.0260
# weekly_price                                      0.0769
# monthly_price                                    -0.1205
# security_deposit                                  0.0395
# cleaning_fee                                     -0.0726
# guests_included                                   0.0746
# extra_people                                      0.0673
# minimum_nights                                   -0.0427
# maximum_nights                                   -0.0130
# availability_30                                  -0.2126
# availability_60                                  -0.2087
# availability_90                                  -0.1940
# availability_365                                 -0.0980
# number_of_reviews                                -0.0037
# review_scores_rating                              0.6775
# review_scores_accuracy                            1.0000
# review_scores_cleanliness                         0.6029
# review_scores_checkin                             0.4478
# review_scores_communication                       0.4755
# review_scores_location                            0.2228
# review_scores_value                               0.6137
# instant_bookable                                  0.0119
# require_guest_profile_picture                     0.0191
# require_guest_phone_verification                 -0.1494
# reviews_per_month                                 0.0833
#
#                                   review_scores_cleanliness  \
# id                                                   0.0592
# host_id                                              0.0530
# host_response_rate                                   0.0142
# host_acceptance_rate                                 0.0298
# host_is_superhost                                    0.1882
# host_listings_count                                 -0.0726
# host_has_profile_pic                                -0.0398
# host_identity_verified                               0.0365
# latitude                                            -0.0141
# longitude                                            0.0504
# is_location_exact                                    0.0018
# accommodates                                         0.0048
# bathrooms                                            0.0358
# bedrooms                                             0.0458
# beds                                                 0.0165
# price                                                0.0830
# weekly_price                                         0.0318
# monthly_price                                       -0.0055
# security_deposit                                     0.0209
# cleaning_fee                                         0.0574
# guests_included                                      0.0077
# extra_people                                         0.0438
# minimum_nights                                      -0.0035
# maximum_nights                                      -0.0096
# availability_30                                     -0.0687
# availability_60                                     -0.0554
# availability_90                                     -0.0323
# availability_365                                    -0.0205
# number_of_reviews                                   -0.0454
# review_scores_rating                                 0.6918
# review_scores_accuracy                               0.6029
# review_scores_cleanliness                            1.0000
# review_scores_checkin                                0.4169
# review_scores_communication                          0.3502
# review_scores_location                               0.2343
# review_scores_value                                  0.5893
# instant_bookable                                    -0.0115
# require_guest_profile_picture                        0.0028
# require_guest_phone_verification                    -0.0359
# reviews_per_month                                    0.0627
#
#                                   review_scores_checkin  \
# id                                               0.0320
# host_id                                          0.0710
# host_response_rate                               0.0780
# host_acceptance_rate                             0.0950
# host_is_superhost                                0.1454
# host_listings_count                             -0.2779
# host_has_profile_pic                            -0.0032
# host_identity_verified                          -0.0110
# latitude                                        -0.0421
# longitude                                        0.0387
# is_location_exact                               -0.0242
# accommodates                                    -0.0091
# bathrooms                                       -0.0592
# bedrooms                                         0.0054
# beds                                             0.0086
# price                                           -0.0083
# weekly_price                                    -0.0063
# monthly_price                                   -0.1605
# security_deposit                                 0.0096
# cleaning_fee                                    -0.1265
# guests_included                                  0.0322
# extra_people                                     0.0461
# minimum_nights                                  -0.0853
# maximum_nights                                   0.0122
# availability_30                                 -0.2092
# availability_60                                 -0.1973
# availability_90                                 -0.1757
# availability_365                                -0.0715
# number_of_reviews                                0.0508
# review_scores_rating                             0.5859
# review_scores_accuracy                           0.4478
# review_scores_cleanliness                        0.4169
# review_scores_checkin                            1.0000
# review_scores_communication                      0.6788
# review_scores_location                           0.2722
# review_scores_value                              0.4780
# instant_bookable                                -0.0174
# require_guest_profile_picture                    0.0278
# require_guest_phone_verification                -0.1259
# reviews_per_month                                0.1171
#
#                                   review_scores_communication  \
# id                                                     0.0437
# host_id                                                0.0672
# host_response_rate                                     0.0754
# host_acceptance_rate                                   0.1326
# host_is_superhost                                      0.1506
# host_listings_count                                   -0.2987
# host_has_profile_pic                                  -0.0022
# host_identity_verified                                -0.0098
# latitude                                              -0.0345
# longitude                                              0.0352
# is_location_exact                                     -0.0301
# accommodates                                          -0.0098
# bathrooms                                             -0.0544
# bedrooms                                               0.0081
# beds                                                   0.0175
# price                                                  0.0036
# weekly_price                                          -0.0087
# monthly_price                                         -0.2740
# security_deposit                                       0.0037
# cleaning_fee                                          -0.1637
# guests_included                                        0.0993
# extra_people                                           0.1003
# minimum_nights                                        -0.0375
# maximum_nights                                         0.0123
# availability_30                                       -0.2091
# availability_60                                       -0.2097
# availability_90                                       -0.1959
# availability_365                                      -0.1126
# number_of_reviews                                      0.0590
# review_scores_rating                                   0.5973
# review_scores_accuracy                                 0.4755
# review_scores_cleanliness                              0.3502
# review_scores_checkin                                  0.6788
# review_scores_communication                            1.0000
# review_scores_location                                 0.2338
# review_scores_value                                    0.4844
# instant_bookable                                      -0.0066
# require_guest_profile_picture                          0.0460
# require_guest_phone_verification                      -0.1338
# reviews_per_month                                      0.1274
#
#                                   review_scores_location  review_scores_value  \
# id                                                0.0063               0.0862
# host_id                                           0.0376               0.0810
# host_response_rate                                0.0176               0.0185
# host_acceptance_rate                             -0.0346               0.1336
# host_is_superhost                                 0.0823               0.1934
# host_listings_count                              -0.0685              -0.2692
# host_has_profile_pic                             -0.0212              -0.0435
# host_identity_verified                           -0.0528              -0.0195
# latitude                                          0.1809              -0.0128
# longitude                                         0.0340               0.0282
# is_location_exact                                -0.0194              -0.0521
# accommodates                                     -0.1688              -0.0332
# bathrooms                                        -0.0409              -0.0098
# bedrooms                                         -0.1673               0.0133
# beds                                             -0.1364              -0.0101
# price                                             0.0518              -0.0017
# weekly_price                                     -0.0228              -0.0327
# monthly_price                                    -0.0339              -0.2134
# security_deposit                                  0.0163               0.0017
# cleaning_fee                                      0.0032              -0.1051
# guests_included                                  -0.0560               0.0178
# extra_people                                     -0.0404               0.0200
# minimum_nights                                    0.0403              -0.0197
# maximum_nights                                    0.0143              -0.0043
# availability_30                                  -0.1059              -0.2652
# availability_60                                  -0.0969              -0.2609
# availability_90                                  -0.0956              -0.2490
# availability_365                                 -0.0108              -0.1204
# number_of_reviews                                -0.0076              -0.0082
# review_scores_rating                              0.3607               0.7535
# review_scores_accuracy                            0.2228               0.6137
# review_scores_cleanliness                         0.2343               0.5893
# review_scores_checkin                             0.2722               0.4780
# review_scores_communication                       0.2338               0.4844
# review_scores_location                            1.0000               0.4075
# review_scores_value                               0.4075               1.0000
# instant_bookable                                 -0.0460               0.0138
# require_guest_profile_picture                    -0.0013               0.0123
# require_guest_phone_verification                 -0.0051              -0.1511
# reviews_per_month                                 0.0096               0.0967
#
#                                   instant_bookable  \
# id                                          0.1513
# host_id                                     0.0730
# host_response_rate                         -0.0766
# host_acceptance_rate                        0.3423
# host_is_superhost                           0.0935
# host_listings_count                        -0.0504
# host_has_profile_pic                       -0.0223
# host_identity_verified                      0.0545
# latitude                                    0.0565
# longitude                                  -0.0042
# is_location_exact                           0.0043
# accommodates                                0.0927
# bathrooms                                  -0.0090
# bedrooms                                    0.0725
# beds                                        0.0949
# price                                      -0.0251
# weekly_price                               -0.0112
# monthly_price                              -0.0961
# security_deposit                           -0.0502
# cleaning_fee                               -0.0504
# guests_included                             0.0776
# extra_people                                0.0066
# minimum_nights                             -0.0629
# maximum_nights                              0.0533
# availability_30                            -0.1213
# availability_60                            -0.1161
# availability_90                            -0.0930
# availability_365                           -0.0355
# number_of_reviews                           0.2032
# review_scores_rating                       -0.0147
# review_scores_accuracy                      0.0119
# review_scores_cleanliness                  -0.0115
# review_scores_checkin                      -0.0174
# review_scores_communication                -0.0066
# review_scores_location                     -0.0460
# review_scores_value                         0.0138
# instant_bookable                            1.0000
# require_guest_profile_picture              -0.0167
# require_guest_phone_verification           -0.1138
# reviews_per_month                           0.3245
#
#                                   require_guest_profile_picture  \
# id                                                      -0.1645
# host_id                                                 -0.1193
# host_response_rate                                       0.0424
# host_acceptance_rate                                     0.0483
# host_is_superhost                                        0.0605
# host_listings_count                                     -0.0540
# host_has_profile_pic                                    -0.0635
# host_identity_verified                                   0.0432
# latitude                                                -0.0391
# longitude                                               -0.0136
# is_location_exact                                        0.0440
# accommodates                                            -0.0050
# bathrooms                                               -0.0379
# bedrooms                                                -0.0018
# beds                                                    -0.0120
# price                                                   -0.0073
# weekly_price                                            -0.0119
# monthly_price                                           -0.0763
# security_deposit                                        -0.0215
# cleaning_fee                                            -0.0572
# guests_included                                          0.0727
# extra_people                                             0.1179
# minimum_nights                                          -0.0126
# maximum_nights                                          -0.0028
# availability_30                                         -0.0010
# availability_60                                          0.0002
# availability_90                                          0.0085
# availability_365                                         0.0391
# number_of_reviews                                        0.2013
# review_scores_rating                                     0.0289
# review_scores_accuracy                                   0.0191
# review_scores_cleanliness                                0.0028
# review_scores_checkin                                    0.0278
# review_scores_communication                              0.0460
# review_scores_location                                  -0.0013
# review_scores_value                                      0.0123
# instant_bookable                                        -0.0167
# require_guest_profile_picture                            1.0000
# require_guest_phone_verification                         0.3712
# reviews_per_month                                       -0.0125
#
#                                   require_guest_phone_verification  \
# id                                                         -0.3325
# host_id                                                    -0.2619
# host_response_rate                                         -0.0265
# host_acceptance_rate                                       -0.2278
# host_is_superhost                                          -0.0250
# host_listings_count                                         0.3184
# host_has_profile_pic                                       -0.0141
# host_identity_verified                                      0.1381
# latitude                                                    0.0158
# longitude                                                   0.0040
# is_location_exact                                           0.1052
# accommodates                                               -0.0045
# bathrooms                                                   0.0840
# bedrooms                                                    0.0564
# beds                                                        0.0412
# price                                                       0.1292
# weekly_price                                                0.1587
# monthly_price                                               0.3865
# security_deposit                                           -0.0136
# cleaning_fee                                                0.2033
# guests_included                                            -0.0473
# extra_people                                               -0.0428
# minimum_nights                                              0.0783
# maximum_nights                                             -0.0066
# availability_30                                             0.3013
# availability_60                                             0.2759
# availability_90                                             0.2495
# availability_365                                            0.1333
# number_of_reviews                                           0.0064
# review_scores_rating                                       -0.0760
# review_scores_accuracy                                     -0.1494
# review_scores_cleanliness                                  -0.0359
# review_scores_checkin                                      -0.1259
# review_scores_communication                                -0.1338
# review_scores_location                                     -0.0051
# review_scores_value                                        -0.1511
# instant_bookable                                           -0.1138
# require_guest_profile_picture                               0.3712
# require_guest_phone_verification                            1.0000
# reviews_per_month                                          -0.1995
#
#                                   reviews_per_month
# id                                           0.2489
# host_id                                      0.1983
# host_response_rate                           0.1364
# host_acceptance_rate                         0.3697
# host_is_superhost                            0.2099
# host_listings_count                         -0.2515
# host_has_profile_pic                         0.0027
# host_identity_verified                       0.0037
# latitude                                     0.0717
# longitude                                    0.1048
# is_location_exact                           -0.1232
# accommodates                                 0.0812
# bathrooms                                   -0.0765
# bedrooms                                    -0.0165
# beds                                         0.0617
# price                                       -0.1484
# weekly_price                                -0.1087
# monthly_price                               -0.2200
# security_deposit                            -0.2073
# cleaning_fee                                -0.2745
# guests_included                              0.0945
# extra_people                                 0.0814
# minimum_nights                              -0.1906
# maximum_nights                               0.0578
# availability_30                             -0.1822
# availability_60                             -0.1357
# availability_90                             -0.0496
# availability_365                             0.0695
# number_of_reviews                            0.5243
# review_scores_rating                         0.0439
# review_scores_accuracy                       0.0833
# review_scores_cleanliness                    0.0627
# review_scores_checkin                        0.1171
# review_scores_communication                  0.1274
# review_scores_location                       0.0096
# review_scores_value                          0.0967
# instant_bookable                             0.3245
# require_guest_profile_picture               -0.0125
# require_guest_phone_verification            -0.1995
# reviews_per_month                            1.0000

# %%
# Criar uma tabela de referência com zipcodes e neighbourhoods fictícios
zipcode_to_neighbourhood = {
    'zipcode': ['02108', '02109', '02110', '02111', '02113', '02114', '02115', '02116', '02118', '02119', '02120', '02121', '02122', '02124', '02125', '02126', '02127', '02128', '02129', '02130', '02131', '02132', '02134', '02135', '02136', '02138', '02139', '02140', '02141', '02142', '02143', '02144', '02145'],
    'neighbourhood': ['Beacon Hill', 'North End', 'Waterfront', 'Chinatown', 'North End', 'West End', 'Fenway', 'Back Bay', 'South End', 'Roxbury', 'Mission Hill', 'Dorchester', 'Dorchester', 'Dorchester', 'Dorchester', 'Mattapan', 'South Boston', 'East Boston', 'Charlestown', 'Jamaica Plain', 'Roslindale', 'West Roxbury', 'Allston', 'Brighton', 'Hyde Park', 'Cambridge', 'Cambridge', 'Cambridge', 'Cambridge', 'Cambridge', 'Somerville', 'Somerville', 'Somerville']
}

# Converter para DataFrame
reference_data = pd.DataFrame(zipcode_to_neighbourhood) 

# Exibir a tabela de referência
print(reference_data)
# Out:
#    zipcode  neighbourhood
# 0    02108    Beacon Hill
# 1    02109      North End
# 2    02110     Waterfront
# 3    02111      Chinatown
# 4    02113      North End
# 5    02114       West End
# 6    02115         Fenway
# 7    02116       Back Bay
# 8    02118      South End
# 9    02119        Roxbury
# 10   02120   Mission Hill
# 11   02121     Dorchester
# 12   02122     Dorchester
# 13   02124     Dorchester
# 14   02125     Dorchester
# 15   02126       Mattapan
# 16   02127   South Boston
# 17   02128    East Boston
# 18   02129    Charlestown
# 19   02130  Jamaica Plain
# 20   02131     Roslindale
# 21   02132   West Roxbury
# 22   02134        Allston
# 23   02135       Brighton
# 24   02136      Hyde Park
# 25   02138      Cambridge
# 26   02139      Cambridge
# 27   02140      Cambridge
# 28   02141      Cambridge
# 29   02142      Cambridge
# 30   02143     Somerville
# 31   02144     Somerville
# 32   02145     Somerville

# %%
# Supondo que seu DataFrame se chame listings
# Criar um dicionário de mapeamento do zipcode para o neighbourhood
zipcode_to_neighbourhood = listings.dropna(subset=['neighbourhood']).groupby('zipcode')['neighbourhood'].first().to_dict()

# Preencher valores ausentes em 'neighbourhood' usando o mapeamento
listings['neighbourhood_updated'] = listings['neighbourhood'].fillna(listings['zipcode'].map(zipcode_to_neighbourhood))

# Verificar o DataFrame resultante
print(listings[['zipcode','neighbourhood','neighbourhood_cleansed','neighbourhood_updated']])
# Out:
#      zipcode   neighbourhood neighbourhood_cleansed neighbourhood_updated
# 6      02131             NaN             Roslindale            Roslindale
# 9      02131      Roslindale             Roslindale            Roslindale
# 12     02131      Roslindale             Roslindale            Roslindale
# 13     02131      Roslindale             Roslindale            Roslindale
# 21     02131      Roslindale             Roslindale            Roslindale
# ...      ...             ...                    ...                   ...
# 3565   02138             NaN                Allston             Cambridge
# 3567   02138  Harvard Square                Allston        Harvard Square
# 3569   02145             NaN            Charlestown            Somerville
# 3572   02138  Harvard Square                Allston        Harvard Square
# 3582   02141             NaN            Charlestown             Cambridge
#
# [1957 rows x 4 columns]

# %%
print(listings[listings['neighbourhood'].isna()][['zipcode','neighbourhood','neighbourhood_cleansed','neighbourhood_updated']])
# Out:
#      zipcode neighbourhood neighbourhood_cleansed neighbourhood_updated
# 6      02131           NaN             Roslindale            Roslindale
# 23     02131           NaN             Roslindale            Roslindale
# 94       NaN           NaN          Jamaica Plain                   NaN
# 188    02130           NaN          Jamaica Plain         Jamaica Plain
# 216    02120           NaN          Jamaica Plain          Mission Hill
# ...      ...           ...                    ...                   ...
# 3539   02446           NaN  Longwood Medical Area        Fenway/Kenmore
# 3558   02139           NaN                Allston             Cambridge
# 3565   02138           NaN                Allston             Cambridge
# 3569   02145           NaN            Charlestown            Somerville
# 3582   02141           NaN            Charlestown             Cambridge
#
# [250 rows x 4 columns]

# %%
# Criar um mapeamento dos valores de 'neighbourhood_updated' para 'neighbourhood_cleansed'
mapping = listings.dropna(subset=['neighbourhood_updated'])[['neighbourhood_cleansed', 'neighbourhood_updated']].drop_duplicates()
mapping_dict = mapping.set_index('neighbourhood_cleansed')['neighbourhood_updated'].to_dict()

# Preencher 'neighbourhood_updated' onde ela é NaN e 'zipcode' e 'neighbourhood' são NaN, usando o mapeamento criado
listings.loc[listings['neighbourhood_updated'].isna() & listings['zipcode'].isna(), 'neighbourhood_updated'] = listings.loc[listings['neighbourhood_updated'].isna() & listings['zipcode'].isna(), 'neighbourhood_cleansed'].map(mapping_dict)

# Exibir o DataFrame atualizado
listings[listings['neighbourhood'].isna() & listings['zipcode'].isna()][['zipcode','neighbourhood','neighbourhood_cleansed','neighbourhood_updated']]
# Out:
#      zipcode neighbourhood   neighbourhood_cleansed neighbourhood_updated
# 94       NaN           NaN            Jamaica Plain            Roslindale
# 1385     NaN           NaN                 Back Bay               Roxbury
# 1473     NaN           NaN                 Back Bay               Roxbury
# 1631     NaN           NaN              East Boston           East Boston
# 1662     NaN           NaN              East Boston           East Boston
# 2151     NaN           NaN                 Downtown    Financial District
# 2298     NaN           NaN                   Fenway          Mission Hill
# 2550     NaN           NaN                 Brighton      Allston-Brighton
# 2932     NaN           NaN               Dorchester              Mattapan
# 3058     NaN           NaN  South Boston Waterfront          South Boston
# 3117     NaN           NaN  South Boston Waterfront          South Boston
# 3477     NaN           NaN                  Allston        Harvard Square

# %%
listings
# Out:
#             id                            listing_url  \
# 6      5706985   https://www.airbnb.com/rooms/5706985
# 9       849408    https://www.airbnb.com/rooms/849408
# 12     2684840   https://www.airbnb.com/rooms/2684840
# 13    13547301  https://www.airbnb.com/rooms/13547301
# 21    13251243  https://www.airbnb.com/rooms/13251243
# ...        ...                                    ...
# 3565  14335003  https://www.airbnb.com/rooms/14335003
# 3567  14472678  https://www.airbnb.com/rooms/14472678
# 3569  14426586  https://www.airbnb.com/rooms/14426586
# 3572  14744740  https://www.airbnb.com/rooms/14744740
# 3582  14585486  https://www.airbnb.com/rooms/14585486
#
#                                       name  \
# 6      New Lrg Studio apt 15 min to Boston
# 9        Perfect & Practical Boston Rental
# 12      Updated, spacious living in Rozzie
# 13           2 Bedroom Apartment in Boston
# 21                 Arborside Guest Cottage
# ...                                    ...
# 3565  On Charles River near Harvard Square
# 3567                 Cool 5BR in Cambridge
# 3569           Condo for 4 close to Boston
# 3572          NEW - Sunny 5BR in Cambridge
# 3582              Gorgeous funky apartment
#
#                                                 summary  \
# 6     It's a 5 minute walk to Rosi Square to catch t...
# 9     This is a cozy and spacious two bedroom unit w...
# 12    Clean, sunny 2 bedroom in amazing Roslindale V...
# 13    My place is close to Public Transportation. Th...
# 21    Lovely sun-filled private guest cottage set on...
# ...                                                 ...
# 3565  My place is a block from the Charles River, a ...
# 3567  3 reasons why you should stay at this Flatbook...
# 3569  1 private BR w/ full size bed and bath + a que...
# 3572  This sunny Cambridge apartment boasts expansiv...
# 3582  Funky little apartment close to public transpo...
#
#                                                   space  \
# 6     The whole house was recently redone and it 's ...
# 9     Perfect apartment rental for those in town vis...
# 12                                                  NaN
# 13                                                  NaN
# 21    Today the cottage could be called a "tiny hous...
# ...                                                 ...
# 3565                                                NaN
# 3567  3 reasons why you should stay at this Flatbook...
# 3569                                                NaN
# 3572  When you walk through the front door of this F...
# 3582  Modern and relaxed space with many facilities ...
#
#                                             description  \
# 6     It's a 5 minute walk to Rosi Square to catch t...
# 9     This is a cozy and spacious two bedroom unit w...
# 12    Clean, sunny 2 bedroom in amazing Roslindale V...
# 13    My place is close to Public Transportation. Th...
# 21    Lovely sun-filled private guest cottage set on...
# ...                                                 ...
# 3565  My place is a block from the Charles River, a ...
# 3567  3 reasons why you should stay at this Flatbook...
# 3569  1 private BR w/ full size bed and bath + a que...
# 3572  This sunny Cambridge apartment boasts expansiv...
# 3582  Funky little apartment close to public transpo...
#
#                                   neighborhood_overview  \
# 6     Roslindale is the new hip area of Boston. Clos...
# 9     This neighborhood truly has it all.  Good, not...
# 12                                                  NaN
# 13                                                  NaN
# 21    This Boston location is true gem - just a few ...
# ...                                                 ...
# 3565                                                NaN
# 3567  Cambridge has a distinct vibe all its own; bot...
# 3569                                                NaN
# 3572  Cambridge has a distinct vibe all its own; bot...
# 3582  Cambridge is a short walk into Boston, and set...
#
#                                                   notes  \
# 6     Information about the house, wifi pasword and ...
# 9     Please note that this is a second floor apartm...
# 12                                                  NaN
# 13                                                  NaN
# 21    Enclosed bike storage is available. Let us kno...
# ...                                                 ...
# 3565                                                NaN
# 3567                                                NaN
# 3569                                                NaN
# 3572                                                NaN
# 3582  Depending on when you arrive, I can be here to...
#
#                                                 transit  \
# 6     The commuter rail (Needham Line) is a 5 minute...
# 9     Plenty of on street parking with no restrictio...
# 12                                                  NaN
# 13                                                  NaN
# 21    Steps to the bus stops for Forest Hills (Jamai...
# ...                                                 ...
# 3565                                                NaN
# 3567  While Cambridge is great to travel by foot alo...
# 3569  Easy walk to T (.4 miles to Sullivan Station- ...
# 3572  While Cambridge is great to travel by foot alo...
# 3582  Public transport is 5 minuts away, but walking...
#
#                                                  access  \
# 6     I have an electronic keypad so arrival time ca...
# 9                                                   NaN
# 12                                                  NaN
# 13                                                  NaN
# 21    Unload your luggage from the driveway and find...
# ...                                                 ...
# 3565                                                NaN
# 3567                                                NaN
# 3569  Kitchen/ Living Room/ Balcony/ Grill.. As long...
# 3572                                                NaN
# 3582  The whole place including social areas is your...
#
#                                             interaction  \
# 6     I can interact or not- that is up to you. This...
# 9     I'm available for questions anytime before or ...
# 12                                                  NaN
# 13                                                  NaN
# 21    You can be completely independent in this trul...
# ...                                                 ...
# 3565                                                NaN
# 3567  Need more towels? A restaurant recommendation?...
# 3569                                                NaN
# 3572  Need more towels? A restaurant recommendation?...
# 3582                                                NaN
#
#                                             house_rules   host_id  \
# 6     Please no shoes in the house so bring slippers...   6570877
# 9     NO SMOKING OR PETS ANYWHERE ON THE PROPERTY 1....   4434391
# 12    - One of the bedroom closets is not accessible...  13743098
# 13                                                  NaN  57402911
# 21    - No smoking or open flames on the property - ...  74531248
# ...                                                 ...       ...
# 3565  - Washer/dryer coinup in apartment basement. -...  74137888
# 3567  House Rules 1. All bookings made at least a we...  12243051
# 3569  Please know this is my 2 bedroom condo that I ...  21149134
# 3572  House Rules 1. All bookings made at least a we...  12243051
# 3582                                                NaN  11311919
#
#                                         host_url    host_name host_since  \
# 6      https://www.airbnb.com/users/show/6570877       Juliet 2013-05-25
# 9      https://www.airbnb.com/users/show/4434391        Damon 2012-12-18
# 12    https://www.airbnb.com/users/show/13743098        Megan 2014-03-31
# 13    https://www.airbnb.com/users/show/57402911      Georgia 2016-02-04
# 21    https://www.airbnb.com/users/show/74531248  Carl & Judy 2016-05-28
# ...                                          ...          ...        ...
# 3565  https://www.airbnb.com/users/show/74137888        Chris 2016-05-26
# 3567  https://www.airbnb.com/users/show/12243051     Flatbook 2014-02-14
# 3569  https://www.airbnb.com/users/show/21149134      Johanna 2014-09-09
# 3572  https://www.airbnb.com/users/show/12243051     Flatbook 2014-02-14
# 3582  https://www.airbnb.com/users/show/11311919         Vera 2014-01-14
#
#       host_response_time  host_response_rate  host_acceptance_rate  \
# 6         within an hour                0.98                  0.96
# 9         within an hour                1.00                  1.00
# 12    within a few hours                1.00                  1.00
# 13        within an hour                1.00                  0.97
# 21        within an hour                1.00                  1.00
# ...                  ...                 ...                   ...
# 3565  within a few hours                1.00                  1.00
# 3567  within a few hours                0.71                  0.98
# 3569      within an hour                1.00                  0.53
# 3572  within a few hours                0.71                  0.98
# 3582        within a day                0.78                  0.50
#
#       host_is_superhost  host_listings_count  \
# 6                 False                    5
# 9                  True                    2
# 12                False                    2
# 13                False                    1
# 21                False                    1
# ...                 ...                  ...
# 3565              False                    1
# 3567              False                  363
# 3569              False                    2
# 3572              False                  363
# 3582              False                    1
#
#                                      host_verifications  host_has_profile_pic  \
# 6         ['email', 'phone', 'reviews', 'jumio', 'kba']                  True
# 9      ['email', 'phone', 'facebook', 'reviews', 'kba']                  True
# 12                        ['email', 'phone', 'reviews']                  True
# 13                 ['email', 'phone', 'reviews', 'kba']                  True
# 21     ['email', 'phone', 'linkedin', 'reviews', 'kba']                  True
# ...                                                 ...                   ...
# 3565                               ['phone', 'reviews']                  True
# 3567  ['email', 'phone', 'reviews', 'manual_offline'...                  True
# 3569                               ['phone', 'reviews']                  True
# 3572  ['email', 'phone', 'reviews', 'manual_offline'...                  True
# 3582                                          ['phone']                  True
#
#       host_identity_verified  \
# 6                       True
# 9                       True
# 12                     False
# 13                      True
# 21                      True
# ...                      ...
# 3565                   False
# 3567                    True
# 3569                   False
# 3572                    True
# 3582                   False
#
#                                                  street   neighbourhood  \
# 6     Kittredge Street, Boston, MA 02131, United States             NaN
# 9        Centre Street, Boston, MA 02131, United States      Roslindale
# 12     Primrose Street, Boston, MA 02131, United States      Roslindale
# 13     Fairview Street, Boston, MA 02131, United States      Roslindale
# 21     Weld Street, Roslindale, MA 02131, United States      Roslindale
# ...                                                 ...             ...
# 3565  Gibson Street, Cambridge, MA 02138, United States             NaN
# 3567   Story Street, Cambridge, MA 02138, United States  Harvard Square
# 3569  Pinckney Street, Somerville, MA 02145, United ...             NaN
# 3572   Story Street, Cambridge, MA 02138, United States  Harvard Square
# 3582   Child Street, Cambridge, MA 02141, United States             NaN
#
#      neighbourhood_cleansed        city state zipcode   latitude  longitude  \
# 6                Roslindale      Boston    MA   02131  42.281390 -71.131190
# 9                Roslindale      Boston    MA   02131  42.288820 -71.139510
# 12               Roslindale      Boston    MA   02131  42.291723 -71.131556
# 13               Roslindale      Boston    MA   02131  42.287641 -71.129883
# 21               Roslindale  Roslindale    MA   02131  42.294035 -71.132237
# ...                     ...         ...   ...     ...        ...        ...
# 3565                Allston   Cambridge    MA   02138  42.375730 -71.133388
# 3567                Allston   Cambridge    MA   02138  42.373724 -71.121888
# 3569            Charlestown  Somerville    MA   02145  42.384376 -71.080522
# 3572                Allston   Cambridge    MA   02138  42.373756 -71.122116
# 3582            Charlestown   Cambridge    MA   02141  42.371771 -71.071300
#
#       is_location_exact property_type        room_type  accommodates  \
# 6                 False     Apartment  Entire home/apt             3
# 9                  True     Apartment  Entire home/apt             5
# 12                 True   Condominium  Entire home/apt             4
# 13                 True     Apartment  Entire home/apt             5
# 21                 True         House  Entire home/apt             3
# ...                 ...           ...              ...           ...
# 3565              False     Apartment  Entire home/apt             4
# 3567               True     Apartment  Entire home/apt            10
# 3569              False     Apartment  Entire home/apt             4
# 3572               True     Apartment  Entire home/apt             9
# 3582              False     Apartment  Entire home/apt             4
#
#       bathrooms  bedrooms  beds  bed_type  \
# 6             1         1     2  Real Bed
# 9             1         2     2  Real Bed
# 12            1         2     2  Real Bed
# 13            1         2     3  Real Bed
# 21            1         0     2  Real Bed
# ...         ...       ...   ...       ...
# 3565          1         1     2  Real Bed
# 3567          3         5     5  Real Bed
# 3569          1         1     2  Real Bed
# 3572          2         5     5  Real Bed
# 3582          1         1     1  Real Bed
#
#                                               amenities  price  weekly_price  \
# 6     {TV,Internet,"Wireless Internet",Kitchen,"Free...  100.0           NaN
# 9     {TV,"Cable TV",Internet,"Wireless Internet","A...  229.0           NaN
# 12    {"Cable TV","Wireless Internet","Air Condition...   93.0           NaN
# 13    {TV,Internet,"Wireless Internet","Air Conditio...  150.0           NaN
# 21    {TV,Internet,"Wireless Internet","Air Conditio...  120.0           NaN
# ...                                                 ...    ...           ...
# 3565  {"Wireless Internet",Kitchen,"Free Parking on ...  146.0           NaN
# 3567  {TV,"Cable TV",Internet,"Wireless Internet","A...  259.0           NaN
# 3569  {TV,Internet,"Wireless Internet","Air Conditio...  200.0           NaN
# 3572  {TV,"Cable TV",Internet,"Wireless Internet","A...  459.0           NaN
# 3582  {"translation missing: en.hosting_amenity_49",...  198.0           NaN
#
#       monthly_price  security_deposit  cleaning_fee  guests_included  \
# 6               NaN               NaN           NaN                1
# 9               NaN             200.0          50.0                4
# 12              NaN               NaN          40.0                1
# 13              NaN               NaN          50.0                5
# 21              NaN             150.0          50.0                3
# ...             ...               ...           ...              ...
# 3565            NaN               NaN           NaN                1
# 3567            NaN             400.0          95.0                1
# 3569            NaN               NaN           NaN                1
# 3572            NaN             400.0          95.0                1
# 3582            NaN               NaN           NaN                1
#
#       extra_people  minimum_nights  maximum_nights  availability_30  \
# 6             25.0               1            1125               22
# 9             25.0               4              10               20
# 12             0.0               1            1125                0
# 13            30.0               2              21                8
# 21             0.0               2               6                0
# ...            ...             ...             ...              ...
# 3565           0.0               4               8                0
# 3567           0.0               3            1125                0
# 3569          50.0               1            1125               29
# 3572           0.0               3            1125               14
# 3582           0.0               3              12                0
#
#       availability_60  availability_90  availability_365  number_of_reviews  \
# 6                  39               69               344                 57
# 9                  50               80               107                 33
# 12                  0                0                 0                  1
# 13                 17               39               129                 12
# 21                  7               32               207                 16
# ...               ...              ...               ...                ...
# 3565                0                0                 0                  1
# 3567                0                0                 0                  0
# 3569               59               89               364                  0
# 3572               31               58                86                  0
# 3582               15               40                40                  0
#
#      first_review last_review  review_scores_rating  review_scores_accuracy  \
# 6      2015-07-08  2016-09-01                  90.0                    10.0
# 9      2014-01-02  2016-05-27                  94.0                    10.0
# 12     2016-07-23  2016-07-23                 100.0                    10.0
# 13     2016-06-27  2016-09-03                  97.0                    10.0
# 21     2016-06-19  2016-09-01                  98.0                    10.0
# ...           ...         ...                   ...                     ...
# 3565   2016-08-28  2016-08-28                 100.0                    10.0
# 3567          NaT         NaT                   NaN                     NaN
# 3569          NaT         NaT                   NaN                     NaN
# 3572          NaT         NaT                   NaN                     NaN
# 3582          NaT         NaT                   NaN                     NaN
#
#       review_scores_cleanliness  review_scores_checkin  \
# 6                          10.0                   10.0
# 9                           9.0                   10.0
# 12                         10.0                   10.0
# 13                         10.0                   10.0
# 21                         10.0                   10.0
# ...                         ...                    ...
# 3565                        8.0                   10.0
# 3567                        NaN                    NaN
# 3569                        NaN                    NaN
# 3572                        NaN                    NaN
# 3582                        NaN                    NaN
#
#       review_scores_communication  review_scores_location  \
# 6                            10.0                     9.0
# 9                            10.0                     9.0
# 12                           10.0                    10.0
# 13                           10.0                     9.0
# 21                           10.0                    10.0
# ...                           ...                     ...
# 3565                         10.0                    10.0
# 3567                          NaN                     NaN
# 3569                          NaN                     NaN
# 3572                          NaN                     NaN
# 3582                          NaN                     NaN
#
#       review_scores_value  instant_bookable cancellation_policy  \
# 6                     9.0             False              strict
# 9                     9.0             False              strict
# 12                   10.0              True            flexible
# 13                   10.0             False            moderate
# 21                   10.0              True            moderate
# ...                   ...               ...                 ...
# 3565                 10.0              True            flexible
# 3567                  NaN              True              strict
# 3569                  NaN             False            flexible
# 3572                  NaN              True              strict
# 3582                  NaN             False            flexible
#
#       require_guest_profile_picture  require_guest_phone_verification  \
# 6                             False                             False
# 9                             False                             False
# 12                            False                             False
# 13                            False                             False
# 21                            False                             False
# ...                             ...                               ...
# 3565                          False                             False
# 3567                          False                             False
# 3569                          False                             False
# 3572                          False                             False
# 3582                          False                             False
#
#       reviews_per_month neighbourhood_updated
# 6                  4.00            Roslindale
# 9                  1.01            Roslindale
# 12                 0.64            Roslindale
# 13                 4.93            Roslindale
# 21                 5.93            Roslindale
# ...                 ...                   ...
# 3565               1.00             Cambridge
# 3567                NaN        Harvard Square
# 3569                NaN            Somerville
# 3572                NaN        Harvard Square
# 3582                NaN             Cambridge
#
# [1957 rows x 70 columns]

# %%
(listings['price'] > 400).sum()
# Out:
# 82

# %%
(listings['price']).count()
# Out:
# 1957

# %%
ax = sns.pairplot(listings, y_vars='price', x_vars=['reviews_per_month','reviews_per_month'])
ax.fig.suptitle("Dispersão entre as variáveis", fontsize=20, y=1.09)
ax

# %% [markdown]
# #### Vamos analisar a distribuição dos preços médios por tipo de propriedade e neighbourhood

# %%
# Calcular o preço médio por tipo de propriedade e bairro
average_price = listings.groupby(['property_type', 'neighbourhood_updated'])['price'].mean().reset_index()

# Transformar os dados em uma tabela usando pivot
table = pd.pivot_table(average_price, values='price', index='property_type', columns='neighbourhood_updated', aggfunc='mean')

# Mostrar a tabela
table
# Out:
# neighbourhood_updated  Allston-Brighton    Back Bay  Beacon Hill  Brookline  \
# property_type
# Apartment                    156.558824  245.069264   202.585366      350.0
# Condominium                  183.545455  246.875000   258.125000        NaN
# Entire Floor                        NaN         NaN          NaN        NaN
# House                        190.181818  337.000000   327.250000        NaN
# Loft                         162.500000  150.250000          NaN        NaN
# Townhouse                           NaN  174.500000          NaN        NaN
#
# neighbourhood_updated   Cambridge  Charlestown  Chestnut Hill   Chinatown  \
# property_type
# Apartment              223.833333   236.384615          104.5  239.558824
# Condominium                   NaN   235.545455            NaN  383.000000
# Entire Floor                  NaN          NaN            NaN         NaN
# House                  240.000000   364.777778            NaN         NaN
# Loft                          NaN          NaN            NaN  236.750000
# Townhouse                     NaN          NaN            NaN         NaN
#
# neighbourhood_updated  Dorchester  Downtown  Downtown Crossing  East Boston  \
# property_type
# Apartment              146.166667     242.5         272.714286   151.037037
# Condominium            177.800000       NaN                NaN   151.714286
# Entire Floor           153.000000       NaN                NaN          NaN
# House                  154.125000       NaN                NaN   177.333333
# Loft                   250.000000       NaN         449.000000          NaN
# Townhouse                     NaN       NaN                NaN          NaN
#
# neighbourhood_updated  Fenway/Kenmore  Financial District  Government Center  \
# property_type
# Apartment                  252.176166               332.6         205.333333
# Condominium                350.800000                 NaN                NaN
# Entire Floor                      NaN                 NaN                NaN
# House                      190.000000                 NaN                NaN
# Loft                              NaN                 NaN                NaN
# Townhouse                         NaN                 NaN                NaN
#
# neighbourhood_updated  Harvard Square  Hyde Park  Jamaica Plain  \
# property_type
# Apartment                       289.0      205.0     191.933333
# Condominium                       NaN        NaN     179.058824
# Entire Floor                      NaN        NaN     155.000000
# House                             NaN        NaN     211.461538
# Loft                              NaN       85.0     220.000000
# Townhouse                         NaN        NaN      94.000000
#
# neighbourhood_updated  Leather District  Mattapan  Mission Hill   North End  \
# property_type
# Apartment                    281.111111     179.0    196.984127  223.758065
# Condominium                  288.000000       NaN           NaN  178.777778
# Entire Floor                        NaN       NaN           NaN         NaN
# House                               NaN     129.0           NaN  205.000000
# Loft                         312.500000       NaN    166.666667  213.333333
# Townhouse                           NaN       NaN           NaN         NaN
#
# neighbourhood_updated  Roslindale     Roxbury  Somerville  South Boston  \
# property_type
# Apartment              141.333333  209.018868       216.0    280.122807
# Condominium             93.000000  236.000000         NaN    237.913043
# Entire Floor                  NaN         NaN         NaN           NaN
# House                  152.142857  255.000000         NaN    290.454545
# Loft                          NaN         NaN         NaN    214.666667
# Townhouse                     NaN         NaN         NaN    299.000000
#
# neighbourhood_updated   South End  Theater District  West End  West Roxbury
# property_type
# Apartment              203.816754        234.958333    220.95    138.714286
# Condominium            274.950000               NaN       NaN           NaN
# Entire Floor                  NaN               NaN       NaN           NaN
# House                  220.000000               NaN       NaN    201.333333
# Loft                   100.000000        389.500000       NaN           NaN
# Townhouse              156.250000               NaN       NaN           NaN

# %% [markdown]
# Para a análise acima, vamos utilizar o tableau

# %%
listings.shape
# Out:
# (1957, 70)

# %% [markdown]
# ### Agora vamos olhar o dataset review

# %%
reviews = pd.read_csv('../csvs_originais/reviews.csv')
reviews.head()
# Out:
#    listing_id       id        date  reviewer_id reviewer_name  \
# 0     1178162  4724140  2013-05-21      4298113       Olivier
# 1     1178162  4869189  2013-05-29      6452964     Charlotte
# 2     1178162  5003196  2013-06-06      6449554     Sebastian
# 3     1178162  5150351  2013-06-15      2215611        Marine
# 4     1178162  5171140  2013-06-16      6848427        Andrew
#
#                                             comments
# 0  My stay at islam's place was really cool! Good...
# 1  Great location for both airport and city - gre...
# 2  We really enjoyed our stay at Islams house. Fr...
# 3  The room was nice and clean and so were the co...
# 4  Great location. Just 5 mins walk from the Airp...

# %% [markdown]
# Para nossa análise, não é interesse no momento o dataset reviews

# %% [markdown]
# ### Vamos olhar o dataset calendar

# %%
calendar = pd.read_csv('../csvs_originais/calendar.csv')
calendar.head()
# Out:
#    listing_id        date available price
# 0    12147973  2017-09-05         f   NaN
# 1    12147973  2017-09-04         f   NaN
# 2    12147973  2017-09-03         f   NaN
# 3    12147973  2017-09-02         f   NaN
# 4    12147973  2017-09-01         f   NaN

# %%
calendar.shape
# Out:
# (1308890, 4)

# %%
(calendar['available'] == 't').sum()
# Out:
# 643037

# %%
calendar['price'].isnull().sum()
# Out:
# 665853

# %%
#Converter o date para o tipo datetime
calendar['date'] = pd.to_datetime(calendar['date'])

# %%
calendar.describe()
# Out:
#          listing_id                           date
# count  1.308890e+06                        1308890
# mean   8.442118e+06  2017-03-07 00:00:00.000000256
# min    3.353000e+03            2016-09-06 00:00:00
# 25%    4.679319e+06            2016-12-06 00:00:00
# 50%    8.578710e+06            2017-03-07 00:00:00
# 75%    1.279603e+07            2017-06-06 00:00:00
# max    1.493346e+07            2017-09-05 00:00:00
# std    4.500149e+06                            NaN

# %%
print(calendar['available'].head(10))
print(calendar['available'].value_counts())
# Out:
# 0    f
# 1    f
# 2    f
# 3    f
# 4    f
# 5    f
# 6    f
# 7    f
# 8    f
# 9    f
# Name: available, dtype: object
# available
# f    665853
# t    643037
# Name: count, dtype: int64

# %%
# Corrigir a conversão da coluna 'available'
calendar['available'] = calendar['available'].replace({'t': True, 'f': False})
# Out:
# /var/folders/_5/jv6f9k4n2xq59l09xtzj00fc0000gn/T/ipykernel_36706/923267366.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   calendar['available'] = calendar['available'].replace({'t': True, 'f': False})

# %%
# Verificar a conversão da coluna 'available'
print(calendar['available'].head(10))
print(calendar['available'].value_counts())
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# Name: available, dtype: bool
# available
# False    665853
# True     643037
# Name: count, dtype: int64

# %%
duplicated_entries = calendar[calendar.duplicated(['listing_id', 'date'])]
print(f"Número de entradas duplicadas: {len(duplicated_entries)}")
# Out:
# Número de entradas duplicadas: 365

# %%
# Remover duplicatas
calendar = calendar.drop_duplicates(['listing_id', 'date'])

# %%
duplicated_entries = calendar[calendar.duplicated(['listing_id', 'date'])]
print(f"Número de entradas duplicadas: {len(duplicated_entries)}")
# Out:
# Número de entradas duplicadas: 0

# %% [markdown]
# Calcular a taxa de ocupação em 1 ano

# %%
# Calcular a taxa de ocupação
# Calcular o número de dias não disponíveis para cada listing_id
occupancy = calendar.groupby('listing_id')['available'].apply(lambda x: (~x).sum()).reset_index()
occupancy.columns = ['listing_id', 'days_booked']
occupancy.head()
# Out:
#    listing_id  days_booked
# 0        3353          116
# 1        5506           21
# 2        6695           41
# 3        6976           46
# 4        8792          117

# %% [markdown]
# Calcular a taxa de ocupação anual

# %%
# Calcular a taxa de ocupação
total_days = 365  # Considerando um ano
occupancy['annual_occupancy_rate'] = (occupancy['days_booked'] / total_days)

# %%
occupancy['annual_occupancy_rate'].describe()
# Out:
# count    3585.000000
# mean        0.508640
# std         0.389414
# min         0.000000
# 25%         0.109589
# 50%         0.509589
# 75%         0.947945
# max         1.000000
# Name: annual_occupancy_rate, dtype: float64

# %%
# Juntar a taxa de ocupação com a tabela de listagens
listings = listings.merge(occupancy, left_on='id', right_on='listing_id', how='left')

# Substituir valores NaN por 0 (caso algumas listagens não tenham dados de ocupação)
listings['annual_occupancy_rate'].fillna(0, inplace=True)
# Out:
# /var/folders/_5/jv6f9k4n2xq59l09xtzj00fc0000gn/T/ipykernel_36706/1820484344.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   listings['annual_occupancy_rate'].fillna(0, inplace=True)

# %%
print(listings[['id', 'property_type', 'room_type', 'price', 'annual_occupancy_rate']])
# Out:
#             id property_type        room_type  price  annual_occupancy_rate
# 0      5706985     Apartment  Entire home/apt  100.0               0.057534
# 1       849408     Apartment  Entire home/apt  229.0               0.706849
# 2      2684840   Condominium  Entire home/apt   93.0               1.000000
# 3     13547301     Apartment  Entire home/apt  150.0               0.646575
# 4     13251243         House  Entire home/apt  120.0               0.432877
# ...        ...           ...              ...    ...                    ...
# 1952  14335003     Apartment  Entire home/apt  146.0               1.000000
# 1953  14472678     Apartment  Entire home/apt  259.0               1.000000
# 1954  14426586     Apartment  Entire home/apt  200.0               0.002740
# 1955  14744740     Apartment  Entire home/apt  459.0               0.764384
# 1956  14585486     Apartment  Entire home/apt  198.0               0.890411
#
# [1957 rows x 5 columns]

# %%
listings['annual_occupancy_rate'].describe()
# Out:
# count    1957.000000
# mean        0.522484
# std         0.376969
# min         0.000000
# 25%         0.136986
# 50%         0.520548
# 75%         0.942466
# max         1.000000
# Name: annual_occupancy_rate, dtype: float64

# %%
#Remover a coluna listing_id que está duplicada
listings.drop(columns=['listing_id','state'], inplace=True)

# %%
calendar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1308525 entries, 0 to 1308889
# Data columns (total 4 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   listing_id  1308525 non-null  int64
#  1   date        1308525 non-null  datetime64[ns]
#  2   available   1308525 non-null  bool
#  3   price       642957 non-null   object
# dtypes: bool(1), datetime64[ns](1), int64(1), object(1)
# memory usage: 41.2+ MB

# %% [markdown]
# Calcular a frequência de reservas por mês

# %%
# Remover o símbolo de dólar e converter a coluna de preço para float
calendar['price'] = calendar['price'].str.replace('$', '').str.replace(',', '').astype(float)

# %%
# Adicionar uma coluna de ano e mês
calendar['year_month'] = calendar['date'].dt.to_period('M')

# Calcular o número de dias reservados (não disponíveis) e o número total de dias por mês para cada listing_id
monthly_occupancy = calendar.groupby(['listing_id', 'year_month']).agg(
    days_booked=('available', lambda x: (~x).sum()),
    total_days=('available', 'count'),
    avg_price_property_available=('price', 'mean')
).reset_index()

# Calcular a taxa de ocupação
monthly_occupancy['occupancy_rate'] = monthly_occupancy['days_booked'] / monthly_occupancy['total_days']

# Criar a coluna com o nome do mês
monthly_occupancy['month_name'] = monthly_occupancy['year_month'].dt.strftime('%B')

monthly_occupancy
# Out:
#        listing_id year_month  days_booked  total_days  \
# 0            3353    2016-09           25          25
# 1            3353    2016-10           31          31
# 2            3353    2016-11           30          30
# 3            3353    2016-12           30          31
# 4            3353    2017-01            0          31
# ...           ...        ...          ...         ...
# 46600    14933461    2017-05            8          31
# 46601    14933461    2017-06            3          30
# 46602    14933461    2017-07            0          31
# 46603    14933461    2017-08            0          31
# 46604    14933461    2017-09            0           5
#
#        avg_price_property_available  occupancy_rate month_name
# 0                               NaN        1.000000  September
# 1                               NaN        1.000000    October
# 2                               NaN        1.000000   November
# 3                         32.000000        0.967742   December
# 4                         32.612903        0.000000    January
# ...                             ...             ...        ...
# 46600                    165.000000        0.258065        May
# 46601                    165.000000        0.100000       June
# 46602                    165.000000        0.000000       July
# 46603                    165.000000        0.000000     August
# 46604                    165.000000        0.000000  September
#
# [46605 rows x 7 columns]

# %%
listings.head(2)
# Out:
#         id                           listing_url  \
# 0  5706985  https://www.airbnb.com/rooms/5706985
# 1   849408   https://www.airbnb.com/rooms/849408
#
#                                   name  \
# 0  New Lrg Studio apt 15 min to Boston
# 1    Perfect & Practical Boston Rental
#
#                                              summary  \
# 0  It's a 5 minute walk to Rosi Square to catch t...
# 1  This is a cozy and spacious two bedroom unit w...
#
#                                                space  \
# 0  The whole house was recently redone and it 's ...
# 1  Perfect apartment rental for those in town vis...
#
#                                          description  \
# 0  It's a 5 minute walk to Rosi Square to catch t...
# 1  This is a cozy and spacious two bedroom unit w...
#
#                                neighborhood_overview  \
# 0  Roslindale is the new hip area of Boston. Clos...
# 1  This neighborhood truly has it all.  Good, not...
#
#                                                notes  \
# 0  Information about the house, wifi pasword and ...
# 1  Please note that this is a second floor apartm...
#
#                                              transit  \
# 0  The commuter rail (Needham Line) is a 5 minute...
# 1  Plenty of on street parking with no restrictio...
#
#                                               access  \
# 0  I have an electronic keypad so arrival time ca...
# 1                                                NaN
#
#                                          interaction  \
# 0  I can interact or not- that is up to you. This...
# 1  I'm available for questions anytime before or ...
#
#                                          house_rules  host_id  \
# 0  Please no shoes in the house so bring slippers...  6570877
# 1  NO SMOKING OR PETS ANYWHERE ON THE PROPERTY 1....  4434391
#
#                                     host_url host_name host_since  \
# 0  https://www.airbnb.com/users/show/6570877    Juliet 2013-05-25
# 1  https://www.airbnb.com/users/show/4434391     Damon 2012-12-18
#
#   host_response_time  host_response_rate  host_acceptance_rate  \
# 0     within an hour                0.98                  0.96
# 1     within an hour                1.00                  1.00
#
#    host_is_superhost  host_listings_count  \
# 0              False                    5
# 1               True                    2
#
#                                  host_verifications  host_has_profile_pic  \
# 0     ['email', 'phone', 'reviews', 'jumio', 'kba']                  True
# 1  ['email', 'phone', 'facebook', 'reviews', 'kba']                  True
#
#    host_identity_verified                                             street  \
# 0                    True  Kittredge Street, Boston, MA 02131, United States
# 1                    True     Centre Street, Boston, MA 02131, United States
#
#   neighbourhood neighbourhood_cleansed    city zipcode  latitude  longitude  \
# 0           NaN             Roslindale  Boston   02131  42.28139  -71.13119
# 1    Roslindale             Roslindale  Boston   02131  42.28882  -71.13951
#
#    is_location_exact property_type        room_type  accommodates  bathrooms  \
# 0              False     Apartment  Entire home/apt             3          1
# 1               True     Apartment  Entire home/apt             5          1
#
#    bedrooms  beds  bed_type  \
# 0         1     2  Real Bed
# 1         2     2  Real Bed
#
#                                            amenities  price  weekly_price  \
# 0  {TV,Internet,"Wireless Internet",Kitchen,"Free...  100.0           NaN
# 1  {TV,"Cable TV",Internet,"Wireless Internet","A...  229.0           NaN
#
#    monthly_price  security_deposit  cleaning_fee  guests_included  \
# 0            NaN               NaN           NaN                1
# 1            NaN             200.0          50.0                4
#
#    extra_people  minimum_nights  maximum_nights  availability_30  \
# 0          25.0               1            1125               22
# 1          25.0               4              10               20
#
#    availability_60  availability_90  availability_365  number_of_reviews  \
# 0               39               69               344                 57
# 1               50               80               107                 33
#
#   first_review last_review  review_scores_rating  review_scores_accuracy  \
# 0   2015-07-08  2016-09-01                  90.0                    10.0
# 1   2014-01-02  2016-05-27                  94.0                    10.0
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                       10.0                   10.0
# 1                        9.0                   10.0
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         10.0                     9.0                  9.0
# 1                         10.0                     9.0                  9.0
#
#    instant_bookable cancellation_policy  require_guest_profile_picture  \
# 0             False              strict                          False
# 1             False              strict                          False
#
#    require_guest_phone_verification  reviews_per_month neighbourhood_updated  \
# 0                             False               4.00            Roslindale
# 1                             False               1.01            Roslindale
#
#    days_booked  annual_occupancy_rate
# 0           21               0.057534
# 1          258               0.706849

# %%
calendar.query('listing_id == 5706985')
# Out:
#       listing_id       date  available  price year_month
# 2190     5706985 2017-09-05       True  100.0    2017-09
# 2191     5706985 2017-09-04       True  100.0    2017-09
# 2192     5706985 2017-09-03       True  100.0    2017-09
# 2193     5706985 2017-09-02       True  125.0    2017-09
# 2194     5706985 2017-09-01       True  125.0    2017-09
# ...          ...        ...        ...    ...        ...
# 2550     5706985 2016-09-10       True  125.0    2016-09
# 2551     5706985 2016-09-09       True  125.0    2016-09
# 2552     5706985 2016-09-08       True  100.0    2016-09
# 2553     5706985 2016-09-07      False    NaN    2016-09
# 2554     5706985 2016-09-06      False    NaN    2016-09
#
# [365 rows x 5 columns]

# %%
calendar['year_month'].min()
# Out:
# Period('2016-09', 'M')

# %%
listings['property_type'].unique()
# Out:
# array(['Apartment', 'Condominium', 'House', 'Entire Floor', 'Townhouse',
#        'Loft'], dtype=object)

# %%
qtd_property = listings.groupby('property_type').count()

# %%
qtd_property['id']
# Out:
# property_type
# Apartment       1682
# Condominium      141
# Entire Floor       2
# House             96
# Loft              28
# Townhouse          8
# Name: id, dtype: int64

# %%
qtd_property['review_scores_rating']
# Out:
# property_type
# Apartment       1277
# Condominium      110
# Entire Floor       0
# House             83
# Loft              24
# Townhouse          8
# Name: review_scores_rating, dtype: int64

# %%
listings = listings[~listings['property_type'].isin(['Entire Floor', 'Townhouse', 'Loft'])]

# %%
monthly_occupancy.to_excel('../visualizacoes/arquivos_excel/monthly_occupancy.xlsx', index=False)

# %%
listings['id'].count()
# Out:
# 1919

# %%
listings.groupby('neighbourhood_updated').count().sort_values(by='id', ascending=False)
# Out:
#                         id  listing_url  name  summary  space  description  \
# neighbourhood_updated
# Back Bay               249          249   249      234    188          249
# South End              212          212   212      205    165          212
# Fenway/Kenmore         199          199   199      188    121          199
# Allston-Brighton       158          158   158      155    109          158
# South Boston           148          148   148      146    104          148
# Beacon Hill            135          135   135      132    104          135
# North End              135          135   135      131     94          135
# Jamaica Plain          133          133   133      127    108          133
# Chinatown               69           69    69       69     64           69
# East Boston             64           64    64       60     46           64
# Mission Hill            63           63    63       60     45           63
# Roxbury                 63           63    63       54     55           63
# West End                60           60    60       54     48           60
# Charlestown             59           59    59       54     42           59
# Dorchester              55           55    55       54     40           55
# Theater District        24           24    24       23     16           24
# Downtown Crossing       21           21    21       21     19           21
# Roslindale              17           17    17       17     14           17
# Leather District        12           12    12       12      7           12
# West Roxbury            10           10    10       10      7           10
# Cambridge                7            7     7        7      3            7
# Financial District       5            5     5        5      4            5
# Downtown                 4            4     4        4      3            4
# Government Center        3            3     3        3      3            3
# Somerville               3            3     3        3      1            3
# Harvard Square           3            3     3        3      2            3
# Mattapan                 2            2     2        2      1            2
# Hyde Park                2            2     2        2      2            2
# Chestnut Hill            2            2     2        2      1            2
# Brookline                1            1     1        1      1            1
#
#                        neighborhood_overview  notes  transit  access  \
# neighbourhood_updated
# Back Bay                                 159     99      158     127
# South End                                153    109      157     148
# Fenway/Kenmore                           112     63      112      71
# Allston-Brighton                          86     57       96      74
# South Boston                              80     67       96      81
# Beacon Hill                               94     72       93      91
# North End                                 87     65       94      78
# Jamaica Plain                             93     69       99     101
# Chinatown                                 52     47       46      26
# East Boston                               44     31       44      43
# Mission Hill                              35     25       37      27
# Roxbury                                   48     32       47      37
# West End                                  39     23       35      20
# Charlestown                               36     34       40      35
# Dorchester                                23     27       32      29
# Theater District                          13      6       12      12
# Downtown Crossing                         18     14       18      14
# Roslindale                                11     10       11      11
# Leather District                           6      4        7       7
# West Roxbury                               6      4        6       6
# Cambridge                                  3      2        3       3
# Financial District                         4      2        4       1
# Downtown                                   3      3        3       3
# Government Center                          3      3        3       3
# Somerville                                 1      0        2       2
# Harvard Square                             2      0        2       0
# Mattapan                                   1      0        1       1
# Hyde Park                                  2      2        2       2
# Chestnut Hill                              0      0        1       1
# Brookline                                  1      1        1       1
#
#                        interaction  house_rules  host_id  host_url  host_name  \
# neighbourhood_updated
# Back Bay                       124          169      249       249        249
# South End                      127          167      212       212        212
# Fenway/Kenmore                  75          103      199       199        199
# Allston-Brighton                90          102      158       158        158
# South Boston                    77           81      148       148        148
# Beacon Hill                     72          105      135       135        135
# North End                       77           90      135       135        135
# Jamaica Plain                   93          108      133       133        133
# Chinatown                       49           47       69        69         69
# East Boston                     37           40       64        64         64
# Mission Hill                    32           40       63        63         63
# Roxbury                         41           43       63        63         63
# West End                        22           28       60        60         60
# Charlestown                     38           39       59        59         59
# Dorchester                      31           37       55        55         55
# Theater District                 9           15       24        24         24
# Downtown Crossing               18           15       21        21         21
# Roslindale                      12           13       17        17         17
# Leather District                 5            9       12        12         12
# West Roxbury                     4            7       10        10         10
# Cambridge                        3            3        7         7          7
# Financial District               2            1        5         5          5
# Downtown                         3            3        4         4          4
# Government Center                3            3        3         3          3
# Somerville                       1            3        3         3          3
# Harvard Square                   2            2        3         3          3
# Mattapan                         1            1        2         2          2
# Hyde Park                        2            2        2         2          2
# Chestnut Hill                    0            1        2         2          2
# Brookline                        1            1        1         1          1
#
#                        host_since  host_response_time  host_response_rate  \
# neighbourhood_updated
# Back Bay                      249                 222                 222
# South End                     212                 184                 184
# Fenway/Kenmore                199                 174                 174
# Allston-Brighton              158                 127                 127
# South Boston                  148                 128                 128
# Beacon Hill                   135                 125                 125
# North End                     135                 118                 118
# Jamaica Plain                 133                 117                 117
# Chinatown                      69                  68                  68
# East Boston                    64                  57                  57
# Mission Hill                   63                  56                  56
# Roxbury                        63                  61                  61
# West End                       60                  56                  56
# Charlestown                    59                  49                  49
# Dorchester                     55                  50                  50
# Theater District               24                  18                  18
# Downtown Crossing              21                  21                  21
# Roslindale                     17                  15                  15
# Leather District               12                  10                  10
# West Roxbury                   10                   8                   8
# Cambridge                       7                   7                   7
# Financial District              5                   5                   5
# Downtown                        4                   4                   4
# Government Center               3                   3                   3
# Somerville                      3                   2                   2
# Harvard Square                  3                   3                   3
# Mattapan                        2                   2                   2
# Hyde Park                       2                   2                   2
# Chestnut Hill                   2                   1                   1
# Brookline                       1                   1                   1
#
#                        host_acceptance_rate  host_is_superhost  \
# neighbourhood_updated
# Back Bay                                222                249
# South End                               184                212
# Fenway/Kenmore                          174                199
# Allston-Brighton                        127                158
# South Boston                            128                148
# Beacon Hill                             125                135
# North End                               118                135
# Jamaica Plain                           117                133
# Chinatown                                68                 69
# East Boston                              57                 64
# Mission Hill                             56                 63
# Roxbury                                  61                 63
# West End                                 56                 60
# Charlestown                              49                 59
# Dorchester                               50                 55
# Theater District                         18                 24
# Downtown Crossing                        21                 21
# Roslindale                               15                 17
# Leather District                         10                 12
# West Roxbury                              8                 10
# Cambridge                                 7                  7
# Financial District                        5                  5
# Downtown                                  4                  4
# Government Center                         3                  3
# Somerville                                2                  3
# Harvard Square                            3                  3
# Mattapan                                  2                  2
# Hyde Park                                 2                  2
# Chestnut Hill                             1                  2
# Brookline                                 1                  1
#
#                        host_listings_count  host_verifications  \
# neighbourhood_updated
# Back Bay                               249                 249
# South End                              212                 212
# Fenway/Kenmore                         199                 199
# Allston-Brighton                       158                 158
# South Boston                           148                 148
# Beacon Hill                            135                 135
# North End                              135                 135
# Jamaica Plain                          133                 133
# Chinatown                               69                  69
# East Boston                             64                  64
# Mission Hill                            63                  63
# Roxbury                                 63                  63
# West End                                60                  60
# Charlestown                             59                  59
# Dorchester                              55                  55
# Theater District                        24                  24
# Downtown Crossing                       21                  21
# Roslindale                              17                  17
# Leather District                        12                  12
# West Roxbury                            10                  10
# Cambridge                                7                   7
# Financial District                       5                   5
# Downtown                                 4                   4
# Government Center                        3                   3
# Somerville                               3                   3
# Harvard Square                           3                   3
# Mattapan                                 2                   2
# Hyde Park                                2                   2
# Chestnut Hill                            2                   2
# Brookline                                1                   1
#
#                        host_has_profile_pic  host_identity_verified  street  \
# neighbourhood_updated
# Back Bay                                249                     249     249
# South End                               212                     212     212
# Fenway/Kenmore                          199                     199     199
# Allston-Brighton                        158                     158     158
# South Boston                            148                     148     148
# Beacon Hill                             135                     135     135
# North End                               135                     135     135
# Jamaica Plain                           133                     133     133
# Chinatown                                69                      69      69
# East Boston                              64                      64      64
# Mission Hill                             63                      63      63
# Roxbury                                  63                      63      63
# West End                                 60                      60      60
# Charlestown                              59                      59      59
# Dorchester                               55                      55      55
# Theater District                         24                      24      24
# Downtown Crossing                        21                      21      21
# Roslindale                               17                      17      17
# Leather District                         12                      12      12
# West Roxbury                             10                      10      10
# Cambridge                                 7                       7       7
# Financial District                        5                       5       5
# Downtown                                  4                       4       4
# Government Center                         3                       3       3
# Somerville                                3                       3       3
# Harvard Square                            3                       3       3
# Mattapan                                  2                       2       2
# Hyde Park                                 2                       2       2
# Chestnut Hill                             2                       2       2
# Brookline                                 1                       1       1
#
#                        neighbourhood  neighbourhood_cleansed  city  zipcode  \
# neighbourhood_updated
# Back Bay                         218                     249   249      249
# South End                        201                     212   212      212
# Fenway/Kenmore                   184                     199   199      199
# Allston-Brighton                 137                     158   158      157
# South Boston                     136                     148   148      146
# Beacon Hill                      133                     135   135      135
# North End                         94                     135   135      134
# Jamaica Plain                    119                     133   133      133
# Chinatown                         69                      69    69       69
# East Boston                       55                      64    64       62
# Mission Hill                      39                      63    63       62
# Roxbury                           37                      63    63       61
# West End                          60                      60    60       60
# Charlestown                       51                      59    59       59
# Dorchester                        43                      55    55       55
# Theater District                  24                      24    24       24
# Downtown Crossing                 21                      21    21       21
# Roslindale                        13                      17    17       16
# Leather District                   4                      12    12       12
# West Roxbury                       9                      10    10       10
# Cambridge                          4                       7     7        7
# Financial District                 4                       5     5        4
# Downtown                           4                       4     4        4
# Government Center                  3                       3     3        3
# Somerville                         2                       3     3        3
# Harvard Square                     2                       3     3        2
# Mattapan                           1                       2     2        1
# Hyde Park                          2                       2     2        2
# Chestnut Hill                      1                       2     2        2
# Brookline                          1                       1     1        1
#
#                        latitude  longitude  is_location_exact  property_type  \
# neighbourhood_updated
# Back Bay                    249        249                249            249
# South End                   212        212                212            212
# Fenway/Kenmore              199        199                199            199
# Allston-Brighton            158        158                158            158
# South Boston                148        148                148            148
# Beacon Hill                 135        135                135            135
# North End                   135        135                135            135
# Jamaica Plain               133        133                133            133
# Chinatown                    69         69                 69             69
# East Boston                  64         64                 64             64
# Mission Hill                 63         63                 63             63
# Roxbury                      63         63                 63             63
# West End                     60         60                 60             60
# Charlestown                  59         59                 59             59
# Dorchester                   55         55                 55             55
# Theater District             24         24                 24             24
# Downtown Crossing            21         21                 21             21
# Roslindale                   17         17                 17             17
# Leather District             12         12                 12             12
# West Roxbury                 10         10                 10             10
# Cambridge                     7          7                  7              7
# Financial District            5          5                  5              5
# Downtown                      4          4                  4              4
# Government Center             3          3                  3              3
# Somerville                    3          3                  3              3
# Harvard Square                3          3                  3              3
# Mattapan                      2          2                  2              2
# Hyde Park                     2          2                  2              2
# Chestnut Hill                 2          2                  2              2
# Brookline                     1          1                  1              1
#
#                        room_type  accommodates  bathrooms  bedrooms  beds  \
# neighbourhood_updated
# Back Bay                     249           249        249       249   249
# South End                    212           212        212       212   212
# Fenway/Kenmore               199           199        199       199   199
# Allston-Brighton             158           158        158       158   158
# South Boston                 148           148        148       148   148
# Beacon Hill                  135           135        135       135   135
# North End                    135           135        135       135   135
# Jamaica Plain                133           133        133       133   133
# Chinatown                     69            69         69        69    69
# East Boston                   64            64         64        64    64
# Mission Hill                  63            63         63        63    63
# Roxbury                       63            63         63        63    63
# West End                      60            60         60        60    60
# Charlestown                   59            59         59        59    59
# Dorchester                    55            55         55        55    55
# Theater District              24            24         24        24    24
# Downtown Crossing             21            21         21        21    21
# Roslindale                    17            17         17        17    17
# Leather District              12            12         12        12    12
# West Roxbury                  10            10         10        10    10
# Cambridge                      7             7          7         7     7
# Financial District             5             5          5         5     5
# Downtown                       4             4          4         4     4
# Government Center              3             3          3         3     3
# Somerville                     3             3          3         3     3
# Harvard Square                 3             3          3         3     3
# Mattapan                       2             2          2         2     2
# Hyde Park                      2             2          2         2     2
# Chestnut Hill                  2             2          2         2     2
# Brookline                      1             1          1         1     1
#
#                        bed_type  amenities  price  weekly_price  \
# neighbourhood_updated
# Back Bay                    249        249    249            41
# South End                   212        212    212            40
# Fenway/Kenmore              199        199    199            27
# Allston-Brighton            158        158    158            39
# South Boston                148        148    148            19
# Beacon Hill                 135        135    135            35
# North End                   135        135    135            20
# Jamaica Plain               133        133    133            55
# Chinatown                    69         69     69             1
# East Boston                  64         64     64            15
# Mission Hill                 63         63     63             9
# Roxbury                      63         63     63            12
# West End                     60         60     60             5
# Charlestown                  59         59     59            21
# Dorchester                   55         55     55            17
# Theater District             24         24     24             6
# Downtown Crossing            21         21     21             4
# Roslindale                   17         17     17             6
# Leather District             12         12     12             3
# West Roxbury                 10         10     10             3
# Cambridge                     7          7      7             0
# Financial District            5          5      5             0
# Downtown                      4          4      4             3
# Government Center             3          3      3             2
# Somerville                    3          3      3             0
# Harvard Square                3          3      3             0
# Mattapan                      2          2      2             0
# Hyde Park                     2          2      2             2
# Chestnut Hill                 2          2      2             1
# Brookline                     1          1      1             0
#
#                        monthly_price  security_deposit  cleaning_fee  \
# neighbourhood_updated
# Back Bay                          53                94           179
# South End                         39               102           179
# Fenway/Kenmore                    81                32           151
# Allston-Brighton                  34                76           109
# South Boston                      14                65           118
# Beacon Hill                       28                66           102
# North End                         27                68           102
# Jamaica Plain                     43                70           105
# Chinatown                         11                14            66
# East Boston                       13                22            46
# Mission Hill                      16                18            52
# Roxbury                           11                35            55
# West End                          18                 4            48
# Charlestown                       16                22            42
# Dorchester                        14                33            46
# Theater District                   9                15            20
# Downtown Crossing                  3                13            15
# Roslindale                         6                10            15
# Leather District                   3                 6            10
# West Roxbury                       3                 3             6
# Cambridge                          0                 3             4
# Financial District                 0                 3             4
# Downtown                           2                 4             4
# Government Center                  2                 2             2
# Somerville                         0                 2             1
# Harvard Square                     0                 2             3
# Mattapan                           0                 1             1
# Hyde Park                          2                 2             2
# Chestnut Hill                      0                 1             1
# Brookline                          0                 0             1
#
#                        guests_included  extra_people  minimum_nights  \
# neighbourhood_updated
# Back Bay                           249           249             249
# South End                          212           212             212
# Fenway/Kenmore                     199           199             199
# Allston-Brighton                   158           158             158
# South Boston                       148           148             148
# Beacon Hill                        135           135             135
# North End                          135           135             135
# Jamaica Plain                      133           133             133
# Chinatown                           69            69              69
# East Boston                         64            64              64
# Mission Hill                        63            63              63
# Roxbury                             63            63              63
# West End                            60            60              60
# Charlestown                         59            59              59
# Dorchester                          55            55              55
# Theater District                    24            24              24
# Downtown Crossing                   21            21              21
# Roslindale                          17            17              17
# Leather District                    12            12              12
# West Roxbury                        10            10              10
# Cambridge                            7             7               7
# Financial District                   5             5               5
# Downtown                             4             4               4
# Government Center                    3             3               3
# Somerville                           3             3               3
# Harvard Square                       3             3               3
# Mattapan                             2             2               2
# Hyde Park                            2             2               2
# Chestnut Hill                        2             2               2
# Brookline                            1             1               1
#
#                        maximum_nights  availability_30  availability_60  \
# neighbourhood_updated
# Back Bay                          249              249              249
# South End                         212              212              212
# Fenway/Kenmore                    199              199              199
# Allston-Brighton                  158              158              158
# South Boston                      148              148              148
# Beacon Hill                       135              135              135
# North End                         135              135              135
# Jamaica Plain                     133              133              133
# Chinatown                          69               69               69
# East Boston                        64               64               64
# Mission Hill                       63               63               63
# Roxbury                            63               63               63
# West End                           60               60               60
# Charlestown                        59               59               59
# Dorchester                         55               55               55
# Theater District                   24               24               24
# Downtown Crossing                  21               21               21
# Roslindale                         17               17               17
# Leather District                   12               12               12
# West Roxbury                       10               10               10
# Cambridge                           7                7                7
# Financial District                  5                5                5
# Downtown                            4                4                4
# Government Center                   3                3                3
# Somerville                          3                3                3
# Harvard Square                      3                3                3
# Mattapan                            2                2                2
# Hyde Park                           2                2                2
# Chestnut Hill                       2                2                2
# Brookline                           1                1                1
#
#                        availability_90  availability_365  number_of_reviews  \
# neighbourhood_updated
# Back Bay                           249               249                249
# South End                          212               212                212
# Fenway/Kenmore                     199               199                199
# Allston-Brighton                   158               158                158
# South Boston                       148               148                148
# Beacon Hill                        135               135                135
# North End                          135               135                135
# Jamaica Plain                      133               133                133
# Chinatown                           69                69                 69
# East Boston                         64                64                 64
# Mission Hill                        63                63                 63
# Roxbury                             63                63                 63
# West End                            60                60                 60
# Charlestown                         59                59                 59
# Dorchester                          55                55                 55
# Theater District                    24                24                 24
# Downtown Crossing                   21                21                 21
# Roslindale                          17                17                 17
# Leather District                    12                12                 12
# West Roxbury                        10                10                 10
# Cambridge                            7                 7                  7
# Financial District                   5                 5                  5
# Downtown                             4                 4                  4
# Government Center                    3                 3                  3
# Somerville                           3                 3                  3
# Harvard Square                       3                 3                  3
# Mattapan                             2                 2                  2
# Hyde Park                            2                 2                  2
# Chestnut Hill                        2                 2                  2
# Brookline                            1                 1                  1
#
#                        first_review  last_review  review_scores_rating  \
# neighbourhood_updated
# Back Bay                        196          196                   192
# South End                       183          183                   180
# Fenway/Kenmore                  131          131                   127
# Allston-Brighton                114          114                   111
# South Boston                    118          118                   116
# Beacon Hill                     122          122                   121
# North End                       113          113                   112
# Jamaica Plain                   112          112                   111
# Chinatown                        36           36                    36
# East Boston                      60           60                    59
# Mission Hill                     40           40                    39
# Roxbury                          55           55                    55
# West End                         33           33                    32
# Charlestown                      48           48                    48
# Dorchester                       50           50                    47
# Theater District                 15           15                    15
# Downtown Crossing                20           20                    19
# Roslindale                       15           15                    15
# Leather District                 10           10                     9
# West Roxbury                      7            7                     7
# Cambridge                         3            3                     3
# Financial District                3            3                     3
# Downtown                          4            4                     4
# Government Center                 3            3                     3
# Somerville                        0            0                     0
# Harvard Square                    1            1                     1
# Mattapan                          1            1                     1
# Hyde Park                         2            2                     2
# Chestnut Hill                     1            1                     1
# Brookline                         0            0                     0
#
#                        review_scores_accuracy  review_scores_cleanliness  \
# neighbourhood_updated
# Back Bay                                  191                        191
# South End                                 180                        180
# Fenway/Kenmore                            125                        125
# Allston-Brighton                          111                        111
# South Boston                              116                        116
# Beacon Hill                               121                        121
# North End                                 112                        112
# Jamaica Plain                             111                        111
# Chinatown                                  36                         36
# East Boston                                59                         59
# Mission Hill                               39                         39
# Roxbury                                    55                         55
# West End                                   32                         32
# Charlestown                                48                         48
# Dorchester                                 46                         46
# Theater District                           15                         15
# Downtown Crossing                          19                         19
# Roslindale                                 15                         15
# Leather District                            9                          9
# West Roxbury                                7                          7
# Cambridge                                   3                          3
# Financial District                          3                          3
# Downtown                                    4                          4
# Government Center                           3                          3
# Somerville                                  0                          0
# Harvard Square                              1                          1
# Mattapan                                    1                          1
# Hyde Park                                   2                          2
# Chestnut Hill                               1                          1
# Brookline                                   0                          0
#
#                        review_scores_checkin  review_scores_communication  \
# neighbourhood_updated
# Back Bay                                 191                          191
# South End                                180                          180
# Fenway/Kenmore                           125                          125
# Allston-Brighton                         111                          111
# South Boston                             116                          116
# Beacon Hill                              121                          121
# North End                                112                          112
# Jamaica Plain                            111                          111
# Chinatown                                 36                           36
# East Boston                               59                           59
# Mission Hill                              39                           39
# Roxbury                                   55                           55
# West End                                  32                           32
# Charlestown                               48                           48
# Dorchester                                46                           46
# Theater District                          15                           15
# Downtown Crossing                         19                           19
# Roslindale                                15                           15
# Leather District                           9                            9
# West Roxbury                               7                            7
# Cambridge                                  3                            3
# Financial District                         3                            3
# Downtown                                   4                            4
# Government Center                          3                            3
# Somerville                                 0                            0
# Harvard Square                             1                            1
# Mattapan                                   1                            1
# Hyde Park                                  2                            2
# Chestnut Hill                              1                            1
# Brookline                                  0                            0
#
#                        review_scores_location  review_scores_value  \
# neighbourhood_updated
# Back Bay                                  191                  191
# South End                                 179                  180
# Fenway/Kenmore                            125                  125
# Allston-Brighton                          110                  111
# South Boston                              116                  116
# Beacon Hill                               121                  121
# North End                                 112                  112
# Jamaica Plain                             111                  111
# Chinatown                                  36                   36
# East Boston                                59                   59
# Mission Hill                               39                   39
# Roxbury                                    55                   55
# West End                                   32                   32
# Charlestown                                48                   48
# Dorchester                                 46                   46
# Theater District                           15                   15
# Downtown Crossing                          19                   19
# Roslindale                                 15                   15
# Leather District                            9                    9
# West Roxbury                                7                    7
# Cambridge                                   3                    3
# Financial District                          3                    3
# Downtown                                    4                    4
# Government Center                           3                    3
# Somerville                                  0                    0
# Harvard Square                              1                    1
# Mattapan                                    1                    1
# Hyde Park                                   2                    2
# Chestnut Hill                               1                    1
# Brookline                                   0                    0
#
#                        instant_bookable  cancellation_policy  \
# neighbourhood_updated
# Back Bay                            249                  249
# South End                           212                  212
# Fenway/Kenmore                      199                  199
# Allston-Brighton                    158                  158
# South Boston                        148                  148
# Beacon Hill                         135                  135
# North End                           135                  135
# Jamaica Plain                       133                  133
# Chinatown                            69                   69
# East Boston                          64                   64
# Mission Hill                         63                   63
# Roxbury                              63                   63
# West End                             60                   60
# Charlestown                          59                   59
# Dorchester                           55                   55
# Theater District                     24                   24
# Downtown Crossing                    21                   21
# Roslindale                           17                   17
# Leather District                     12                   12
# West Roxbury                         10                   10
# Cambridge                             7                    7
# Financial District                    5                    5
# Downtown                              4                    4
# Government Center                     3                    3
# Somerville                            3                    3
# Harvard Square                        3                    3
# Mattapan                              2                    2
# Hyde Park                             2                    2
# Chestnut Hill                         2                    2
# Brookline                             1                    1
#
#                        require_guest_profile_picture  \
# neighbourhood_updated
# Back Bay                                         249
# South End                                        212
# Fenway/Kenmore                                   199
# Allston-Brighton                                 158
# South Boston                                     148
# Beacon Hill                                      135
# North End                                        135
# Jamaica Plain                                    133
# Chinatown                                         69
# East Boston                                       64
# Mission Hill                                      63
# Roxbury                                           63
# West End                                          60
# Charlestown                                       59
# Dorchester                                        55
# Theater District                                  24
# Downtown Crossing                                 21
# Roslindale                                        17
# Leather District                                  12
# West Roxbury                                      10
# Cambridge                                          7
# Financial District                                 5
# Downtown                                           4
# Government Center                                  3
# Somerville                                         3
# Harvard Square                                     3
# Mattapan                                           2
# Hyde Park                                          2
# Chestnut Hill                                      2
# Brookline                                          1
#
#                        require_guest_phone_verification  reviews_per_month  \
# neighbourhood_updated
# Back Bay                                            249                196
# South End                                           212                183
# Fenway/Kenmore                                      199                131
# Allston-Brighton                                    158                114
# South Boston                                        148                118
# Beacon Hill                                         135                122
# North End                                           135                113
# Jamaica Plain                                       133                112
# Chinatown                                            69                 36
# East Boston                                          64                 60
# Mission Hill                                         63                 40
# Roxbury                                              63                 55
# West End                                             60                 33
# Charlestown                                          59                 48
# Dorchester                                           55                 50
# Theater District                                     24                 15
# Downtown Crossing                                    21                 20
# Roslindale                                           17                 15
# Leather District                                     12                 10
# West Roxbury                                         10                  7
# Cambridge                                             7                  3
# Financial District                                    5                  3
# Downtown                                              4                  4
# Government Center                                     3                  3
# Somerville                                            3                  0
# Harvard Square                                        3                  1
# Mattapan                                              2                  1
# Hyde Park                                             2                  2
# Chestnut Hill                                         2                  1
# Brookline                                             1                  0
#
#                        days_booked  annual_occupancy_rate
# neighbourhood_updated
# Back Bay                       249                    249
# South End                      212                    212
# Fenway/Kenmore                 199                    199
# Allston-Brighton               158                    158
# South Boston                   148                    148
# Beacon Hill                    135                    135
# North End                      135                    135
# Jamaica Plain                  133                    133
# Chinatown                       69                     69
# East Boston                     64                     64
# Mission Hill                    63                     63
# Roxbury                         63                     63
# West End                        60                     60
# Charlestown                     59                     59
# Dorchester                      55                     55
# Theater District                24                     24
# Downtown Crossing               21                     21
# Roslindale                      17                     17
# Leather District                12                     12
# West Roxbury                    10                     10
# Cambridge                        7                      7
# Financial District               5                      5
# Downtown                         4                      4
# Government Center                3                      3
# Somerville                       3                      3
# Harvard Square                   3                      3
# Mattapan                         2                      2
# Hyde Park                        2                      2
# Chestnut Hill                    2                      2
# Brookline                        1                      1

# %%
listings = listings[listings['city'].isin(['Boston'])]

# %%
listings[['id','annual_occupancy_rate']]
# Out:
#             id  annual_occupancy_rate
# 0      5706985               0.057534
# 1       849408               0.706849
# 2      2684840               1.000000
# 3     13547301               0.646575
# 5      6400432               1.000000
# ...        ...                    ...
# 1938   7931331               0.690411
# 1939  14572086               0.043836
# 1940   4964365               0.306849
# 1941  13681910               1.000000
# 1942   8921130               0.989041
#
# [1858 rows x 2 columns]

# %%
listings[listings["price"] > 400].count()
# Out:
# id                                  76
# listing_url                         76
# name                                76
# summary                             72
# space                               56
#                                     ..
# require_guest_phone_verification    76
# reviews_per_month                   54
# neighbourhood_updated               76
# days_booked                         76
# annual_occupancy_rate               76
# Length: 71, dtype: int64

# %%
listings[listings["price"] <= 400].count()
# Out:
# id                                  1782
# listing_url                         1782
# name                                1782
# summary                             1710
# space                               1314
#                                     ...
# require_guest_phone_verification    1782
# reviews_per_month                   1399
# neighbourhood_updated               1782
# days_booked                         1782
# annual_occupancy_rate               1782
# Length: 71, dtype: int64

# %%
# Verifique e converta a coluna 'price' para uma série pandas, se necessário
if not isinstance(listings['price'], pd.Series):
    listings['price'] = pd.Series(listings['price'])

# Crie o boxplot
ax = sns.boxplot(y=listings['price'], orient='v', width=0.2)
ax.figure.set_size_inches(12, 6)
ax.set_title('Preço dos imóveis', fontsize=20)
plt.show()

# %%
listings[['host_response_rate','host_is_superhost','accommodates','bathrooms','bedrooms','price','review_scores_rating','annual_occupancy_rate']].corr().round(4)
# Out:
#                        host_response_rate  host_is_superhost  accommodates  \
# host_response_rate                 1.0000             0.1202        0.0327
# host_is_superhost                  0.1202             1.0000        0.0778
# accommodates                       0.0327             0.0778        1.0000
# bathrooms                          0.0068            -0.0109        0.4484
# bedrooms                          -0.0075             0.0654        0.7430
# price                              0.0377             0.0395        0.2585
# review_scores_rating               0.0408             0.1993       -0.0287
# annual_occupancy_rate             -0.0868            -0.0714       -0.1125
#
#                        bathrooms  bedrooms   price  review_scores_rating  \
# host_response_rate        0.0068   -0.0075  0.0377                0.0408
# host_is_superhost        -0.0109    0.0654  0.0395                0.1993
# accommodates              0.4484    0.7430  0.2585               -0.0287
# bathrooms                 1.0000    0.5344  0.2886                0.0029
# bedrooms                  0.5344    1.0000  0.2862                0.0360
# price                     0.2886    0.2862  1.0000                0.0953
# review_scores_rating      0.0029    0.0360  0.0953                1.0000
# annual_occupancy_rate    -0.0196   -0.0382 -0.0722                0.0744
#
#                        annual_occupancy_rate
# host_response_rate                   -0.0868
# host_is_superhost                    -0.0714
# accommodates                         -0.1125
# bathrooms                            -0.0196
# bedrooms                             -0.0382
# price                                -0.0722
# review_scores_rating                  0.0744
# annual_occupancy_rate                 1.0000

# %%
# Calcula a matriz de correlação
correlation_matrix = listings[['host_response_rate','host_is_superhost','accommodates','bathrooms','bedrooms','price','review_scores_rating','annual_occupancy_rate']].corr()

# Define o tamanho da figura
plt.figure(figsize=(10, 8))

# Desenha o gráfico de calor
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.4f', linewidths=.5, center=0)

# Título do gráfico
plt.title('Heatmap de Correlações (Positivas e Negativas)')

# Exibe o gráfico
plt.show()

# %%
ax = sns.pairplot(listings, y_vars='review_scores_rating', x_vars=['host_response_rate','host_is_superhost','price','annual_occupancy_rate'], kind='reg',height=5, plot_kws={'line_kws':{'color':'red'}})
# Define o tamanho da figura
ax.fig.set_size_inches(20, 10)
ax.fig.suptitle('Dispersão entre as Variáveis', fontsize=20, y=1.05)
ax

# %%
ax = sns.pairplot(listings, y_vars='review_scores_rating', x_vars=['bathrooms','accommodates','bedrooms'], kind='reg',height=5, plot_kws={'line_kws':{'color':'red'}})
# Define o tamanho da figura
ax.fig.set_size_inches(20, 10)
ax.fig.suptitle('Dispersão entre as Variáveis', fontsize=20, y=1.05)
ax

# %%
# Calcular a mediana das reviews por host
host_median_review = listings.groupby('host_id')['review_scores_rating'].median().reset_index()
host_median_review.columns = ['host_id', 'median_review']

# Mesclar a mediana das reviews de volta ao DataFrame original
listings = listings.merge(host_median_review, on='host_id', how='left')

# %%
listings['number_of_reviews'].median()
# Out:
# 5.0

# %%
listings['is_successful_host'] = listings.apply(
    lambda row: 1 if row['host_is_superhost'] == True and row['median_review'] >= 80 and row['annual_occupancy_rate'] >= 0.50 and row['number_of_reviews'] >= 5 else 0,
    axis=1
)

# %%
successful_hosts = listings.groupby('property_type')['is_successful_host'].sum()
total_hosts = listings.groupby('property_type')['host_id'].nunique()
percentage_successful_hosts = (successful_hosts / total_hosts) * 100

result_listings = pd.DataFrame({
    'successful_hosts': successful_hosts,
    'total_hosts': total_hosts,
    'percentage_successful_hosts': percentage_successful_hosts
}).reset_index()

# %%
result_listings
# Out:
#   property_type  successful_hosts  total_hosts  percentage_successful_hosts
# 0     Apartment                53          938                     5.650320
# 1   Condominium                 7          115                     6.086957
# 2         House                 1           76                     1.315789

# %%
listings.groupby('guests_included')['id'].size()
# Out:
# guests_included
# 0       39
# 1     1215
# 2      338
# 3       76
# 4      139
# 5       21
# 6       25
# 8        2
# 10       1
# 12       1
# 14       1
# Name: id, dtype: int64

# %%
# Remover registros onde 'guests_included' é 0
listings = listings[listings['guests_included'] != 0]
# Remover registros onde 'guests_included' é maior ou igual a 8
listings = listings[listings['guests_included'] < 8]

# %%
listings.groupby('guests_included')['id'].size()
# Out:
# guests_included
# 1    1215
# 2     338
# 3      76
# 4     139
# 5      21
# 6      25
# Name: id, dtype: int64

# %%
# Remover registros onde 'guests_included' é 0
listings = listings[listings['neighbourhood_updated'] != 'Harvard Square']

# %%
numeric_columns = [
    'price', 'weekly_price', 'monthly_price', 'security_deposit', 'cleaning_fee',
    'review_scores_rating', 'annual_occupancy_rate', 'reviews_per_month', 'bathrooms', 'bedrooms'
]

for col in numeric_columns:
    mean = listings[col].mean()
    median = listings[col].median()
    difference = abs(mean - median)
    print(f'{col} - Média: {mean:.2f}, Mediana: {median:.2f}, Diferença: {difference:.2f}')
# Out:
# price - Média: 220.05, Mediana: 199.00, Diferença: 21.05
# weekly_price - Média: 1234.64, Mediana: 1080.00, Diferença: 154.64
# monthly_price - Média: 5080.93, Mediana: 4650.00, Diferença: 430.93
# security_deposit - Média: 355.74, Mediana: 300.00, Diferença: 55.74
# cleaning_fee - Média: 84.55, Mediana: 80.00, Diferença: 4.55
# review_scores_rating - Média: 92.11, Mediana: 94.00, Diferença: 1.89
# annual_occupancy_rate - Média: 0.52, Mediana: 0.52, Diferença: 0.00
# reviews_per_month - Média: 1.84, Mediana: 1.09, Diferença: 0.75
# bathrooms - Média: 1.20, Mediana: 1.00, Diferença: 0.20
# bedrooms - Média: 1.34, Mediana: 1.00, Diferença: 0.34

# %%
listings.to_excel('../visualizacoes/arquivos_excel/listings_cleaned.xlsx', index=False)

# %%
listings[listings['neighbourhood_updated'] == 'West Roxbury']
# Out:
#             id                            listing_url  \
# 1547    962610    https://www.airbnb.com/rooms/962610
# 1548  14303090  https://www.airbnb.com/rooms/14303090
# 1549    601763    https://www.airbnb.com/rooms/601763
# 1550  10185866  https://www.airbnb.com/rooms/10185866
# 1551   7513906   https://www.airbnb.com/rooms/7513906
# 1552   6300089   https://www.airbnb.com/rooms/6300089
# 1553  14685903  https://www.airbnb.com/rooms/14685903
#
#                                                    name  \
# 1547                Convenient Boston Hotel Alternative
# 1548                  Cozy Remodeled Compact  Apartment
# 1549                The Alameda 2 | 2BR 1BA | 2nd Floor
# 1550                Beautiful large 2 BR for three week
# 1551                     Temple Street By Maverick, Six
# 1552                 Rustic, european style 3 bed/2bath
# 1553  SPACIOUS private Boston home surrounded by nat...
#
#                                                 summary  \
# 1547  This is a cozy yet spacious one bedroom unit w...
# 1548  The apartment is located on the lower level of...
# 1549  Our comfy two bedroom apartment with tons of l...
# 1550  Fully furnished apartment is available for sho...
# 1551  Studio offers the luxury of home furnishings w...
# 1552  Beautiful, fully renovated apartment 3 bd/2bth...
# 1553  Bright + airy 6 rm, 2 bed home with lg LR, DR,...
#
#                                                   space  \
# 1547  Recently renovated, private one bedroom apartm...
# 1548                                                NaN
# 1549  West Roxbury – Friendly Neighborhood – Commute...
# 1550                                                NaN
# 1551  Our professional managed apartments are great ...
# 1552  A clean and renovated apartment with all ameni...
# 1553                                                NaN
#
#                                             description  \
# 1547  This is a cozy yet spacious one bedroom unit w...
# 1548  The apartment is located on the lower level of...
# 1549  Our comfy two bedroom apartment with tons of l...
# 1550  Fully furnished apartment is available for sho...
# 1551  Studio offers the luxury of home furnishings w...
# 1552  Beautiful, fully renovated apartment 3 bd/2bth...
# 1553  Bright + airy 6 rm, 2 bed home with lg LR, DR,...
#
#                                   neighborhood_overview  \
# 1547  This neighborhood truly has it all.  Good, not...
# 1548                                                NaN
# 1549                                                NaN
# 1550                                                NaN
# 1551  Beacon Hill is one of Boston’s most historic n...
# 1552  The neighborhood is close to the city in a ver...
# 1553                                                NaN
#
#                                                   notes  \
# 1547  Please note that this is a third floor apartme...
# 1548                                                NaN
# 1549                                                NaN
# 1550                                                NaN
# 1551  Things you'll need to bring: Paper products: t...
# 1552  One of the most important & valued aspect of t...
# 1553                                                NaN
#
#                                                 transit  \
# 1547  Plenty of on street parking with no restrictio...
# 1548                                                NaN
# 1549                                                NaN
# 1550                                                NaN
# 1551  Located less than a five minute walk to Park S...
# 1552  3 busses running in high frequency; commuter r...
# 1553                                                NaN
#
#                                                  access  \
# 1547  There is a shared porch and patio available to...
# 1548                                                NaN
# 1549                                                NaN
# 1550                                                NaN
# 1551  The studio's kitchenette comes equipped with a...
# 1552                 Wi-fi, TV, washer & dryer in unit.
# 1553                                                NaN
#
#                                             interaction  \
# 1547  I'm available for questions anytime before or ...
# 1548                                                NaN
# 1549                                                NaN
# 1550                                                NaN
# 1551                                                NaN
# 1552  Check in & out. Questions about area & any oth...
# 1553                                                NaN
#
#                                             house_rules   host_id  \
# 1547  NO SMOKING AND PETS ANYWHERE ON THE PROPERTY 1...   4434391
# 1548        No smoking, keep clean and respect property   8015347
# 1549                                                NaN     71783
# 1550                                                NaN  52311253
# 1551                                 No Smoking No Pets  22348222
# 1552  The house is absolutely NO SMOKING & NO PETS o...  29483150
# 1553                                                NaN   2953540
#
#                                         host_url      host_name host_since  \
# 1547   https://www.airbnb.com/users/show/4434391          Damon 2012-12-18
# 1548   https://www.airbnb.com/users/show/8015347          Edwin 2013-08-07
# 1549     https://www.airbnb.com/users/show/71783          Lance 2010-01-19
# 1550  https://www.airbnb.com/users/show/52311253          Amita 2015-12-26
# 1551  https://www.airbnb.com/users/show/22348222         Alicia 2014-10-09
# 1552  https://www.airbnb.com/users/show/29483150          Irida 2015-03-17
# 1553   https://www.airbnb.com/users/show/2953540  Meghan & Matt 2012-07-16
#
#       host_response_time  host_response_rate  host_acceptance_rate  \
# 1547      within an hour                1.00                  1.00
# 1548      within an hour                1.00                  0.95
# 1549        within a day                0.73                  0.91
# 1550                 NaN                 NaN                   NaN
# 1551  within a few hours                1.00                  0.91
# 1552  within a few hours                1.00                  1.00
# 1553        within a day                1.00                  1.00
#
#       host_is_superhost  host_listings_count  \
# 1547               True                    2
# 1548              False                    3
# 1549              False                   10
# 1550              False                    1
# 1551              False                   52
# 1552              False                    1
# 1553              False                    1
#
#                                     host_verifications  host_has_profile_pic  \
# 1547  ['email', 'phone', 'facebook', 'reviews', 'kba']                  True
# 1548              ['email', 'phone', 'reviews', 'kba']                  True
# 1549  ['email', 'phone', 'facebook', 'reviews', 'kba']                  True
# 1550                                ['email', 'phone']                  True
# 1551            ['email', 'phone', 'reviews', 'jumio']                  True
# 1552              ['email', 'phone', 'reviews', 'kba']                  True
# 1553  ['email', 'phone', 'facebook', 'reviews', 'kba']                  True
#
#       host_identity_verified  \
# 1547                    True
# 1548                    True
# 1549                    True
# 1550                   False
# 1551                    True
# 1552                    True
# 1553                    True
#
#                                                  street neighbourhood  \
# 1547     Centre Street, Boston, MA 02131, United States  West Roxbury
# 1548    Johnson Street, Boston, MA 02132, United States           NaN
# 1549        Alameda Rd, Boston, MA 02132, United States  West Roxbury
# 1550  Ridgecrest Terrace, Boston, MA 02132, United S...  West Roxbury
# 1551     Temple Street, Boston, MA 02114, United States  West Roxbury
# 1552      Maple Street, Boston, MA 02132, United States  West Roxbury
# 1553  Allandale Street, Boston, MA 02130, United States  West Roxbury
#
#      neighbourhood_cleansed    city zipcode   latitude  longitude  \
# 1547           West Roxbury  Boston   02131  42.290526 -71.141056
# 1548           West Roxbury  Boston   02132  42.272320 -71.162498
# 1549           West Roxbury  Boston   02132  42.291181 -71.153162
# 1550           West Roxbury  Boston   02132  42.263386 -71.153656
# 1551           West Roxbury  Boston   02114  42.280096 -71.160763
# 1552           West Roxbury  Boston   02132  42.286412 -71.153716
# 1553           West Roxbury  Boston   02130  42.299553 -71.129138
#
#       is_location_exact property_type        room_type  accommodates  \
# 1547               True     Apartment  Entire home/apt             2
# 1548              False         House  Entire home/apt             4
# 1549               True     Apartment  Entire home/apt             5
# 1550               True     Apartment  Entire home/apt             2
# 1551               True     Apartment  Entire home/apt             2
# 1552               True     Apartment  Entire home/apt             6
# 1553               True         House  Entire home/apt             8
#
#       bathrooms  bedrooms  beds  bed_type  \
# 1547          1         1     1  Real Bed
# 1548          1         2     2  Real Bed
# 1549          1         2     2  Real Bed
# 1550          1         2     2  Real Bed
# 1551          1         0     1  Real Bed
# 1552          2         3     3  Real Bed
# 1553          1         2     2  Real Bed
#
#                                               amenities  price  weekly_price  \
# 1547  {TV,"Cable TV",Internet,"Wireless Internet","A...  119.0         740.0
# 1548  {TV,Internet,"Wireless Internet","Air Conditio...  155.0           NaN
# 1549  {TV,"Cable TV",Internet,"Wireless Internet","A...  125.0         800.0
# 1550  {TV,"Cable TV",Internet,"Wireless Internet","A...  120.0           NaN
# 1551  {TV,"Cable TV","Wireless Internet","Air Condit...  137.0           NaN
# 1552  {TV,"Cable TV",Internet,"Wireless Internet","A...  245.0           NaN
# 1553  {TV,"Cable TV",Internet,"Wireless Internet","A...  349.0           NaN
#
#       monthly_price  security_deposit  cleaning_fee  guests_included  \
# 1547         2550.0             150.0          25.0                2
# 1548            NaN               NaN           NaN                1
# 1549         3200.0             500.0         175.0                2
# 1550            NaN               NaN           NaN                1
# 1551            NaN               NaN         225.0                1
# 1552         4450.0             300.0          75.0                6
# 1553            NaN               NaN           NaN                1
#
#       extra_people  minimum_nights  maximum_nights  availability_30  \
# 1547          35.0               3            1125                9
# 1548           0.0               1            1125                0
# 1549          10.0               2             365                5
# 1550           0.0               1            1125                0
# 1551           0.0               7            1125                0
# 1552          45.0               2            1125               11
# 1553           0.0               2            1125               25
#
#       availability_60  availability_90  availability_365  number_of_reviews  \
# 1547               23               53               328                 33
# 1548                0               25               300                  3
# 1549               10               40               300                  0
# 1550                0                0                 0                  0
# 1551                7               37               312                  1
# 1552               36               62               337                 22
# 1553               55               85               360                  0
#
#      first_review last_review  review_scores_rating  review_scores_accuracy  \
# 1547   2013-08-01  2016-08-19                  99.0                    10.0
# 1548   2016-08-07  2016-08-23                 100.0                     9.0
# 1549          NaT         NaT                   NaN                     NaN
# 1550          NaT         NaT                   NaN                     NaN
# 1551   2015-10-25  2015-10-25                 100.0                    10.0
# 1552   2015-06-01  2016-08-20                  94.0                    10.0
# 1553          NaT         NaT                   NaN                     NaN
#
#       review_scores_cleanliness  review_scores_checkin  \
# 1547                       10.0                   10.0
# 1548                       10.0                   10.0
# 1549                        NaN                    NaN
# 1550                        NaN                    NaN
# 1551                       10.0                   10.0
# 1552                       10.0                   10.0
# 1553                        NaN                    NaN
#
#       review_scores_communication  review_scores_location  \
# 1547                         10.0                     9.0
# 1548                         10.0                    10.0
# 1549                          NaN                     NaN
# 1550                          NaN                     NaN
# 1551                         10.0                    10.0
# 1552                         10.0                    10.0
# 1553                          NaN                     NaN
#
#       review_scores_value  instant_bookable cancellation_policy  \
# 1547                 10.0              True              strict
# 1548                 10.0              True            moderate
# 1549                  NaN             False              strict
# 1550                  NaN             False            flexible
# 1551                  8.0             False              strict
# 1552                 10.0             False              strict
# 1553                  NaN             False            flexible
#
#       require_guest_profile_picture  require_guest_phone_verification  \
# 1547                          False                             False
# 1548                          False                             False
# 1549                          False                             False
# 1550                          False                             False
# 1551                          False                             False
# 1552                          False                             False
# 1553                           True                              True
#
#       reviews_per_month neighbourhood_updated  days_booked  \
# 1547               0.87          West Roxbury           37
# 1548               2.81          West Roxbury           65
# 1549                NaN          West Roxbury           65
# 1550                NaN          West Roxbury          365
# 1551               0.09          West Roxbury           53
# 1552               1.42          West Roxbury           28
# 1553                NaN          West Roxbury            5
#
#       annual_occupancy_rate  median_review  is_successful_host
# 1547               0.101370           96.5                   0
# 1548               0.178082          100.0                   0
# 1549               0.178082           93.0                   0
# 1550               1.000000            NaN                   0
# 1551               0.145205           93.0                   0
# 1552               0.076712           94.0                   0
# 1553               0.013699            NaN                   0

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1813 entries, 0 to 1857
# Data columns (total 73 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                1813 non-null   int64
#  1   listing_url                       1813 non-null   object
#  2   name                              1813 non-null   object
#  3   summary                           1737 non-null   object
#  4   space                             1337 non-null   object
#  5   description                       1813 non-null   object
#  6   neighborhood_overview             1147 non-null   object
#  7   notes                             820 non-null    object
#  8   transit                           1187 non-null   object
#  9   access                            986 non-null    object
#  10  interaction                       983 non-null    object
#  11  house_rules                       1198 non-null   object
#  12  host_id                           1813 non-null   int64
#  13  host_url                          1813 non-null   object
#  14  host_name                         1813 non-null   object
#  15  host_since                        1813 non-null   datetime64[ns]
#  16  host_response_time                1599 non-null   object
#  17  host_response_rate                1599 non-null   float64
#  18  host_acceptance_rate              1599 non-null   float64
#  19  host_is_superhost                 1813 non-null   bool
#  20  host_listings_count               1813 non-null   int64
#  21  host_verifications                1813 non-null   object
#  22  host_has_profile_pic              1813 non-null   bool
#  23  host_identity_verified            1813 non-null   bool
#  24  street                            1813 non-null   object
#  25  neighbourhood                     1585 non-null   object
#  26  neighbourhood_cleansed            1813 non-null   object
#  27  city                              1813 non-null   object
#  28  zipcode                           1803 non-null   object
#  29  latitude                          1813 non-null   float64
#  30  longitude                         1813 non-null   float64
#  31  is_location_exact                 1813 non-null   bool
#  32  property_type                     1813 non-null   object
#  33  room_type                         1813 non-null   object
#  34  accommodates                      1813 non-null   int64
#  35  bathrooms                         1813 non-null   int64
#  36  bedrooms                          1813 non-null   int64
#  37  beds                              1813 non-null   int64
#  38  bed_type                          1813 non-null   object
#  39  amenities                         1813 non-null   object
#  40  price                             1813 non-null   float64
#  41  weekly_price                      346 non-null    float64
#  42  monthly_price                     409 non-null    float64
#  43  security_deposit                  734 non-null    float64
#  44  cleaning_fee                      1405 non-null   float64
#  45  guests_included                   1813 non-null   int64
#  46  extra_people                      1813 non-null   float64
#  47  minimum_nights                    1813 non-null   int64
#  48  maximum_nights                    1813 non-null   int64
#  49  availability_30                   1813 non-null   int64
#  50  availability_60                   1813 non-null   int64
#  51  availability_90                   1813 non-null   int64
#  52  availability_365                  1813 non-null   int64
#  53  number_of_reviews                 1813 non-null   int64
#  54  first_review                      1413 non-null   datetime64[ns]
#  55  last_review                       1413 non-null   datetime64[ns]
#  56  review_scores_rating              1387 non-null   float64
#  57  review_scores_accuracy            1383 non-null   float64
#  58  review_scores_cleanliness         1383 non-null   float64
#  59  review_scores_checkin             1383 non-null   float64
#  60  review_scores_communication       1383 non-null   float64
#  61  review_scores_location            1381 non-null   float64
#  62  review_scores_value               1383 non-null   float64
#  63  instant_bookable                  1813 non-null   bool
#  64  cancellation_policy               1813 non-null   object
#  65  require_guest_profile_picture     1813 non-null   bool
#  66  require_guest_phone_verification  1813 non-null   bool
#  67  reviews_per_month                 1413 non-null   float64
#  68  neighbourhood_updated             1813 non-null   object
#  69  days_booked                       1813 non-null   int64
#  70  annual_occupancy_rate             1813 non-null   float64
#  71  median_review                     1599 non-null   float64
#  72  is_successful_host                1813 non-null   int64
# dtypes: bool(7), datetime64[ns](3), float64(20), int64(17), object(26)
# memory usage: 961.4+ KB

# %%
listings[listings['bathrooms'] == 0].count()
# Out:
# id                       0
# listing_url              0
# name                     0
# summary                  0
# space                    0
#                         ..
# neighbourhood_updated    0
# days_booked              0
# annual_occupancy_rate    0
# median_review            0
# is_successful_host       0
# Length: 73, dtype: int64

# %%
listings[listings['guests_included'] == 1]['price'].median()
# Out:
# 199.0

# %%
listings['guests_included'].median()
# Out:
# 1.0

# %%
listings['annual_occupancy_rate'].mean()
# Out:
# 0.5192256836092453

# %%
listings['number_of_reviews'].median()
# Out:
# 5.0

# %%
listings['number_of_reviews'].sum()
# Out:
# 30500

# %%
listings['review_scores_rating'].median()
# Out:
# 94.0

# %%
listings['number_of_reviews'].count()
# Out:
# 1813

# %%
listings
# Out:
#             id                            listing_url  \
# 0      5706985   https://www.airbnb.com/rooms/5706985
# 1       849408    https://www.airbnb.com/rooms/849408
# 2      2684840   https://www.airbnb.com/rooms/2684840
# 3     13547301  https://www.airbnb.com/rooms/13547301
# 4      6400432   https://www.airbnb.com/rooms/6400432
# ...        ...                                    ...
# 1853   7931331   https://www.airbnb.com/rooms/7931331
# 1854  14572086  https://www.airbnb.com/rooms/14572086
# 1855   4964365   https://www.airbnb.com/rooms/4964365
# 1856  13681910  https://www.airbnb.com/rooms/13681910
# 1857   8921130   https://www.airbnb.com/rooms/8921130
#
#                                                    name  \
# 0                   New Lrg Studio apt 15 min to Boston
# 1                     Perfect & Practical Boston Rental
# 2                    Updated, spacious living in Rozzie
# 3                         2 Bedroom Apartment in Boston
# 4                     Spacious 3 bedroom cape cod style
# ...                                                 ...
# 1853                Pristine Modern 2BR next to Harvard
# 1854  1 mins to train,clean and neat,wifi,Queensize ...
# 1855                      Charming sunny 2BD near BU/BC
# 1856                               Cool 3 BR in Allston
# 1857                  Beautiful, Modern, Furnished Apt!
#
#                                                 summary  \
# 0     It's a 5 minute walk to Rosi Square to catch t...
# 1     This is a cozy and spacious two bedroom unit w...
# 2     Clean, sunny 2 bedroom in amazing Roslindale V...
# 3     My place is close to Public Transportation. Th...
# 4     Three bedroom in Boston's Roslindale neighborh...
# ...                                                 ...
# 1853  This welcoming 2-bedroom apartment is located ...
# 1854  My place is close to Train station,Boston Coll...
# 1855  Our cozy 2 bed is located near Comm Ave; a qui...
# 1856  This fun 3 bedroom apartment is conveniently l...
# 1857  This is a beautiful apt, equipped with new app...
#
#                                                   space  \
# 0     The whole house was recently redone and it 's ...
# 1     Perfect apartment rental for those in town vis...
# 2                                                   NaN
# 3                                                   NaN
# 4     This Cape Cod style home features two bedrooms...
# ...                                                 ...
# 1853  This welcoming 2-bedroom apartment is located ...
# 1854  The pictures are not updated it, we changed th...
# 1855  Sunny, cheerful open floor plan with two bedro...
# 1856  Capturing the spirit of New England, this red ...
# 1857                                                NaN
#
#                                             description  \
# 0     It's a 5 minute walk to Rosi Square to catch t...
# 1     This is a cozy and spacious two bedroom unit w...
# 2     Clean, sunny 2 bedroom in amazing Roslindale V...
# 3     My place is close to Public Transportation. Th...
# 4     Three bedroom in Boston's Roslindale neighborh...
# ...                                                 ...
# 1853  This welcoming 2-bedroom apartment is located ...
# 1854  My place is close to Train station,Boston Coll...
# 1855  Our cozy 2 bed is located near Comm Ave; a qui...
# 1856  This fun 3 bedroom apartment is conveniently l...
# 1857  This is a beautiful apt, equipped with new app...
#
#                                   neighborhood_overview  \
# 0     Roslindale is the new hip area of Boston. Clos...
# 1     This neighborhood truly has it all.  Good, not...
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1853  Cambridge is situated North of Boston Proper, ...
# 1854                                                NaN
# 1855  We love our neighborhood's close proximity to ...
# 1856  Named after the American painter Washington Al...
# 1857  Located right on the Brookline/Allston border,...
#
#                                                   notes  \
# 0     Information about the house, wifi pasword and ...
# 1     Please note that this is a second floor apartm...
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1853  • Please be aware that we don’t have a dining ...
# 1854                                                NaN
# 1855  Private pool access from Memorial Day to Labor...
# 1856                                                NaN
# 1857                                                NaN
#
#                                                 transit  \
# 0     The commuter rail (Needham Line) is a 5 minute...
# 1     Plenty of on street parking with no restrictio...
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1853  10-min walk to the Harvard Square T station. T...
# 1854                                                NaN
# 1855  Very close (less than 5 min walk) to Green Lin...
# 1856  You're a mere 3 minute walk from the 66 bus li...
# 1857  This apartment includes a parking spot for no ...
#
#                                                  access  \
# 0     I have an electronic keypad so arrival time ca...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1853                                                NaN
# 1854                                                NaN
# 1855  Guests can enter through front or back door of...
# 1856                                                NaN
# 1857                                                NaN
#
#                                             interaction  \
# 0     I can interact or not- that is up to you. This...
# 1     I'm available for questions anytime before or ...
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1853  Need more towels? A restaurant recommendation?...
# 1854                                                NaN
# 1855  We will be here to show you into the apartment.
# 1856  Need more towels? A restaurant recommendation?...
# 1857                                                NaN
#
#                                             house_rules   host_id  \
# 0     Please no shoes in the house so bring slippers...   6570877
# 1     NO SMOKING OR PETS ANYWHERE ON THE PROPERTY 1....   4434391
# 2     - One of the bedroom closets is not accessible...  13743098
# 3                                                   NaN  57402911
# 4                                                   NaN  23127285
# ...                                                 ...       ...
# 1853  House Rules 1. Check-in is 4 pm local time. If...  12243051
# 1854                                                NaN  84991497
# 1855  We are a non-smoking apartment.  Thank you! Pl...   6104365
# 1856  House Rules 1. Check-in is 4 pm local time. If...  12243051
# 1857                        This is a non-smoking unit.  16569506
#
#                                         host_url host_name host_since  \
# 0      https://www.airbnb.com/users/show/6570877    Juliet 2013-05-25
# 1      https://www.airbnb.com/users/show/4434391     Damon 2012-12-18
# 2     https://www.airbnb.com/users/show/13743098     Megan 2014-03-31
# 3     https://www.airbnb.com/users/show/57402911   Georgia 2016-02-04
# 4     https://www.airbnb.com/users/show/23127285     Jesús 2014-10-29
# ...                                          ...       ...        ...
# 1853  https://www.airbnb.com/users/show/12243051  Flatbook 2014-02-14
# 1854  https://www.airbnb.com/users/show/84991497      Qing 2016-07-20
# 1855   https://www.airbnb.com/users/show/6104365     Sarah 2013-04-26
# 1856  https://www.airbnb.com/users/show/12243051  Flatbook 2014-02-14
# 1857  https://www.airbnb.com/users/show/16569506      Alex 2014-06-09
#
#       host_response_time  host_response_rate  host_acceptance_rate  \
# 0         within an hour                0.98                  0.96
# 1         within an hour                1.00                  1.00
# 2     within a few hours                1.00                  1.00
# 3         within an hour                1.00                  0.97
# 4           within a day                1.00                  0.63
# ...                  ...                 ...                   ...
# 1853  within a few hours                0.71                  0.98
# 1854      within an hour                1.00                  1.00
# 1855  within a few hours                1.00                  1.00
# 1856  within a few hours                0.71                  0.98
# 1857                 NaN                 NaN                   NaN
#
#       host_is_superhost  host_listings_count  \
# 0                 False                    5
# 1                  True                    2
# 2                 False                    2
# 3                 False                    1
# 4                 False                    1
# ...                 ...                  ...
# 1853              False                  363
# 1854              False                    2
# 1855              False                    1
# 1856              False                  363
# 1857              False                    1
#
#                                      host_verifications  host_has_profile_pic  \
# 0         ['email', 'phone', 'reviews', 'jumio', 'kba']                  True
# 1      ['email', 'phone', 'facebook', 'reviews', 'kba']                  True
# 2                         ['email', 'phone', 'reviews']                  True
# 3                  ['email', 'phone', 'reviews', 'kba']                  True
# 4                  ['email', 'phone', 'reviews', 'kba']                  True
# ...                                                 ...                   ...
# 1853  ['email', 'phone', 'reviews', 'manual_offline'...                  True
# 1854                      ['email', 'phone', 'reviews']                  True
# 1855   ['email', 'phone', 'facebook', 'reviews', 'kba']                  True
# 1856  ['email', 'phone', 'reviews', 'manual_offline'...                  True
# 1857             ['email', 'phone', 'reviews', 'jumio']                  True
#
#       host_identity_verified  \
# 0                       True
# 1                       True
# 2                      False
# 3                       True
# 4                       True
# ...                      ...
# 1853                    True
# 1854                   False
# 1855                    True
# 1856                    True
# 1857                    True
#
#                                                  street     neighbourhood  \
# 0     Kittredge Street, Boston, MA 02131, United States               NaN
# 1        Centre Street, Boston, MA 02131, United States        Roslindale
# 2      Primrose Street, Boston, MA 02131, United States        Roslindale
# 3      Fairview Street, Boston, MA 02131, United States        Roslindale
# 4     Metropolitan Ave, Boston, MA 02131, United States               NaN
# ...                                                 ...               ...
# 1853  N. Harvard Street, Boston, MA 02134, United St...  Allston-Brighton
# 1854     Gordon Street, Boston, MA 02135, United States  Allston-Brighton
# 1855     Kelton Street, Boston, MA 02134, United States  Allston-Brighton
# 1856     Brainerd Road, Boston, MA 02134, United States  Allston-Brighton
# 1857     Brainerd Road, Boston, MA 02134, United States  Allston-Brighton
#
#      neighbourhood_cleansed    city zipcode   latitude  longitude  \
# 0                Roslindale  Boston   02131  42.281390 -71.131190
# 1                Roslindale  Boston   02131  42.288820 -71.139510
# 2                Roslindale  Boston   02131  42.291723 -71.131556
# 3                Roslindale  Boston   02131  42.287641 -71.129883
# 4                Roslindale  Boston   02131  42.278383 -71.128780
# ...                     ...     ...     ...        ...        ...
# 1853                Allston  Boston   02134  42.362878 -71.129409
# 1854                Allston  Boston   02135  42.350058 -71.139250
# 1855                Allston  Boston   02134  42.347355 -71.137387
# 1856                Allston  Boston   02134  42.349670 -71.130489
# 1857                Allston  Boston   02134  42.347206 -71.134339
#
#       is_location_exact property_type        room_type  accommodates  \
# 0                 False     Apartment  Entire home/apt             3
# 1                  True     Apartment  Entire home/apt             5
# 2                  True   Condominium  Entire home/apt             4
# 3                  True     Apartment  Entire home/apt             5
# 4                 False         House  Entire home/apt             8
# ...                 ...           ...              ...           ...
# 1853               True     Apartment  Entire home/apt             6
# 1854               True     Apartment  Entire home/apt             4
# 1855               True     Apartment  Entire home/apt             5
# 1856               True     Apartment  Entire home/apt             6
# 1857               True     Apartment  Entire home/apt             2
#
#       bathrooms  bedrooms  beds  bed_type  \
# 0             1         1     2  Real Bed
# 1             1         2     2  Real Bed
# 2             1         2     2  Real Bed
# 3             1         2     3  Real Bed
# 4             1         3     5  Real Bed
# ...         ...       ...   ...       ...
# 1853          2         2     3  Real Bed
# 1854          1         2     2  Real Bed
# 1855          1         2     2  Real Bed
# 1856          2         3     3  Real Bed
# 1857          1         1     1  Real Bed
#
#                                               amenities  price  weekly_price  \
# 0     {TV,Internet,"Wireless Internet",Kitchen,"Free...  100.0           NaN
# 1     {TV,"Cable TV",Internet,"Wireless Internet","A...  229.0           NaN
# 2     {"Cable TV","Wireless Internet","Air Condition...   93.0           NaN
# 3     {TV,Internet,"Wireless Internet","Air Conditio...  150.0           NaN
# 4     {TV,Internet,"Wireless Internet",Kitchen,"Free...  150.0         700.0
# ...                                                 ...    ...           ...
# 1853  {TV,"Cable TV",Internet,"Wireless Internet","A...  269.0           NaN
# 1854  {"Air Conditioning",Kitchen,Heating,"Family/Ki...  150.0           NaN
# 1855  {TV,"Cable TV",Internet,"Wireless Internet","A...  180.0           NaN
# 1856  {TV,"Cable TV",Internet,"Wireless Internet","A...  279.0           NaN
# 1857  {TV,"Cable TV",Internet,"Wireless Internet","A...  129.0         712.0
#
#       monthly_price  security_deposit  cleaning_fee  guests_included  \
# 0               NaN               NaN           NaN                1
# 1               NaN             200.0          50.0                4
# 2               NaN               NaN          40.0                1
# 3               NaN               NaN          50.0                5
# 4            2500.0             150.0         100.0                6
# ...             ...               ...           ...              ...
# 1853            NaN             300.0          80.0                2
# 1854            NaN               NaN           NaN                1
# 1855            NaN               NaN          80.0                4
# 1856            NaN             400.0          95.0                1
# 1857         2309.0               NaN           NaN                1
#
#       extra_people  minimum_nights  maximum_nights  availability_30  \
# 0             25.0               1            1125               22
# 1             25.0               4              10               20
# 2              0.0               1            1125                0
# 3             30.0               2              21                8
# 4              0.0               3            1125                0
# ...            ...             ...             ...              ...
# 1853          10.0               3            1125               17
# 1854           0.0               1            1125               15
# 1855          25.0               1            1125                0
# 1856           0.0               3            1125                0
# 1857           0.0               1            1125                0
#
#       availability_60  availability_90  availability_365  number_of_reviews  \
# 0                  39               69               344                 57
# 1                  50               80               107                 33
# 2                   0                0                 0                  1
# 3                  17               39               129                 12
# 4                   0                0                 0                 21
# ...               ...              ...               ...                ...
# 1853               37               67               113                 21
# 1854               44               74               349                  0
# 1855                0                5               253                  6
# 1856                0                0                 0                  0
# 1857                0                0                 4                  2
#
#      first_review last_review  review_scores_rating  review_scores_accuracy  \
# 0      2015-07-08  2016-09-01                  90.0                    10.0
# 1      2014-01-02  2016-05-27                  94.0                    10.0
# 2      2016-07-23  2016-07-23                 100.0                    10.0
# 3      2016-06-27  2016-09-03                  97.0                    10.0
# 4      2015-08-07  2016-08-19                  88.0                     9.0
# ...           ...         ...                   ...                     ...
# 1853   2015-09-15  2016-07-28                  95.0                    10.0
# 1854          NaT         NaT                   NaN                     NaN
# 1855   2015-06-03  2016-08-08                  92.0                     9.0
# 1856          NaT         NaT                   NaN                     NaN
# 1857   2016-01-20  2016-02-20                 100.0                    10.0
#
#       review_scores_cleanliness  review_scores_checkin  \
# 0                          10.0                   10.0
# 1                           9.0                   10.0
# 2                          10.0                   10.0
# 3                          10.0                   10.0
# 4                           9.0                    9.0
# ...                         ...                    ...
# 1853                       10.0                    9.0
# 1854                        NaN                    NaN
# 1855                        9.0                   10.0
# 1856                        NaN                    NaN
# 1857                       10.0                   10.0
#
#       review_scores_communication  review_scores_location  \
# 0                            10.0                     9.0
# 1                            10.0                     9.0
# 2                            10.0                    10.0
# 3                            10.0                     9.0
# 4                            10.0                     9.0
# ...                           ...                     ...
# 1853                         10.0                     9.0
# 1854                          NaN                     NaN
# 1855                         10.0                     9.0
# 1856                          NaN                     NaN
# 1857                         10.0                     NaN
#
#       review_scores_value  instant_bookable cancellation_policy  \
# 0                     9.0             False              strict
# 1                     9.0             False              strict
# 2                    10.0              True            flexible
# 3                    10.0             False            moderate
# 4                    10.0             False            flexible
# ...                   ...               ...                 ...
# 1853                  9.0              True              strict
# 1854                  NaN              True              strict
# 1855                 10.0             False            flexible
# 1856                  NaN              True              strict
# 1857                 10.0             False            flexible
#
#       require_guest_profile_picture  require_guest_phone_verification  \
# 0                             False                             False
# 1                             False                             False
# 2                             False                             False
# 3                             False                             False
# 4                             False                             False
# ...                             ...                               ...
# 1853                          False                             False
# 1854                          False                             False
# 1855                          False                             False
# 1856                          False                             False
# 1857                          False                             False
#
#       reviews_per_month neighbourhood_updated  days_booked  \
# 0                  4.00            Roslindale           21
# 1                  1.01            Roslindale          258
# 2                  0.64            Roslindale          365
# 3                  4.93            Roslindale          236
# 4                  1.58            Roslindale          365
# ...                 ...                   ...          ...
# 1853               1.75      Allston-Brighton          252
# 1854                NaN      Allston-Brighton           16
# 1855               0.39      Allston-Brighton          112
# 1856                NaN      Allston-Brighton          365
# 1857               0.26      Allston-Brighton          361
#
#       annual_occupancy_rate  median_review  is_successful_host
# 0                  0.057534           90.5                   0
# 1                  0.706849           96.5                   1
# 2                  1.000000          100.0                   0
# 3                  0.646575           97.0                   0
# 4                  1.000000           88.0                   0
# ...                     ...            ...                 ...
# 1853               0.690411           92.0                   0
# 1854               0.043836           90.0                   0
# 1855               0.306849           92.0                   0
# 1856               1.000000           92.0                   0
# 1857               0.989041          100.0                   0
#
# [1813 rows x 73 columns]

# %%
# Filtrando os registros de calendar que têm listing_id no listings
filtered_calendar = calendar[calendar['listing_id'].isin(listings['id'])]

# Fazendo a junção dos DataFrames com base nas colunas 'listing_id' e 'id'
merged_df = pd.merge(filtered_calendar[['listing_id', 'available']], listings[['id', 'property_type']], left_on='listing_id', right_on='id')

# Filtrando registros onde 'available' é True
available_listings = merged_df[merged_df['available'] == False]

# Agrupando por 'property_type' e contando 'listing_id' distintos
result = available_listings.groupby('property_type')['listing_id'].nunique().reset_index()

# Renomeando a coluna para melhor entendimento
result.columns = ['property_type', 'distinct_listing_count']

print(result)
# Out:
#   property_type  distinct_listing_count
# 0     Apartment                    1567
# 1   Condominium                     132
# 2         House                      79

# %%
listings.groupby(['neighbourhood_updated', 'property_type'])['annual_occupancy_rate'].mean().reset_index().round(2) * 100
# Out:
#                                 neighbourhood_updated  \
# 0   Allston-BrightonAllston-BrightonAllston-Bright...
# 1   Allston-BrightonAllston-BrightonAllston-Bright...
# 2   Allston-BrightonAllston-BrightonAllston-Bright...
# 3   Back BayBack BayBack BayBack BayBack BayBack B...
# 4   Back BayBack BayBack BayBack BayBack BayBack B...
# 5   Back BayBack BayBack BayBack BayBack BayBack B...
# 6   Beacon HillBeacon HillBeacon HillBeacon HillBe...
# 7   Beacon HillBeacon HillBeacon HillBeacon HillBe...
# 8   Beacon HillBeacon HillBeacon HillBeacon HillBe...
# 9   CharlestownCharlestownCharlestownCharlestownCh...
# 10  CharlestownCharlestownCharlestownCharlestownCh...
# 11  CharlestownCharlestownCharlestownCharlestownCh...
# 12  ChinatownChinatownChinatownChinatownChinatownC...
# 13  ChinatownChinatownChinatownChinatownChinatownC...
# 14  DorchesterDorchesterDorchesterDorchesterDorche...
# 15  DorchesterDorchesterDorchesterDorchesterDorche...
# 16  DorchesterDorchesterDorchesterDorchesterDorche...
# 17  DowntownDowntownDowntownDowntownDowntownDownto...
# 18  Downtown CrossingDowntown CrossingDowntown Cro...
# 19  East BostonEast BostonEast BostonEast BostonEa...
# 20  East BostonEast BostonEast BostonEast BostonEa...
# 21  East BostonEast BostonEast BostonEast BostonEa...
# 22  Fenway/KenmoreFenway/KenmoreFenway/KenmoreFenw...
# 23  Fenway/KenmoreFenway/KenmoreFenway/KenmoreFenw...
# 24  Fenway/KenmoreFenway/KenmoreFenway/KenmoreFenw...
# 25  Financial DistrictFinancial DistrictFinancial ...
# 26  Government CenterGovernment CenterGovernment C...
# 27  Hyde ParkHyde ParkHyde ParkHyde ParkHyde ParkH...
# 28  Jamaica PlainJamaica PlainJamaica PlainJamaica...
# 29  Jamaica PlainJamaica PlainJamaica PlainJamaica...
# 30  Jamaica PlainJamaica PlainJamaica PlainJamaica...
# 31  Leather DistrictLeather DistrictLeather Distri...
# 32  Leather DistrictLeather DistrictLeather Distri...
# 33  MattapanMattapanMattapanMattapanMattapanMattap...
# 34  MattapanMattapanMattapanMattapanMattapanMattap...
# 35  Mission HillMission HillMission HillMission Hi...
# 36  North EndNorth EndNorth EndNorth EndNorth EndN...
# 37  North EndNorth EndNorth EndNorth EndNorth EndN...
# 38  North EndNorth EndNorth EndNorth EndNorth EndN...
# 39  RoslindaleRoslindaleRoslindaleRoslindaleRoslin...
# 40  RoslindaleRoslindaleRoslindaleRoslindaleRoslin...
# 41  RoslindaleRoslindaleRoslindaleRoslindaleRoslin...
# 42  RoxburyRoxburyRoxburyRoxburyRoxburyRoxburyRoxb...
# 43  RoxburyRoxburyRoxburyRoxburyRoxburyRoxburyRoxb...
# 44  RoxburyRoxburyRoxburyRoxburyRoxburyRoxburyRoxb...
# 45  South BostonSouth BostonSouth BostonSouth Bost...
# 46  South BostonSouth BostonSouth BostonSouth Bost...
# 47  South BostonSouth BostonSouth BostonSouth Bost...
# 48  South EndSouth EndSouth EndSouth EndSouth EndS...
# 49  South EndSouth EndSouth EndSouth EndSouth EndS...
# 50  South EndSouth EndSouth EndSouth EndSouth EndS...
# 51  Theater DistrictTheater DistrictTheater Distri...
# 52  West EndWest EndWest EndWest EndWest EndWest E...
# 53  West RoxburyWest RoxburyWest RoxburyWest Roxbu...
# 54  West RoxburyWest RoxburyWest RoxburyWest Roxbu...
#
#                                         property_type  annual_occupancy_rate
# 0   ApartmentApartmentApartmentApartmentApartmentA...                   64.0
# 1   CondominiumCondominiumCondominiumCondominiumCo...                   60.0
# 2   HouseHouseHouseHouseHouseHouseHouseHouseHouseH...                   39.0
# 3   ApartmentApartmentApartmentApartmentApartmentA...                   44.0
# 4   CondominiumCondominiumCondominiumCondominiumCo...                   55.0
# 5   HouseHouseHouseHouseHouseHouseHouseHouseHouseH...                   35.0
# 6   ApartmentApartmentApartmentApartmentApartmentA...                   59.0
# 7   CondominiumCondominiumCondominiumCondominiumCo...                   56.0
# 8   HouseHouseHouseHouseHouseHouseHouseHouseHouseH...                   50.0
# 9   ApartmentApartmentApartmentApartmentApartmentA...                   54.0
# 10  CondominiumCondominiumCondominiumCondominiumCo...                   76.0
# 11  HouseHouseHouseHouseHouseHouseHouseHouseHouseH...                   34.0
# 12  ApartmentApartmentApartmentApartmentApartmentA...                   42.0
# 13  CondominiumCondominiumCondominiumCondominiumCo...                   98.0
# 14  ApartmentApartmentApartmentApartmentApartmentA...                   54.0
# 15  CondominiumCondominiumCondominiumCondominiumCo...                   79.0
# 16  HouseHouseHouseHouseHouseHouseHouseHouseHouseH...                   48.0
# 17  ApartmentApartmentApartmentApartmentApartmentA...                   48.0
# 18  ApartmentApartmentApartmentApartmentApartmentA...                   62.0
# 19  ApartmentApartmentApartmentApartmentApartmentA...                   50.0
# 20  CondominiumCondominiumCondominiumCondominiumCo...                   35.0
# 21  HouseHouseHouseHouseHouseHouseHouseHouseHouseH...                   61.0
# 22  ApartmentApartmentApartmentApartmentApartmentA...                   56.0
# 23  CondominiumCondominiumCondominiumCondominiumCo...                   47.0
# 24  HouseHouseHouseHouseHouseHouseHouseHouseHouseH...                  100.0
# 25  ApartmentApartmentApartmentApartmentApartmentA...                   47.0
# 26  ApartmentApartmentApartmentApartmentApartmentA...                   21.0
# 27  ApartmentApartmentApartmentApartmentApartmentA...                   65.0
# 28  ApartmentApartmentApartmentApartmentApartmentA...                   51.0
# 29  CondominiumCondominiumCondominiumCondominiumCo...                   58.0
# 30  HouseHouseHouseHouseHouseHouseHouseHouseHouseH...                   43.0
# 31  ApartmentApartmentApartmentApartmentApartmentA...                   45.0
# 32  CondominiumCondominiumCondominiumCondominiumCo...                   67.0
# 33  ApartmentApartmentApartmentApartmentApartmentA...                   15.0
# 34  HouseHouseHouseHouseHouseHouseHouseHouseHouseH...                    0.0
# 35  ApartmentApartmentApartmentApartmentApartmentA...                   53.0
# 36  ApartmentApartmentApartmentApartmentApartmentA...                   54.0
# 37  CondominiumCondominiumCondominiumCondominiumCo...                   51.0
# 38  HouseHouseHouseHouseHouseHouseHouseHouseHouseH...                   50.0
# 39  ApartmentApartmentApartmentApartmentApartmentA...                   35.0
# 40  CondominiumCondominiumCondominiumCondominiumCo...                  100.0
# 41  HouseHouseHouseHouseHouseHouseHouseHouseHouseH...                   28.0
# 42  ApartmentApartmentApartmentApartmentApartmentA...                   47.0
# 43  CondominiumCondominiumCondominiumCondominiumCo...                   69.0
# 44  HouseHouseHouseHouseHouseHouseHouseHouseHouseH...                   72.0
# 45  ApartmentApartmentApartmentApartmentApartmentA...                   57.0
# 46  CondominiumCondominiumCondominiumCondominiumCo...                   64.0
# 47  HouseHouseHouseHouseHouseHouseHouseHouseHouseH...                   64.0
# 48  ApartmentApartmentApartmentApartmentApartmentA...                   49.0
# 49  CondominiumCondominiumCondominiumCondominiumCo...                   81.0
# 50  HouseHouseHouseHouseHouseHouseHouseHouseHouseH...                    0.0
# 51  ApartmentApartmentApartmentApartmentApartmentA...                   47.0
# 52  ApartmentApartmentApartmentApartmentApartmentA...                   30.0
# 53  ApartmentApartmentApartmentApartmentApartmentA...                   30.0
# 54  HouseHouseHouseHouseHouseHouseHouseHouseHouseH...                   10.0

# %%
listings.groupby('neighbourhood_updated').size().reset_index(name='count').sort_values(by='count',ascending = False)
# Out:
#    neighbourhood_updated  count
# 1               Back Bay    243
# 21             South End    212
# 9         Fenway/Kenmore    195
# 20          South Boston    145
# 0       Allston-Brighton    145
# 17             North End    133
# 2            Beacon Hill    124
# 13         Jamaica Plain    120
# 4              Chinatown     69
# 23              West End     60
# 8            East Boston     59
# 19               Roxbury     58
# 16          Mission Hill     56
# 5             Dorchester     53
# 3            Charlestown     46
# 22      Theater District     24
# 7      Downtown Crossing     21
# 18            Roslindale     15
# 14      Leather District     12
# 24          West Roxbury      7
# 10    Financial District      5
# 6               Downtown      4
# 11     Government Center      3
# 15              Mattapan      2
# 12             Hyde Park      2
